# %%
import io
import paramiko

# %%
class KeyReader(object):
    
    available_pkey_classes = (
        paramiko.rsakey.RSAKey,
        paramiko.dsskey.DSSKey, 
        paramiko.ecdsakey.ECDSAKey,
        paramiko.ed25519key.Ed25519Key
    )
    
    def __init__(self, *args, **kwargs):
        self.__key = None
        
    def __load_certificate(self, cert_path, cert_data):
        if cert_path is not None:
            self.__key.load_certificate(cert_path)
        if cert_data is not None:
            self.__key.load_certificate(cert_data)

    def __read_private_key_from_file(self, filename, password):
        for pkey_class in self.available_pkey_classes:
            try:
                self.__key = pkey_class.from_private_key_file(filename, password)
            except paramiko.SSHException as e:
                print("{}".format(e))
            except paramiko.PasswordRequiredException:
                raise paramiko.PasswordRequiredException('Password is requred')

    def __read_private_key(self, pkey_str, password):
        for pkey_class in self.available_pkey_classes:
            try:
                file_obj = io.StringIO(pkey_str)
                self.__key = pkey_class.from_private_key(file_obj, password)
            except paramiko.SSHException as e:            
                print("{}".format(e))
            except paramiko.PasswordRequiredException:
                raise paramiko.PasswordRequiredException('Password is requred')
            finally:
                file_obj.close()
    
    def read(self, filename=None, pkey_str=None, password=None, cert_path=None, cert_data=None):
        if filename is not None:
            self.__read_private_key_from_file(filename, password)
        if pkey_str is not None:
            self.__read_private_key(pkey_str, password)
            
        if self.__key is None:
            raise paramiko.SSHException("Incorrect input credentials")
        else:
            self.__load_certificate(cert_path, cert_data)
            
        return self.__key

# %%
class SSHClient(object):
    def __init__(self, hostname, username, password=None, pkey=None):
        self.hostname = hostname
        self.username = username
        self.password = password
        self.pkey = pkey
        
        self.__client = paramiko.SSHClient()
        self.__client.set_missing_host_key_policy(paramiko.MissingHostKeyPolicy())
    
    def connect(self):
        self.__client.connect(hostname=self.hostname, username=self.username, password=self.password, pkey=self.pkey)
        
    def close(self):
        self.__client.close()
    
    def exec_command(self, cmd):
        return self.__client.exec_command(cmd)

# %%
HOST = '192.168.56.111'
USER = 'u1'
PASSWORD = 'q'
KEY_PASSPHRASE = 'P@ssw0rd'
KEY_FILE = '/home/shabykivai/.ssh/vm5/id_rsa'
KEY_CERTIFICATE_FILE = '/home/shabykivai/.ssh/vm5/id_rsa-cert.pub'

# %%
key_reader = KeyReader()
key = key_reader.read(filename=KEY_FILE, password=KEY_PASSPHRASE, cert_path=KEY_CERTIFICATE_FILE)
    
client = SSHClient(HOST, USER, PASSWORD, key)
client.connect()
# Out:
# not a valid DSA private key file
# not a valid EC private key file
# not a valid OPENSSH private key file

# %%
import abc

class SystemInfoCrawler(abc.ABC):
    @abc.abstractmethod
    def get_operating_system(self):
        raise NotImplementedError('Метод не реализован')
    
    @abc.abstractmethod
    def get_cpu(self):
        raise NotImplementedError('Метод не реализован') 
    
    @abc.abstractmethod
    def get_gpu(self):
        raise NotImplementedError('Метод не реализован') 
    
    @abc.abstractmethod
    def get_deamon_services(self):
        raise NotImplementedError('Метод не реализован')
    
    @abc.abstractmethod
    def get_software(self):
        raise NotImplementedError('Метод не реализован')

# %%
stdin, stdout, stderr = client.exec_command('cat /etc/os-release')
for line in stdout:
    print(line.strip('\n'))
    
stdin, stdout, stderr = client.exec_command('hostnamectl')
for line in stdout:
    print(line.strip('\n'))
# Out:
# NAME="Ubuntu"
# VERSION="18.04.3 LTS (Bionic Beaver)"
# ID=ubuntu
# ID_LIKE=debian
# PRETTY_NAME="Ubuntu 18.04.3 LTS"
# VERSION_ID="18.04"
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# VERSION_CODENAME=bionic
# UBUNTU_CODENAME=bionic
#    Static hostname: u1
#          Icon name: computer-vm
#            Chassis: vm
#         Machine ID: ca6dfc4eb469493fa214dcef38a759f5
#            Boot ID: 1f0e0f02265545a7b98d01fcb71f4e60
#     Virtualization: oracle
#   Operating System: Ubuntu 18.04.3 LTS
#             Kernel: Linux 5.0.0-23-generic
#       Architecture: x86-64

# %%
import re 

def remove_quotes_from_line(line):
    return re.sub(r'[\"]', '', line)


def is_line_splitable(line, regex=r'[\=]'):
    return re.search(regex, line)


def split_line_to_tuple(line, by='='):
    items = line.split(by)
    return re.sub(' ', '_', items[0]).strip().lower(), items[-1].strip()


def parse_cat_os_release_stdout(stdout):
    return dict(split_line_to_tuple(remove_quotes_from_line(line.strip('\n')), '=') for line in stdout if is_line_splitable(line))


def parse_hostnamectl_stdout(stdout):
    return dict(split_line_to_tuple(remove_quotes_from_line(line.strip()), ':') for line in stdout if is_line_splitable(line, r'[\:]'))

# %%
stdin, stdout, stderr = client.exec_command('cat /etc/os-release')

parse_cat_os_release_stdout(stdout)
# Out:
# {'name': 'Ubuntu',
#  'version': '18.04.3 LTS (Bionic Beaver)',
#  'id': 'ubuntu',
#  'id_like': 'debian',
#  'pretty_name': 'Ubuntu 18.04.3 LTS',
#  'version_id': '18.04',
#  'home_url': 'https://www.ubuntu.com/',
#  'support_url': 'https://help.ubuntu.com/',
#  'bug_report_url': 'https://bugs.launchpad.net/ubuntu/',
#  'privacy_policy_url': 'https://www.ubuntu.com/legal/terms-and-policies/privacy-policy',
#  'version_codename': 'bionic',
#  'ubuntu_codename': 'bionic'}

# %%
stdin, stdout, stderr = client.exec_command('hostnamectl')
    
parse_hostnamectl_stdout(stdout)
# Out:
# {'static_hostname': 'u1',
#  'icon_name': 'computer-vm',
#  'chassis': 'vm',
#  'machine_id': 'ca6dfc4eb469493fa214dcef38a759f5',
#  'boot_id': '1f0e0f02265545a7b98d01fcb71f4e60',
#  'virtualization': 'oracle',
#  'operating_system': 'Ubuntu 18.04.3 LTS',
#  'kernel': 'Linux 5.0.0-23-generic',
#  'architecture': 'x86-64'}

# %%
stdin, stdout, stderr = client.exec_command('lscpu')
for line in stdout:
    print(line.strip('\n'))
# Out:
# Architecture:        x86_64
# CPU op-mode(s):      32-bit, 64-bit
# Byte Order:          Little Endian
# CPU(s):              1
# On-line CPU(s) list: 0
# Thread(s) per core:  1
# Core(s) per socket:  1
# Socket(s):           1
# NUMA node(s):        1
# Vendor ID:           GenuineIntel
# CPU family:          6
# Model:               158
# Model name:          Intel(R) Core(TM) i7-8700K CPU @ 3.70GHz
# Stepping:            10
# CPU MHz:             3695.976
# BogoMIPS:            7391.95
# Hypervisor vendor:   KVM
# Virtualization type: full
# L1d cache:           32K
# L1i cache:           32K
# L2 cache:            256K
# L3 cache:            12288K
# NUMA node0 CPU(s):   0
# Flags:               fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 syscall nx rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq monitor ssse3 cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single pti fsgsbase avx2 invpcid rdseed clflushopt md_clear flush_l1d

# %%
def parse_lscpu_stdout(stdout):
    return [dict(split_line_to_tuple(remove_quotes_from_line(line), ':') for line in stdout if is_line_splitable(line, r'[\:]'))]

# %%
stdin, stdout, stderr = client.exec_command('lscpu')

parse_lscpu_stdout(stdout)
# Out:
# [{'architecture': 'x86_64',
#   'cpu_op-mode(s)': '32-bit, 64-bit',
#   'byte_order': 'Little Endian',
#   'cpu(s)': '1',
#   'on-line_cpu(s)_list': '0',
#   'thread(s)_per_core': '1',
#   'core(s)_per_socket': '1',
#   'socket(s)': '1',
#   'numa_node(s)': '1',
#   'vendor_id': 'GenuineIntel',
#   'cpu_family': '6',
#   'model': '158',
#   'model_name': 'Intel(R) Core(TM) i7-8700K CPU @ 3.70GHz',
#   'stepping': '10',
#   'cpu_mhz': '3695.976',
#   'bogomips': '7391.95',
#   'hypervisor_vendor': 'KVM',
#   'virtualization_type': 'full',
#   'l1d_cache': '32K',
#   'l1i_cache': '32K',
#   'l2_cache': '256K',
#   'l3_cache': '12288K',
#   'numa_node0_cpu(s)': '0',
#   'flags': 'fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 syscall nx rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq monitor ssse3 cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single pti fsgsbase avx2 invpcid rdseed clflushopt md_clear flush_l1d'}]

# %%
stdin, stdout, stderr = client.exec_command('lshw -C display -json')

for line in stdout:
    print(line.strip('\n'))
# Out:
#                                         {
#     "id" : "display",
#     "class" : "display",
#     "claimed" : true,
#     "handle" : "PCI:0000:00:02.0",
#     "description" : "VGA compatible controller",
#     "product" : "VirtualBox Graphics Adapter",
#     "vendor" : "InnoTek Systemberatung GmbH",
#     "physid" : "2",
#     "businfo" : "pci@0000:00:02.0",
#     "version" : "00",
#     "width" : 32,
#     "clock" : 33000000,
#     "configuration" : {
#       "driver" : "vboxvideo",
#       "latency" : "0"
#     },
#     "capabilities" : {
#       "vga_controller" : true,
#       "rom" : "extension ROM"
#     }
#   },

# %%
import json 

def parse_lshw_stdout(stdout):
    json_stdout = ''
    for line in stdout:
        json_stdout += line.strip('\n')
    json_stdout = '[' + json_stdout.strip(",[ \t\r\n]+") + ']'
    return json.loads(json_stdout)

# %%
stdin, stdout, stderr = client.exec_command('lshw -C display -json')
parse_lshw_stdout(stdout)
# Out:
# [{'id': 'display',
#   'class': 'display',
#   'claimed': True,
#   'handle': 'PCI:0000:00:02.0',
#   'description': 'VGA compatible controller',
#   'product': 'VirtualBox Graphics Adapter',
#   'vendor': 'InnoTek Systemberatung GmbH',
#   'physid': '2',
#   'businfo': 'pci@0000:00:02.0',
#   'version': '00',
#   'width': 32,
#   'clock': 33000000,
#   'configuration': {'driver': 'vboxvideo', 'latency': '0'},
#   'capabilities': {'vga_controller': True, 'rom': 'extension ROM'}}]

# %%
from collections import namedtuple


CMDHandler = namedtuple('CMDHandler', ['cmd', 'handle'])


class LinuxSystemInfoCrawler(SystemInfoCrawler):
    
    __operating_system_cmd_handlers = (
        CMDHandler('cat /etc/os-release', parse_cat_os_release_stdout),
        CMDHandler('hostnamectl', parse_hostnamectl_stdout)
    )
    
    __cpu_cmd_handlers = (
        CMDHandler('lscpu', parse_lscpu_stdout),
    )

    __gpu_cmd_handlers = (
        CMDHandler('lshw -C display -json', parse_lshw_stdout),
    )
    
    def __init__(self, ssh_client):
        self.__ssh_client = ssh_client

    def get_operating_system(self):
        return self.__gather_operating_system_info()
    
    def get_cpu(self):
        return self.__gather_cpu_info()

    
    def get_gpu(self):
        return self.__gather_gpu_info()
    
    def get_deamon_services(self):
        return []
    
    def get_software(self):
        return []
    
    def __gather_operating_system_info(self):
        os_info = {}
        for cmd_handler in self.__operating_system_cmd_handlers:
            os_info.update(self._read_remote_system_info(cmd_handler))
        return os_info
    
    def __gather_cpu_info(self):
        cpu_info = []
        for cmd_handler in self.__cpu_cmd_handlers:
            cpu_info += self._read_remote_system_info(cmd_handler)
        return cpu_info
    
    def __gather_gpu_info(self):
        gpu_info = []
        for cmd_handler in self.__gpu_cmd_handlers:
            gpu_info +=  self._read_remote_system_info(cmd_handler)
        return gpu_info
    
    def _read_remote_system_info(self, cmd_handler):
        self.__ssh_client.connect()
        
        _, stdout, _ = self.__ssh_client.exec_command(cmd_handler.cmd)
        system_info = cmd_handler.handle(stdout)
        
        self.__ssh_client.close()
        
        return system_info

# %%
crawler = LinuxSystemInfoCrawler(client)

# %%
crawler.get_operating_system()
# Out:
# {'name': 'Ubuntu',
#  'version': '18.04.3 LTS (Bionic Beaver)',
#  'id': 'ubuntu',
#  'id_like': 'debian',
#  'pretty_name': 'Ubuntu 18.04.3 LTS',
#  'version_id': '18.04',
#  'home_url': 'https://www.ubuntu.com/',
#  'support_url': 'https://help.ubuntu.com/',
#  'bug_report_url': 'https://bugs.launchpad.net/ubuntu/',
#  'privacy_policy_url': 'https://www.ubuntu.com/legal/terms-and-policies/privacy-policy',
#  'version_codename': 'bionic',
#  'ubuntu_codename': 'bionic',
#  'static_hostname': 'u1',
#  'icon_name': 'computer-vm',
#  'chassis': 'vm',
#  'machine_id': 'ca6dfc4eb469493fa214dcef38a759f5',
#  'boot_id': '1f0e0f02265545a7b98d01fcb71f4e60',
#  'virtualization': 'oracle',
#  'operating_system': 'Ubuntu 18.04.3 LTS',
#  'kernel': 'Linux 5.0.0-23-generic',
#  'architecture': 'x86-64'}

# %%
crawler.get_cpu()
# Out:
# [{'architecture': 'x86_64',
#   'cpu_op-mode(s)': '32-bit, 64-bit',
#   'byte_order': 'Little Endian',
#   'cpu(s)': '1',
#   'on-line_cpu(s)_list': '0',
#   'thread(s)_per_core': '1',
#   'core(s)_per_socket': '1',
#   'socket(s)': '1',
#   'numa_node(s)': '1',
#   'vendor_id': 'GenuineIntel',
#   'cpu_family': '6',
#   'model': '158',
#   'model_name': 'Intel(R) Core(TM) i7-8700K CPU @ 3.70GHz',
#   'stepping': '10',
#   'cpu_mhz': '3695.976',
#   'bogomips': '7391.95',
#   'hypervisor_vendor': 'KVM',
#   'virtualization_type': 'full',
#   'l1d_cache': '32K',
#   'l1i_cache': '32K',
#   'l2_cache': '256K',
#   'l3_cache': '12288K',
#   'numa_node0_cpu(s)': '0',
#   'flags': 'fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 syscall nx rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq monitor ssse3 cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single pti fsgsbase avx2 invpcid rdseed clflushopt md_clear flush_l1d'}]

# %%
crawler.get_gpu()
# Out:
# [{'id': 'display',
#   'class': 'display',
#   'claimed': True,
#   'handle': 'PCI:0000:00:02.0',
#   'description': 'VGA compatible controller',
#   'product': 'VirtualBox Graphics Adapter',
#   'vendor': 'InnoTek Systemberatung GmbH',
#   'physid': '2',
#   'businfo': 'pci@0000:00:02.0',
#   'version': '00',
#   'width': 32,
#   'clock': 33000000,
#   'configuration': {'driver': 'vboxvideo', 'latency': '0'},
#   'capabilities': {'vga_controller': True, 'rom': 'extension ROM'}}]

# %%
def split_line_to_dict(line, by=';'):
    items = line.strip('\n').split(by)
    return {'name': items[0], 'version': items[-1]}

def parse_dpkg_query_stdout(stdout):
    return [split_line_to_dict(line) for line in stdout if is_line_splitable(line, r'[\;]')]

# %%
client.connect()
stdin, stdout, stderr = client.exec_command("dpkg-query -f '${binary:Package};${Version}\n' -W")

parse_dpkg_query_stdout(stdout)
# Out:
# [{'name': 'accountsservice', 'version': '0.6.45-1ubuntu1'},
#  {'name': 'acl', 'version': '2.2.52-3build1'},
#  {'name': 'acpi-support', 'version': '0.142'},
#  {'name': 'acpid', 'version': '1:2.0.28-1ubuntu1'},
#  {'name': 'adduser', 'version': '3.116ubuntu1'},
#  {'name': 'adium-theme-ubuntu', 'version': '0.3.4-0ubuntu4'},
#  {'name': 'adwaita-icon-theme', 'version': '3.28.0-1ubuntu1'},
#  {'name': 'aisleriot', 'version': '1:3.22.5-1'},
#  {'name': 'alsa-base', 'version': '1.0.25+dfsg-0ubuntu5'},
#  {'name': 'alsa-utils', 'version': '1.1.3-1ubuntu1'},
#  {'name': 'amd64-microcode', 'version': '3.20180524.1~ubuntu0.18.04.2'},
#  {'name': 'anacron', 'version': '2.3-24'},
#  {'name': 'apg', 'version': '2.2.3.dfsg.1-5'},
#  {'name': 'app-install-data-partner', 'version': '16.04'},
#  {'name': 'apparmor', 'version': '2.12-4ubuntu5.1'},
#  {'name': 'apport', 'version': '2.20.9-0ubuntu7.7'},
#  {'name': 'apport-gtk', 'version': '2.20.9-0ubuntu7.7'},
#  {'name': 'apport-symptoms', 'version': '0.20'},
#  {'name': 'appstream', 'version': '0.12.0-3ubuntu1'},
#  {'name': 'apt', 'version': '1.6.11'},
#  {'name': 'apt-config-icons', 'version': '0.12.0-3ubuntu1'},
#  {'name': 'apt-utils', 'version': '1.6.11'},
#  {'name': 'aptdaemon', 'version': '1.1.1+bzr982-0ubuntu19.1'},
#  {'name': 'aptdaemon-data', 'version': '1.1.1+bzr982-0ubuntu19.1'},
#  {'name': 'apturl', 'version': '0.5.2ubuntu14.2'},
#  {'name': 'apturl-common', 'version': '0.5.2ubuntu14.2'},
#  {'name': 'aspell', 'version': '0.60.7~20110707-4'},
#  {'name': 'aspell-en', 'version': '2017.08.24-0-0.1'},
#  {'name': 'at-spi2-core', 'version': '2.28.0-1'},
#  {'name': 'avahi-autoipd', 'version': '0.7-3.1ubuntu1.2'},
#  {'name': 'avahi-daemon', 'version': '0.7-3.1ubuntu1.2'},
#  {'name': 'avahi-utils', 'version': '0.7-3.1ubuntu1.2'},
#  {'name': 'baobab', 'version': '3.28.0-1'},
#  {'name': 'base-files', 'version': '10.1ubuntu2.6'},
#  {'name': 'base-passwd', 'version': '3.5.44'},
#  {'name': 'bash', 'version': '4.4.18-2ubuntu1.2'},
#  {'name': 'bash-completion', 'version': '1:2.8-1ubuntu1'},
#  {'name': 'bc', 'version': '1.07.1-2'},
#  {'name': 'bind9-host', 'version': '1:9.11.3+dfsg-1ubuntu1.8'},
#  {'name': 'binutils', 'version': '2.30-21ubuntu1~18.04.2'},
#  {'name': 'binutils-common:amd64', 'version': '2.30-21ubuntu1~18.04.2'},
#  {'name': 'binutils-x86-64-linux-gnu', 'version': '2.30-21ubuntu1~18.04.2'},
#  {'name': 'bluez', 'version': '5.48-0ubuntu3.1'},
#  {'name': 'bluez-cups', 'version': '5.48-0ubuntu3.1'},
#  {'name': 'bluez-obexd', 'version': '5.48-0ubuntu3.1'},
#  {'name': 'bolt', 'version': '0.5-0ubuntu0.18.04.1'},
#  {'name': 'branding-ubuntu', 'version': '0.10'},
#  {'name': 'brltty', 'version': '5.5-4ubuntu2.0.1'},
#  {'name': 'bsdmainutils', 'version': '11.1.2ubuntu1'},
#  {'name': 'bsdutils', 'version': '1:2.31.1-0.4ubuntu3.3'},
#  {'name': 'bubblewrap', 'version': '0.2.1-1ubuntu0.1'},
#  {'name': 'busybox-initramfs', 'version': '1:1.27.2-2ubuntu3.2'},
#  {'name': 'busybox-static', 'version': '1:1.27.2-2ubuntu3.2'},
#  {'name': 'bzip2', 'version': '1.0.6-8.1ubuntu0.2'},
#  {'name': 'ca-certificates', 'version': '20180409'},
#  {'name': 'cheese', 'version': '3.28.0-1ubuntu1'},
#  {'name': 'cheese-common', 'version': '3.28.0-1ubuntu1'},
#  {'name': 'colord', 'version': '1.3.3-2build1'},
#  {'name': 'colord-data', 'version': '1.3.3-2build1'},
#  {'name': 'command-not-found', 'version': '18.04.5'},
#  {'name': 'command-not-found-data', 'version': '18.04.5'},
#  {'name': 'console-setup', 'version': '1.178ubuntu2.9'},
#  {'name': 'console-setup-linux', 'version': '1.178ubuntu2.9'},
#  {'name': 'coreutils', 'version': '8.28-1ubuntu1'},
#  {'name': 'cpio', 'version': '2.12+dfsg-6'},
#  {'name': 'cpp', 'version': '4:7.4.0-1ubuntu2.3'},
#  {'name': 'cpp-7', 'version': '7.4.0-1ubuntu1~18.04.1'},
#  {'name': 'cracklib-runtime', 'version': '2.9.2-5build1'},
#  {'name': 'crda', 'version': '3.18-1build1'},
#  {'name': 'cron', 'version': '3.0pl1-128.1ubuntu1'},
#  {'name': 'cups', 'version': '2.2.7-1ubuntu2.7'},
#  {'name': 'cups-browsed', 'version': '1.20.2-0ubuntu3.1'},
#  {'name': 'cups-bsd', 'version': '2.2.7-1ubuntu2.7'},
#  {'name': 'cups-client', 'version': '2.2.7-1ubuntu2.7'},
#  {'name': 'cups-common', 'version': '2.2.7-1ubuntu2.7'},
#  {'name': 'cups-core-drivers', 'version': '2.2.7-1ubuntu2.7'},
#  {'name': 'cups-daemon', 'version': '2.2.7-1ubuntu2.7'},
#  {'name': 'cups-filters', 'version': '1.20.2-0ubuntu3.1'},
#  {'name': 'cups-filters-core-drivers', 'version': '1.20.2-0ubuntu3.1'},
#  {'name': 'cups-ipp-utils', 'version': '2.2.7-1ubuntu2.7'},
#  {'name': 'cups-pk-helper', 'version': '0.2.6-1ubuntu1.2'},
#  {'name': 'cups-ppdc', 'version': '2.2.7-1ubuntu2.7'},
#  {'name': 'cups-server-common', 'version': '2.2.7-1ubuntu2.7'},
#  {'name': 'dash', 'version': '0.5.8-2.10'},
#  {'name': 'dbus', 'version': '1.12.2-1ubuntu1.1'},
#  {'name': 'dbus-user-session', 'version': '1.12.2-1ubuntu1.1'},
#  {'name': 'dbus-x11', 'version': '1.12.2-1ubuntu1.1'},
#  {'name': 'dc', 'version': '1.07.1-2'},
#  {'name': 'dconf-cli', 'version': '0.26.0-2ubuntu3'},
#  {'name': 'dconf-gsettings-backend:amd64', 'version': '0.26.0-2ubuntu3'},
#  {'name': 'dconf-service', 'version': '0.26.0-2ubuntu3'},
#  {'name': 'debconf', 'version': '1.5.66ubuntu1'},
#  {'name': 'debconf-i18n', 'version': '1.5.66ubuntu1'},
#  {'name': 'debianutils', 'version': '4.8.4'},
#  {'name': 'deja-dup', 'version': '37.1-2fakesync1ubuntu0.1'},
#  {'name': 'desktop-file-utils', 'version': '0.23-1ubuntu3.18.04.2'},
#  {'name': 'dictionaries-common', 'version': '1.27.2'},
#  {'name': 'diffstat', 'version': '1.61-1build1'},
#  {'name': 'diffutils', 'version': '1:3.6-1'},
#  {'name': 'dirmngr', 'version': '2.2.4-1ubuntu1.2'},
#  {'name': 'distro-info-data', 'version': '0.37ubuntu0.5'},
#  {'name': 'dmidecode', 'version': '3.1-1'},
#  {'name': 'dmsetup', 'version': '2:1.02.145-4.1ubuntu3.18.04.1'},
#  {'name': 'dmz-cursor-theme', 'version': '0.4.5ubuntu1'},
#  {'name': 'dns-root-data', 'version': '2018013001'},
#  {'name': 'dnsmasq-base', 'version': '2.79-1'},
#  {'name': 'dnsutils', 'version': '1:9.11.3+dfsg-1ubuntu1.8'},
#  {'name': 'dosfstools', 'version': '4.1-1'},
#  {'name': 'dpkg', 'version': '1.19.0.5ubuntu2.1'},
#  {'name': 'e2fsprogs', 'version': '1.44.1-1ubuntu1.1'},
#  {'name': 'ed', 'version': '1.10-2.1'},
#  {'name': 'efibootmgr', 'version': '15-1'},
#  {'name': 'eject', 'version': '2.1.5+deb1+cvs20081104-13.2'},
#  {'name': 'emacsen-common', 'version': '2.0.8'},
#  {'name': 'enchant', 'version': '1.6.0-11.1'},
#  {'name': 'eog', 'version': '3.28.1-1'},
#  {'name': 'espeak-ng-data:amd64', 'version': '1.49.2+dfsg-1'},
#  {'name': 'evince', 'version': '3.28.4-0ubuntu1.2'},
#  {'name': 'evince-common', 'version': '3.28.4-0ubuntu1.2'},
#  {'name': 'evolution-data-server', 'version': '3.28.5-0ubuntu0.18.04.2'},
#  {'name': 'evolution-data-server-common',
#   'version': '3.28.5-0ubuntu0.18.04.2'},
#  {'name': 'example-content', 'version': '50'},
#  {'name': 'fdisk', 'version': '2.31.1-0.4ubuntu3.3'},
#  {'name': 'file', 'version': '1:5.32-2ubuntu0.2'},
#  {'name': 'file-roller', 'version': '3.28.0-1ubuntu1'},
#  {'name': 'findutils', 'version': '4.6.0+git+20170828-2'},
#  {'name': 'firefox', 'version': '69.0+build2-0ubuntu0.18.04.1'},
#  {'name': 'firefox-locale-en', 'version': '69.0+build2-0ubuntu0.18.04.1'},
#  {'name': 'fontconfig', 'version': '2.12.6-0ubuntu2'},
#  {'name': 'fontconfig-config', 'version': '2.12.6-0ubuntu2'},
#  {'name': 'fonts-beng', 'version': '2:1.2'},
#  {'name': 'fonts-beng-extra', 'version': '1.0-6ubuntu0.1'},
#  {'name': 'fonts-dejavu-core', 'version': '2.37-1'},
#  {'name': 'fonts-deva', 'version': '2:1.2'},
#  {'name': 'fonts-deva-extra', 'version': '3.0-4ubuntu0.1'},
#  {'name': 'fonts-droid-fallback', 'version': '1:6.0.1r16-1.1'},
#  {'name': 'fonts-freefont-ttf', 'version': '20120503-7'},
#  {'name': 'fonts-gargi', 'version': '2.0-4'},
#  {'name': 'fonts-gubbi', 'version': '1.3-3'},
#  {'name': 'fonts-gujr', 'version': '2:1.2'},
#  {'name': 'fonts-gujr-extra', 'version': '1.0-6ubuntu0.1'},
#  {'name': 'fonts-guru', 'version': '2:1.2'},
#  {'name': 'fonts-guru-extra', 'version': '2.0-4ubuntu0.1'},
#  {'name': 'fonts-indic', 'version': '2:1.2'},
#  {'name': 'fonts-kacst', 'version': '2.01+mry-14'},
#  {'name': 'fonts-kacst-one', 'version': '5.0+svn11846-9'},
#  {'name': 'fonts-kalapi', 'version': '1.0-2'},
#  {'name': 'fonts-khmeros-core', 'version': '5.0-7ubuntu1'},
#  {'name': 'fonts-knda', 'version': '2:1.2'},
#  {'name': 'fonts-lao', 'version': '0.0.20060226-9ubuntu1'},
#  {'name': 'fonts-liberation', 'version': '1:1.07.4-7~18.04.1'},
#  {'name': 'fonts-liberation2', 'version': '2.00.1-7~18.04.2'},
#  {'name': 'fonts-lklug-sinhala', 'version': '0.6-3'},
#  {'name': 'fonts-lohit-beng-assamese', 'version': '2.91.5-1'},
#  {'name': 'fonts-lohit-beng-bengali', 'version': '2.91.5-1'},
#  {'name': 'fonts-lohit-deva', 'version': '2.95.4-2'},
#  {'name': 'fonts-lohit-gujr', 'version': '2.92.4-2'},
#  {'name': 'fonts-lohit-guru', 'version': '2.91.2-1'},
#  {'name': 'fonts-lohit-knda', 'version': '2.5.4-1'},
#  {'name': 'fonts-lohit-mlym', 'version': '2.92.2-1'},
#  {'name': 'fonts-lohit-orya', 'version': '2.91.2-1'},
#  {'name': 'fonts-lohit-taml', 'version': '2.91.3-1'},
#  {'name': 'fonts-lohit-taml-classical', 'version': '2.5.4-1'},
#  {'name': 'fonts-lohit-telu', 'version': '2.5.5-1'},
#  {'name': 'fonts-mlym', 'version': '2:1.2'},
#  {'name': 'fonts-nakula', 'version': '1.0-3'},
#  {'name': 'fonts-navilu', 'version': '1.2-2'},
#  {'name': 'fonts-noto-cjk', 'version': '1:20190409+repack1-0ubuntu0.18.04'},
#  {'name': 'fonts-noto-color-emoji', 'version': '0~20180810-0ubuntu1'},
#  {'name': 'fonts-noto-mono', 'version': '20171026-2'},
#  {'name': 'fonts-opensymbol',
#   'version': '2:102.10+LibO6.0.7-0ubuntu0.18.04.9'},
#  {'name': 'fonts-orya', 'version': '2:1.2'},
#  {'name': 'fonts-orya-extra', 'version': '2.0-5ubuntu0.1'},
#  {'name': 'fonts-pagul', 'version': '1.0-7'},
#  {'name': 'fonts-sahadeva', 'version': '1.0-4'},
#  {'name': 'fonts-samyak-deva', 'version': '1.2.2-4'},
#  {'name': 'fonts-samyak-gujr', 'version': '1.2.2-4'},
#  {'name': 'fonts-samyak-mlym', 'version': '1.2.2-4'},
#  {'name': 'fonts-samyak-taml', 'version': '1.2.2-4'},
#  {'name': 'fonts-sarai', 'version': '1.0-2'},
#  {'name': 'fonts-sil-abyssinica', 'version': '1.500-1'},
#  {'name': 'fonts-sil-padauk', 'version': '3.003-1'},
#  {'name': 'fonts-smc', 'version': '1:7.0'},
#  {'name': 'fonts-smc-anjalioldlipi', 'version': '7.0-2'},
#  {'name': 'fonts-smc-chilanka', 'version': '1.2.0-2'},
#  {'name': 'fonts-smc-dyuthi', 'version': '2.0-1'},
#  {'name': 'fonts-smc-karumbi', 'version': '1.0-1'},
#  {'name': 'fonts-smc-keraleeyam', 'version': '2.0-1'},
#  {'name': 'fonts-smc-manjari', 'version': '1.5.1-1'},
#  {'name': 'fonts-smc-meera', 'version': '7.0-2'},
#  {'name': 'fonts-smc-rachana', 'version': '7.0-2'},
#  {'name': 'fonts-smc-raghumalayalamsans', 'version': '2.1.1-2'},
#  {'name': 'fonts-smc-suruma', 'version': '3.2.1-1'},
#  {'name': 'fonts-smc-uroob', 'version': '2.0-1'},
#  {'name': 'fonts-taml', 'version': '2:1.3'},
#  {'name': 'fonts-telu', 'version': '2:1.2'},
#  {'name': 'fonts-telu-extra', 'version': '2.0-4'},
#  {'name': 'fonts-thai-tlwg', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tibetan-machine', 'version': '1.901b-5'},
#  {'name': 'fonts-tlwg-garuda', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-garuda-ttf', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-kinnari', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-kinnari-ttf', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-laksaman', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-laksaman-ttf', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-loma', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-loma-ttf', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-mono', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-mono-ttf', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-norasi', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-norasi-ttf', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-purisa', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-purisa-ttf', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-sawasdee', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-sawasdee-ttf', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-typewriter', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-typewriter-ttf', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-typist', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-typist-ttf', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-typo', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-typo-ttf', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-umpush', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-umpush-ttf', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-waree', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-waree-ttf', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-ubuntu', 'version': '0.83-2'},
#  {'name': 'foomatic-db-compressed-ppds', 'version': '20180306-1'},
#  {'name': 'friendly-recovery', 'version': '0.2.38ubuntu1.1'},
#  {'name': 'ftp', 'version': '0.17-34'},
#  {'name': 'fuse', 'version': '2.9.7-1ubuntu1'},
#  {'name': 'fwupd', 'version': '1.0.9-0ubuntu2'},
#  {'name': 'fwupdate', 'version': '12-3bionic2'},
#  {'name': 'fwupdate-signed', 'version': '1.19bionic2+12-3bionic2'},
#  {'name': 'gcc-7-base:amd64', 'version': '7.4.0-1ubuntu1~18.04.1'},
#  {'name': 'gcc-8-base:amd64', 'version': '8.3.0-6ubuntu1~18.04.1'},
#  {'name': 'gcr', 'version': '3.28.0-1'},
#  {'name': 'gdb', 'version': '8.1-0ubuntu3'},
#  {'name': 'gdbserver', 'version': '8.1-0ubuntu3'},
#  {'name': 'gdisk', 'version': '1.0.3-1'},
#  {'name': 'gdm3', 'version': '3.28.3-0ubuntu18.04.4'},
#  {'name': 'gedit', 'version': '3.28.1-1ubuntu1.2'},
#  {'name': 'gedit-common', 'version': '3.28.1-1ubuntu1.2'},
#  {'name': 'genisoimage', 'version': '9:1.1.11-3ubuntu2'},
#  {'name': 'geoclue-2.0', 'version': '2.4.7-1ubuntu1'},
#  {'name': 'geoip-database', 'version': '20180315-1'},
#  {'name': 'gettext', 'version': '0.19.8.1-6ubuntu0.3'},
#  {'name': 'gettext-base', 'version': '0.19.8.1-6ubuntu0.3'},
#  {'name': 'ghostscript', 'version': '9.26~dfsg+0-0ubuntu0.18.04.11'},
#  {'name': 'ghostscript-x', 'version': '9.26~dfsg+0-0ubuntu0.18.04.11'},
#  {'name': 'gir1.2-accountsservice-1.0', 'version': '0.6.45-1ubuntu1'},
#  {'name': 'gir1.2-atk-1.0:amd64', 'version': '2.28.1-1'},
#  {'name': 'gir1.2-atspi-2.0:amd64', 'version': '2.28.0-1'},
#  {'name': 'gir1.2-dbusmenu-glib-0.4:amd64',
#   'version': '16.04.1+18.04.20171206-0ubuntu2'},
#  {'name': 'gir1.2-dee-1.0', 'version': '1.2.7+17.10.20170616-0ubuntu4'},
#  {'name': 'gir1.2-freedesktop:amd64', 'version': '1.56.1-1'},
#  {'name': 'gir1.2-gck-1:amd64', 'version': '3.28.0-1'},
#  {'name': 'gir1.2-gcr-3:amd64', 'version': '3.28.0-1'},
#  {'name': 'gir1.2-gdesktopenums-3.0:amd64', 'version': '3.28.0-1ubuntu1'},
#  {'name': 'gir1.2-gdkpixbuf-2.0:amd64', 'version': '2.36.11-2'},
#  {'name': 'gir1.2-gdm-1.0', 'version': '3.28.3-0ubuntu18.04.4'},
#  {'name': 'gir1.2-geoclue-2.0:amd64', 'version': '2.4.7-1ubuntu1'},
#  {'name': 'gir1.2-geocodeglib-1.0:amd64',
#   'version': '3.25.4.1-4ubuntu0.18.04.1'},
#  {'name': 'gir1.2-glib-2.0:amd64', 'version': '1.56.1-1'},
#  {'name': 'gir1.2-gmenu-3.0:amd64', 'version': '3.13.3-11ubuntu1.1'},
#  {'name': 'gir1.2-gnomebluetooth-1.0:amd64', 'version': '3.28.0-2ubuntu0.2'},
#  {'name': 'gir1.2-gnomedesktop-3.0:amd64', 'version': '3.28.2-0ubuntu1.5'},
#  {'name': 'gir1.2-goa-1.0:amd64', 'version': '3.28.0-0ubuntu2.1'},
#  {'name': 'gir1.2-gst-plugins-base-1.0:amd64',
#   'version': '1.14.5-0ubuntu1~18.04.1'},
#  {'name': 'gir1.2-gstreamer-1.0:amd64', 'version': '1.14.5-0ubuntu1~18.04.1'},
#  {'name': 'gir1.2-gtk-3.0:amd64', 'version': '3.22.30-1ubuntu4'},
#  {'name': 'gir1.2-gtksource-3.0:amd64', 'version': '3.24.7-1'},
#  {'name': 'gir1.2-gudev-1.0:amd64', 'version': '1:232-2'},
#  {'name': 'gir1.2-gweather-3.0:amd64', 'version': '3.28.2-1~ubuntu18.04.1'},
#  {'name': 'gir1.2-ibus-1.0:amd64', 'version': '1.5.17-3ubuntu4'},
#  {'name': 'gir1.2-javascriptcoregtk-4.0:amd64',
#   'version': '2.24.2-0ubuntu0.18.04.1'},
#  {'name': 'gir1.2-json-1.0:amd64', 'version': '1.4.2-3'},
#  {'name': 'gir1.2-mutter-2:amd64', 'version': '3.28.4-0ubuntu18.04.1'},
#  {'name': 'gir1.2-nm-1.0:amd64', 'version': '1.10.6-2ubuntu1.1'},
#  {'name': 'gir1.2-nma-1.0:amd64', 'version': '1.8.10-2ubuntu2'},
#  {'name': 'gir1.2-notify-0.7:amd64', 'version': '0.7.7-3'},
#  {'name': 'gir1.2-packagekitglib-1.0', 'version': '1.1.9-1ubuntu2.18.04.5'},
#  {'name': 'gir1.2-pango-1.0:amd64', 'version': '1.40.14-1ubuntu0.1'},
#  {'name': 'gir1.2-peas-1.0:amd64', 'version': '1.22.0-2'},
#  {'name': 'gir1.2-polkit-1.0', 'version': '0.105-20ubuntu0.18.04.5'},
#  {'name': 'gir1.2-rb-3.0:amd64', 'version': '3.4.2-4ubuntu1'},
#  {'name': 'gir1.2-rsvg-2.0:amd64', 'version': '2.40.20-2'},
#  {'name': 'gir1.2-secret-1:amd64', 'version': '0.18.6-1'},
#  {'name': 'gir1.2-snapd-1:amd64', 'version': '1.47-0ubuntu0.18.04.0'},
#  {'name': 'gir1.2-soup-2.4:amd64', 'version': '2.62.1-1ubuntu0.1'},
#  {'name': 'gir1.2-totem-1.0:amd64', 'version': '3.26.0-0ubuntu6.2'},
#  {'name': 'gir1.2-totemplparser-1.0:amd64', 'version': '3.26.0-1ubuntu2'},
#  {'name': 'gir1.2-udisks-2.0:amd64', 'version': '2.7.6-3ubuntu0.2'},
#  {'name': 'gir1.2-unity-5.0:amd64',
#   'version': '7.1.4+18.04.20180209.1-0ubuntu2'},
#  {'name': 'gir1.2-upowerglib-1.0:amd64', 'version': '0.99.7-2ubuntu0.18.04.1'},
#  {'name': 'gir1.2-vte-2.91:amd64', 'version': '0.52.2-1ubuntu1~18.04.2'},
#  {'name': 'gir1.2-webkit2-4.0:amd64', 'version': '2.24.2-0ubuntu0.18.04.1'},
#  {'name': 'gir1.2-wnck-3.0:amd64', 'version': '3.24.1-2'},
#  {'name': 'gjs', 'version': '1.52.5-0ubuntu18.04.1'},
#  {'name': 'gkbd-capplet', 'version': '3.26.0-3ubuntu0.18.04.1'},
#  {'name': 'glib-networking:amd64', 'version': '2.56.0-1'},
#  {'name': 'glib-networking-common', 'version': '2.56.0-1'},
#  {'name': 'glib-networking-services', 'version': '2.56.0-1'},
#  {'name': 'gnome-accessibility-themes', 'version': '3.28-1ubuntu1'},
#  {'name': 'gnome-bluetooth', 'version': '3.28.0-2ubuntu0.2'},
#  {'name': 'gnome-calendar', 'version': '3.28.2-0ubuntu0.18.04.1'},
#  {'name': 'gnome-control-center', 'version': '1:3.28.2-0ubuntu0.18.04.4'},
#  {'name': 'gnome-control-center-data', 'version': '1:3.28.2-0ubuntu0.18.04.4'},
#  {'name': 'gnome-control-center-faces',
#   'version': '1:3.28.2-0ubuntu0.18.04.4'},
#  {'name': 'gnome-desktop3-data', 'version': '3.28.2-0ubuntu1.5'},
#  {'name': 'gnome-disk-utility', 'version': '3.28.3-0ubuntu1~18.04.1'},
#  {'name': 'gnome-font-viewer', 'version': '3.28.0-1'},
#  {'name': 'gnome-getting-started-docs', 'version': '3.28.2-0ubuntu0.1'},
#  {'name': 'gnome-initial-setup', 'version': '3.28.0-2ubuntu6.16.04.4'},
#  {'name': 'gnome-keyring', 'version': '3.28.0.2-1ubuntu1.18.04.1'},
#  {'name': 'gnome-keyring-pkcs11:amd64',
#   'version': '3.28.0.2-1ubuntu1.18.04.1'},
#  {'name': 'gnome-mahjongg', 'version': '1:3.22.0-3'},
#  {'name': 'gnome-menus', 'version': '3.13.3-11ubuntu1.1'},
#  {'name': 'gnome-mines', 'version': '1:3.28.0-1ubuntu1'},
#  {'name': 'gnome-online-accounts', 'version': '3.28.0-0ubuntu2.1'},
#  {'name': 'gnome-power-manager', 'version': '3.26.0-1'},
#  {'name': 'gnome-screenshot', 'version': '3.25.0-0ubuntu2'},
#  {'name': 'gnome-session-bin', 'version': '3.28.1-0ubuntu3'},
#  {'name': 'gnome-session-canberra', 'version': '0.30-5ubuntu1'},
#  {'name': 'gnome-session-common', 'version': '3.28.1-0ubuntu3'},
#  {'name': 'gnome-settings-daemon', 'version': '3.28.1-0ubuntu1.3'},
#  {'name': 'gnome-settings-daemon-schemas', 'version': '3.28.1-0ubuntu1.3'},
#  {'name': 'gnome-shell', 'version': '3.28.4-0ubuntu18.04.1'},
#  {'name': 'gnome-shell-common', 'version': '3.28.4-0ubuntu18.04.1'},
#  {'name': 'gnome-shell-extension-appindicator', 'version': '18.04.1'},
#  {'name': 'gnome-shell-extension-ubuntu-dock',
#   'version': '0.9.1ubuntu18.04.3'},
#  {'name': 'gnome-software', 'version': '3.28.1-0ubuntu4.18.04.10'},
#  {'name': 'gnome-software-common', 'version': '3.28.1-0ubuntu4.18.04.10'},
#  {'name': 'gnome-software-plugin-snap', 'version': '3.28.1-0ubuntu4.18.04.10'},
#  {'name': 'gnome-startup-applications', 'version': '3.28.1-0ubuntu3'},
#  {'name': 'gnome-sudoku', 'version': '1:3.28.0-1'},
#  {'name': 'gnome-terminal', 'version': '3.28.2-1ubuntu1~18.04.1'},
#  {'name': 'gnome-terminal-data', 'version': '3.28.2-1ubuntu1~18.04.1'},
#  {'name': 'gnome-themes-extra:amd64', 'version': '3.28-1ubuntu1'},
#  {'name': 'gnome-themes-extra-data', 'version': '3.28-1ubuntu1'},
#  {'name': 'gnome-todo', 'version': '3.28.1-1'},
#  {'name': 'gnome-todo-common', 'version': '3.28.1-1'},
#  {'name': 'gnome-user-docs', 'version': '3.28.2+git20180715-0ubuntu0.1'},
#  {'name': 'gnome-user-guide', 'version': '3.28.2+git20180715-0ubuntu0.1'},
#  {'name': 'gnome-video-effects', 'version': '0.4.3-1ubuntu1'},
#  {'name': 'gnupg', 'version': '2.2.4-1ubuntu1.2'},
#  {'name': 'gnupg-l10n', 'version': '2.2.4-1ubuntu1.2'},
#  {'name': 'gnupg-utils', 'version': '2.2.4-1ubuntu1.2'},
#  {'name': 'gpg', 'version': '2.2.4-1ubuntu1.2'},
#  {'name': 'gpg-agent', 'version': '2.2.4-1ubuntu1.2'},
#  {'name': 'gpg-wks-client', 'version': '2.2.4-1ubuntu1.2'},
#  {'name': 'gpg-wks-server', 'version': '2.2.4-1ubuntu1.2'},
#  {'name': 'gpgconf', 'version': '2.2.4-1ubuntu1.2'},
#  {'name': 'gpgsm', 'version': '2.2.4-1ubuntu1.2'},
#  {'name': 'gpgv', 'version': '2.2.4-1ubuntu1.2'},
#  {'name': 'grep', 'version': '3.1-2'},
#  {'name': 'grilo-plugins-0.3-base:amd64', 'version': '0.3.5-1ubuntu1'},
#  {'name': 'groff-base', 'version': '1.22.3-10'},
#  {'name': 'grub-common', 'version': '2.02-2ubuntu8.13'},
#  {'name': 'grub-gfxpayload-lists', 'version': '0.7'},
#  {'name': 'grub-pc', 'version': '2.02-2ubuntu8.13'},
#  {'name': 'grub-pc-bin', 'version': '2.02-2ubuntu8.13'},
#  {'name': 'grub2-common', 'version': '2.02-2ubuntu8.13'},
#  {'name': 'gsettings-desktop-schemas', 'version': '3.28.0-1ubuntu1'},
#  {'name': 'gsettings-ubuntu-schemas',
#   'version': '0.0.7+17.10.20170922-0ubuntu1'},
#  {'name': 'gsfonts', 'version': '1:8.11+urwcyr1.0.7~pre44-4.4'},
#  {'name': 'gstreamer1.0-alsa:amd64', 'version': '1.14.5-0ubuntu1~18.04.1'},
#  {'name': 'gstreamer1.0-clutter-3.0:amd64', 'version': '3.0.26-1'},
#  {'name': 'gstreamer1.0-gl:amd64', 'version': '1.14.5-0ubuntu1~18.04.1'},
#  {'name': 'gstreamer1.0-gtk3:amd64', 'version': '1.14.5-0ubuntu1~18.04.1'},
#  {'name': 'gstreamer1.0-packagekit', 'version': '1.1.9-1ubuntu2.18.04.5'},
#  {'name': 'gstreamer1.0-plugins-base:amd64',
#   'version': '1.14.5-0ubuntu1~18.04.1'},
#  {'name': 'gstreamer1.0-plugins-base-apps',
#   'version': '1.14.5-0ubuntu1~18.04.1'},
#  {'name': 'gstreamer1.0-plugins-good:amd64',
#   'version': '1.14.5-0ubuntu1~18.04.1'},
#  {'name': 'gstreamer1.0-pulseaudio:amd64',
#   'version': '1.14.5-0ubuntu1~18.04.1'},
#  {'name': 'gstreamer1.0-tools', 'version': '1.14.5-0ubuntu1~18.04.1'},
#  {'name': 'gstreamer1.0-x:amd64', 'version': '1.14.5-0ubuntu1~18.04.1'},
#  {'name': 'gtk-update-icon-cache', 'version': '3.22.30-1ubuntu4'},
#  {'name': 'gtk2-engines-murrine:amd64', 'version': '0.98.2-2ubuntu1'},
#  {'name': 'gtk2-engines-pixbuf:amd64', 'version': '2.24.32-1ubuntu1'},
#  {'name': 'guile-2.0-libs:amd64', 'version': '2.0.13+1-5ubuntu0.1'},
#  {'name': 'gvfs:amd64', 'version': '1.36.1-0ubuntu1.3.3'},
#  {'name': 'gvfs-backends', 'version': '1.36.1-0ubuntu1.3.3'},
#  {'name': 'gvfs-bin', 'version': '1.36.1-0ubuntu1.3.3'},
#  {'name': 'gvfs-common', 'version': '1.36.1-0ubuntu1.3.3'},
#  {'name': 'gvfs-daemons', 'version': '1.36.1-0ubuntu1.3.3'},
#  {'name': 'gvfs-fuse', 'version': '1.36.1-0ubuntu1.3.3'},
#  {'name': 'gvfs-libs:amd64', 'version': '1.36.1-0ubuntu1.3.3'},
#  {'name': 'gzip', 'version': '1.6-5ubuntu1'},
#  {'name': 'hdparm', 'version': '9.54+ds-1'},
#  {'name': 'hicolor-icon-theme', 'version': '0.17-2'},
#  {'name': 'hostname', 'version': '3.20'},
#  {'name': 'hplip', 'version': '3.17.10+repack0-5'},
#  {'name': 'hplip-data', 'version': '3.17.10+repack0-5'},
#  {'name': 'humanity-icon-theme', 'version': '0.6.15'},
#  {'name': 'hunspell-en-us', 'version': '1:2017.08.24'},
#  {'name': 'hyphen-en-us', 'version': '2.8.8-5'},
#  {'name': 'ibus', 'version': '1.5.17-3ubuntu4'},
#  {'name': 'ibus-gtk:amd64', 'version': '1.5.17-3ubuntu4'},
#  {'name': 'ibus-gtk3:amd64', 'version': '1.5.17-3ubuntu4'},
#  {'name': 'ibus-table', 'version': '1.9.14-3'},
#  {'name': 'ifupdown', 'version': '0.8.17ubuntu1.1'},
#  {'name': 'iio-sensor-proxy', 'version': '2.4-2'},
#  {'name': 'im-config', 'version': '0.34-1ubuntu1.3'},
#  {'name': 'imagemagick', 'version': '8:6.9.7.4+dfsg-16ubuntu6.7'},
#  {'name': 'imagemagick-6-common', 'version': '8:6.9.7.4+dfsg-16ubuntu6.7'},
#  {'name': 'imagemagick-6.q16', 'version': '8:6.9.7.4+dfsg-16ubuntu6.7'},
#  {'name': 'info', 'version': '6.5.0.dfsg.1-2'},
#  {'name': 'init', 'version': '1.51'},
#  {'name': 'init-system-helpers', 'version': '1.51'},
#  {'name': 'initramfs-tools', 'version': '0.130ubuntu3.8'},
#  {'name': 'initramfs-tools-bin', 'version': '0.130ubuntu3.8'},
#  {'name': 'initramfs-tools-core', 'version': '0.130ubuntu3.8'},
#  {'name': 'inputattach', 'version': '1:1.6.0-2'},
#  {'name': 'install-info', 'version': '6.5.0.dfsg.1-2'},
#  {'name': 'intel-microcode', 'version': '3.20190618.0ubuntu0.18.04.1'},
#  {'name': 'intltool-debian', 'version': '0.35.0+20060710.4'},
#  {'name': 'ippusbxd', 'version': '1.32-2'},
#  {'name': 'iproute2', 'version': '4.15.0-2ubuntu1'},
#  {'name': 'iptables', 'version': '1.6.1-2ubuntu2'},
#  {'name': 'iputils-arping', 'version': '3:20161105-1ubuntu3'},
#  {'name': 'iputils-ping', 'version': '3:20161105-1ubuntu3'},
#  {'name': 'iputils-tracepath', 'version': '3:20161105-1ubuntu3'},
#  {'name': 'irqbalance', 'version': '1.3.0-0.1ubuntu0.18.04.1'},
#  {'name': 'isc-dhcp-client', 'version': '4.3.5-3ubuntu7.1'},
#  {'name': 'isc-dhcp-common', 'version': '4.3.5-3ubuntu7.1'},
#  {'name': 'iso-codes', 'version': '3.79-1'},
#  {'name': 'iucode-tool', 'version': '2.3.1-1'},
#  {'name': 'iw', 'version': '4.14-0.1'},
#  {'name': 'kbd', 'version': '2.0.4-2ubuntu1'},
#  {'name': 'kerneloops', 'version': '0.12+git20140509-6ubuntu2'},
#  {'name': 'keyboard-configuration', 'version': '1.178ubuntu2.9'},
#  {'name': 'klibc-utils', 'version': '2.0.4-9ubuntu2'},
#  {'name': 'kmod', 'version': '24-1ubuntu3.2'},
#  {'name': 'krb5-locales', 'version': '1.16-2ubuntu0.1'},
#  {'name': 'language-pack-en', 'version': '1:18.04+20190718'},
#  {'name': 'language-pack-en-base', 'version': '1:18.04+20180712'},
#  {'name': 'language-pack-gnome-en', 'version': '1:18.04+20190718'},
#  {'name': 'language-pack-gnome-en-base', 'version': '1:18.04+20180712'},
#  {'name': 'language-selector-common', 'version': '0.188.3'},
#  {'name': 'language-selector-gnome', 'version': '0.188.3'},
#  {'name': 'laptop-detect', 'version': '0.16'},
#  {'name': 'less', 'version': '487-0.1'},
#  {'name': 'libaa1:amd64', 'version': '1.4p5-44build2'},
#  {'name': 'libabw-0.1-1:amd64', 'version': '0.1.2-1ubuntu1'},
#  {'name': 'libaccountsservice0:amd64', 'version': '0.6.45-1ubuntu1'},
#  {'name': 'libacl1:amd64', 'version': '2.2.52-3build1'},
#  {'name': 'libao-common', 'version': '1.2.2+20180113-1ubuntu1'},
#  {'name': 'libao4:amd64', 'version': '1.2.2+20180113-1ubuntu1'},
#  {'name': 'libapparmor1:amd64', 'version': '2.12-4ubuntu5.1'},
#  {'name': 'libappindicator3-1',
#   'version': '12.10.1+18.04.20180322.1-0ubuntu1'},
#  {'name': 'libappstream-glib8:amd64', 'version': '0.7.7-2'},
#  {'name': 'libappstream4:amd64', 'version': '0.12.0-3ubuntu1'},
#  {'name': 'libapt-inst2.0:amd64', 'version': '1.6.11'},
#  {'name': 'libapt-pkg-perl', 'version': '0.1.33build1'},
#  {'name': 'libapt-pkg5.0:amd64', 'version': '1.6.11'},
#  {'name': 'libarchive-zip-perl', 'version': '1.60-1ubuntu0.1'},
#  {'name': 'libarchive13:amd64', 'version': '3.2.2-3.1ubuntu0.3'},
#  {'name': 'libargon2-0:amd64', 'version': '0~20161029-1.1'},
#  {'name': 'libart-2.0-2:amd64', 'version': '2.3.21-3'},
#  {'name': 'libasn1-8-heimdal:amd64', 'version': '7.5.0+dfsg-1'},
#  {'name': 'libasound2:amd64', 'version': '1.1.3-5ubuntu0.2'},
#  {'name': 'libasound2-data', 'version': '1.1.3-5ubuntu0.2'},
#  {'name': 'libasound2-plugins:amd64', 'version': '1.1.1-1ubuntu1'},
#  {'name': 'libaspell15:amd64', 'version': '0.60.7~20110707-4'},
#  {'name': 'libassuan0:amd64', 'version': '2.5.1-2'},
#  {'name': 'libasyncns0:amd64', 'version': '0.8-6'},
#  {'name': 'libatasmart4:amd64', 'version': '0.19-4'},
#  {'name': 'libatk-adaptor:amd64', 'version': '2.26.2-1'},
#  {'name': 'libatk-bridge2.0-0:amd64', 'version': '2.26.2-1'},
#  {'name': 'libatk1.0-0:amd64', 'version': '2.28.1-1'},
#  {'name': 'libatk1.0-data', 'version': '2.28.1-1'},
#  {'name': 'libatm1:amd64', 'version': '1:2.5.1-2build1'},
#  {'name': 'libatspi2.0-0:amd64', 'version': '2.28.0-1'},
#  {'name': 'libattr1:amd64', 'version': '1:2.4.47-2build1'},
#  {'name': 'libaudio2:amd64', 'version': '1.9.4-6'},
#  {'name': 'libaudit-common', 'version': '1:2.8.2-1ubuntu1'},
#  {'name': 'libaudit1:amd64', 'version': '1:2.8.2-1ubuntu1'},
#  {'name': 'libauthen-sasl-perl', 'version': '2.1600-1'},
#  {'name': 'libavahi-client3:amd64', 'version': '0.7-3.1ubuntu1.2'},
#  {'name': 'libavahi-common-data:amd64', 'version': '0.7-3.1ubuntu1.2'},
#  {'name': 'libavahi-common3:amd64', 'version': '0.7-3.1ubuntu1.2'},
#  {'name': 'libavahi-core7:amd64', 'version': '0.7-3.1ubuntu1.2'},
#  {'name': 'libavahi-glib1:amd64', 'version': '0.7-3.1ubuntu1.2'},
#  {'name': 'libavahi-ui-gtk3-0:amd64', 'version': '0.7-3.1ubuntu1.2'},
#  {'name': 'libavc1394-0:amd64', 'version': '0.5.4-4build1'},
#  {'name': 'libbabeltrace1:amd64', 'version': '1.5.5-1'},
#  {'name': 'libbind9-160:amd64', 'version': '1:9.11.3+dfsg-1ubuntu1.8'},
#  {'name': 'libbinutils:amd64', 'version': '2.30-21ubuntu1~18.04.2'},
#  {'name': 'libblkid1:amd64', 'version': '2.31.1-0.4ubuntu3.3'},
#  {'name': 'libblockdev-crypto2:amd64', 'version': '2.16-2'},
#  {'name': 'libblockdev-fs2:amd64', 'version': '2.16-2'},
#  {'name': 'libblockdev-loop2:amd64', 'version': '2.16-2'},
#  {'name': 'libblockdev-part-err2:amd64', 'version': '2.16-2'},
#  {'name': 'libblockdev-part2:amd64', 'version': '2.16-2'},
#  {'name': 'libblockdev-swap2:amd64', 'version': '2.16-2'},
#  {'name': 'libblockdev-utils2:amd64', 'version': '2.16-2'},
#  {'name': 'libblockdev2:amd64', 'version': '2.16-2'},
#  {'name': 'libbluetooth3:amd64', 'version': '5.48-0ubuntu3.1'},
#  {'name': 'libboost-date-time1.65.1:amd64', 'version': '1.65.1+dfsg-0ubuntu5'},
#  {'name': 'libboost-filesystem1.65.1:amd64',
#   'version': '1.65.1+dfsg-0ubuntu5'},
#  {'name': 'libboost-iostreams1.65.1:amd64', 'version': '1.65.1+dfsg-0ubuntu5'},
#  {'name': 'libboost-locale1.65.1:amd64', 'version': '1.65.1+dfsg-0ubuntu5'},
#  {'name': 'libboost-system1.65.1:amd64', 'version': '1.65.1+dfsg-0ubuntu5'},
#  {'name': 'libboost-thread1.65.1:amd64', 'version': '1.65.1+dfsg-0ubuntu5'},
#  {'name': 'libbrlapi0.6:amd64', 'version': '5.5-4ubuntu2.0.1'},
#  {'name': 'libbrotli1:amd64', 'version': '1.0.3-1ubuntu1.2'},
#  {'name': 'libbsd0:amd64', 'version': '0.8.7-1'},
#  {'name': 'libbz2-1.0:amd64', 'version': '1.0.6-8.1ubuntu0.2'},
#  {'name': 'libc-bin', 'version': '2.27-3ubuntu1'},
#  {'name': 'libc6:amd64', 'version': '2.27-3ubuntu1'},
#  {'name': 'libc6-dbg:amd64', 'version': '2.27-3ubuntu1'},
#  {'name': 'libcaca0:amd64', 'version': '0.99.beta19-2ubuntu0.18.04.1'},
#  {'name': 'libcairo-gobject-perl', 'version': '1.004-2build3'},
#  {'name': 'libcairo-gobject2:amd64', 'version': '1.15.10-2ubuntu0.1'},
#  {'name': 'libcairo-perl', 'version': '1.106-2build2'},
#  {'name': 'libcairo2:amd64', 'version': '1.15.10-2ubuntu0.1'},
#  {'name': 'libcamel-1.2-61:amd64', 'version': '3.28.5-0ubuntu0.18.04.2'},
#  {'name': 'libcanberra-gtk3-0:amd64', 'version': '0.30-5ubuntu1'},
#  {'name': 'libcanberra-gtk3-module:amd64', 'version': '0.30-5ubuntu1'},
#  {'name': 'libcanberra-pulse:amd64', 'version': '0.30-5ubuntu1'},
#  {'name': 'libcanberra0:amd64', 'version': '0.30-5ubuntu1'},
#  {'name': 'libcap-ng0:amd64', 'version': '0.7.7-3.1'},
#  {'name': 'libcap2:amd64', 'version': '1:2.25-1.2'},
#  {'name': 'libcap2-bin', 'version': '1:2.25-1.2'},
#  {'name': 'libcc1-0:amd64', 'version': '8.3.0-6ubuntu1~18.04.1'},
#  {'name': 'libcdio-cdda2:amd64', 'version': '10.2+0.94+2-2build1'},
#  {'name': 'libcdio-paranoia2:amd64', 'version': '10.2+0.94+2-2build1'},
#  {'name': 'libcdio17:amd64', 'version': '1.0.0-2ubuntu2'},
#  {'name': 'libcdparanoia0:amd64', 'version': '3.10.2+debian-13'},
#  {'name': 'libcdr-0.1-1:amd64', 'version': '0.1.4-1build1'},
#  {'name': 'libcgi-fast-perl', 'version': '1:2.13-1'},
#  {'name': 'libcgi-pm-perl', 'version': '4.38-1'},
#  {'name': 'libcheese-gtk25:amd64', 'version': '3.28.0-1ubuntu1'},
#  {'name': 'libcheese8:amd64', 'version': '3.28.0-1ubuntu1'},
#  {'name': 'libclass-accessor-perl', 'version': '0.51-1'},
#  {'name': 'libclone-perl', 'version': '0.39-1'},
#  {'name': 'libclucene-contribs1v5:amd64', 'version': '2.3.3.4+dfsg-1'},
#  {'name': 'libclucene-core1v5:amd64', 'version': '2.3.3.4+dfsg-1'},
#  {'name': 'libclutter-1.0-0:amd64', 'version': '1.26.2+dfsg-4'},
#  {'name': 'libclutter-1.0-common', 'version': '1.26.2+dfsg-4'},
#  {'name': 'libclutter-gst-3.0-0:amd64', 'version': '3.0.26-1'},
#  {'name': 'libclutter-gtk-1.0-0:amd64', 'version': '1.8.4-3'},
#  {'name': 'libcmis-0.5-5v5', 'version': '0.5.1+git20160603-3build2'},
#  {'name': 'libcogl-common', 'version': '1.22.2-3ubuntu1'},
#  {'name': 'libcogl-pango20:amd64', 'version': '1.22.2-3ubuntu1'},
#  {'name': 'libcogl-path20:amd64', 'version': '1.22.2-3ubuntu1'},
#  {'name': 'libcogl20:amd64', 'version': '1.22.2-3ubuntu1'},
#  {'name': 'libcolamd2:amd64', 'version': '1:5.1.2-2'},
#  {'name': 'libcolord-gtk1:amd64', 'version': '0.1.26-2'},
#  {'name': 'libcolord2:amd64', 'version': '1.3.3-2build1'},
#  {'name': 'libcolorhug2:amd64', 'version': '1.3.3-2build1'},
#  {'name': 'libcom-err2:amd64', 'version': '1.44.1-1ubuntu1.1'},
#  {'name': 'libcrack2:amd64', 'version': '2.9.2-5build1'},
#  {'name': 'libcroco3:amd64', 'version': '0.6.12-2'},
#  {'name': 'libcryptsetup12:amd64', 'version': '2:2.0.2-1ubuntu1.1'},
#  {'name': 'libcups2:amd64', 'version': '2.2.7-1ubuntu2.7'},
#  {'name': 'libcupscgi1:amd64', 'version': '2.2.7-1ubuntu2.7'},
#  {'name': 'libcupsfilters1:amd64', 'version': '1.20.2-0ubuntu3.1'},
#  {'name': 'libcupsimage2:amd64', 'version': '2.2.7-1ubuntu2.7'},
#  {'name': 'libcupsmime1:amd64', 'version': '2.2.7-1ubuntu2.7'},
#  {'name': 'libcupsppdc1:amd64', 'version': '2.2.7-1ubuntu2.7'},
#  {'name': 'libcurl3-gnutls:amd64', 'version': '7.58.0-2ubuntu3.7'},
#  {'name': 'libdaemon0:amd64', 'version': '0.14-6'},
#  {'name': 'libdata-dump-perl', 'version': '1.23-1'},
#  {'name': 'libdatrie1:amd64', 'version': '0.2.10-7'},
#  {'name': 'libdazzle-1.0-0:amd64', 'version': '3.28.1-1'},
#  {'name': 'libdb5.3:amd64', 'version': '5.3.28-13.1ubuntu1.1'},
#  {'name': 'libdbus-1-3:amd64', 'version': '1.12.2-1ubuntu1.1'},
#  {'name': 'libdbus-glib-1-2:amd64', 'version': '0.110-2'},
#  {'name': 'libdbusmenu-glib4:amd64',
#   'version': '16.04.1+18.04.20171206-0ubuntu2'},
#  {'name': 'libdbusmenu-gtk3-4:amd64',
#   'version': '16.04.1+18.04.20171206-0ubuntu2'},
#  {'name': 'libdbusmenu-gtk4:amd64',
#   'version': '16.04.1+18.04.20171206-0ubuntu2'},
#  {'name': 'libdconf1:amd64', 'version': '0.26.0-2ubuntu3'},
#  {'name': 'libdebconfclient0:amd64', 'version': '0.213ubuntu1'},
#  {'name': 'libdee-1.0-4:amd64', 'version': '1.2.7+17.10.20170616-0ubuntu4'},
#  {'name': 'libdevmapper1.02.1:amd64',
#   'version': '2:1.02.145-4.1ubuntu3.18.04.1'},
#  {'name': 'libdigest-hmac-perl', 'version': '1.03+dfsg-1'},
#  {'name': 'libdjvulibre-text', 'version': '3.5.27.1-8'},
#  {'name': 'libdjvulibre21:amd64', 'version': '3.5.27.1-8'},
#  {'name': 'libdmapsharing-3.0-2:amd64', 'version': '2.9.39-2'},
#  {'name': 'libdns-export1100', 'version': '1:9.11.3+dfsg-1ubuntu1.8'},
#  {'name': 'libdns1100:amd64', 'version': '1:9.11.3+dfsg-1ubuntu1.8'},
#  {'name': 'libdotconf0:amd64', 'version': '1.3-0.3fakesync1'},
#  {'name': 'libdpkg-perl', 'version': '1.19.0.5ubuntu2.1'},
#  {'name': 'libdrm-amdgpu1:amd64', 'version': '2.4.97-1ubuntu1~18.04.1'},
#  {'name': 'libdrm-common', 'version': '2.4.97-1ubuntu1~18.04.1'},
#  {'name': 'libdrm-intel1:amd64', 'version': '2.4.97-1ubuntu1~18.04.1'},
#  {'name': 'libdrm-nouveau2:amd64', 'version': '2.4.97-1ubuntu1~18.04.1'},
#  {'name': 'libdrm-radeon1:amd64', 'version': '2.4.97-1ubuntu1~18.04.1'},
#  {'name': 'libdrm2:amd64', 'version': '2.4.97-1ubuntu1~18.04.1'},
#  {'name': 'libdv4:amd64', 'version': '1.0.0-11'},
#  {'name': 'libdw1:amd64', 'version': '0.170-0.4ubuntu0.1'},
#  {'name': 'libe-book-0.1-1:amd64', 'version': '0.1.3-1'},
#  {'name': 'libebackend-1.2-10:amd64', 'version': '3.28.5-0ubuntu0.18.04.2'},
#  {'name': 'libebook-1.2-19:amd64', 'version': '3.28.5-0ubuntu0.18.04.2'},
#  {'name': 'libebook-contacts-1.2-2:amd64',
#   'version': '3.28.5-0ubuntu0.18.04.2'},
#  {'name': 'libecal-1.2-19:amd64', 'version': '3.28.5-0ubuntu0.18.04.2'},
#  {'name': 'libedata-book-1.2-25:amd64', 'version': '3.28.5-0ubuntu0.18.04.2'},
#  {'name': 'libedata-cal-1.2-28:amd64', 'version': '3.28.5-0ubuntu0.18.04.2'},
#  {'name': 'libedataserver-1.2-23:amd64', 'version': '3.28.5-0ubuntu0.18.04.2'},
#  {'name': 'libedataserverui-1.2-2:amd64',
#   'version': '3.28.5-0ubuntu0.18.04.2'},
#  {'name': 'libedit2:amd64', 'version': '3.1-20170329-1'},
#  {'name': 'libefiboot1:amd64', 'version': '34-1'},
#  {'name': 'libefivar1:amd64', 'version': '34-1'},
#  {'name': 'libegl-mesa0:amd64', 'version': '19.0.2-1ubuntu1.1~18.04.2'},
#  {'name': 'libegl1:amd64', 'version': '1.0.0-2ubuntu2.3'},
#  {'name': 'libegl1-mesa:amd64', 'version': '19.0.2-1ubuntu1.1~18.04.2'},
#  {'name': 'libelf1:amd64', 'version': '0.170-0.4ubuntu0.1'},
#  {'name': 'libemail-valid-perl', 'version': '1.202-1'},
#  {'name': 'libenchant1c2a:amd64', 'version': '1.6.0-11.1'},
#  {'name': 'libencode-locale-perl', 'version': '1.05-1'},
#  {'name': 'libeot0:amd64', 'version': '0.01-5'},
#  {'name': 'libepoxy0:amd64', 'version': '1.4.3-1'},
#  {'name': 'libepubgen-0.1-1:amd64', 'version': '0.1.0-2ubuntu1'},
#  {'name': 'libespeak-ng1:amd64', 'version': '1.49.2+dfsg-1'},
#  {'name': 'libestr0:amd64', 'version': '0.1.10-2.1'},
#  {'name': 'libetonyek-0.1-1:amd64', 'version': '0.1.7-3'},
#  {'name': 'libevdev2:amd64', 'version': '1.5.8+dfsg-1'},
#  {'name': 'libevdocument3-4:amd64', 'version': '3.28.4-0ubuntu1.2'},
#  {'name': 'libevent-2.1-6:amd64', 'version': '2.1.8-stable-4build1'},
#  {'name': 'libevview3-3:amd64', 'version': '3.28.4-0ubuntu1.2'},
#  {'name': 'libexempi3:amd64', 'version': '2.4.5-2'},
#  {'name': 'libexif12:amd64', 'version': '0.6.21-4'},
#  {'name': 'libexiv2-14:amd64', 'version': '0.25-3.1ubuntu0.18.04.3'},
#  {'name': 'libexpat1:amd64', 'version': '2.2.5-3ubuntu0.1'},
#  {'name': 'libexporter-tiny-perl', 'version': '1.000000-2'},
#  {'name': 'libext2fs2:amd64', 'version': '1.44.1-1ubuntu1.1'},
#  {'name': 'libexttextcat-2.0-0:amd64', 'version': '3.4.5-1'},
#  {'name': 'libexttextcat-data', 'version': '3.4.5-1'},
#  {'name': 'libfastjson4:amd64', 'version': '0.99.8-2'},
#  {'name': 'libfcgi-perl', 'version': '0.78-2build1'},
#  {'name': 'libfdisk1:amd64', 'version': '2.31.1-0.4ubuntu3.3'},
#  {'name': 'libffi6:amd64', 'version': '3.2.1-8'},
#  {'name': 'libfftw3-double3:amd64', 'version': '3.3.7-1'},
#  {'name': 'libfftw3-single3:amd64', 'version': '3.3.7-1'},
#  {'name': 'libfile-basedir-perl', 'version': '0.07-1'},
#  {'name': 'libfile-copy-recursive-perl', 'version': '0.40-1'},
#  {'name': 'libfile-desktopentry-perl', 'version': '0.22-1'},
#  {'name': 'libfile-fcntllock-perl', 'version': '0.22-3build2'},
#  {'name': 'libfile-listing-perl', 'version': '6.04-1'},
#  {'name': 'libfile-mimeinfo-perl', 'version': '0.28-1'},
#  {'name': 'libflac8:amd64', 'version': '1.3.2-1'},
#  {'name': 'libfont-afm-perl', 'version': '1.20-2'},
#  {'name': 'libfontconfig1:amd64', 'version': '2.12.6-0ubuntu2'},
#  {'name': 'libfontembed1:amd64', 'version': '1.20.2-0ubuntu3.1'},
#  {'name': 'libfontenc1:amd64', 'version': '1:1.1.3-1'},
#  {'name': 'libfreehand-0.1-1', 'version': '0.1.2-2'},
#  {'name': 'libfreerdp-client2-2:amd64',
#   'version': '2.0.0~git20170725.1.1648deb+dfsg1-7ubuntu0.1'},
#  {'name': 'libfreerdp2-2:amd64',
#   'version': '2.0.0~git20170725.1.1648deb+dfsg1-7ubuntu0.1'},
#  {'name': 'libfreetype6:amd64', 'version': '2.8.1-2ubuntu2'},
#  {'name': 'libfribidi0:amd64', 'version': '0.19.7-2'},
#  {'name': 'libfuse2:amd64', 'version': '2.9.7-1ubuntu1'},
#  {'name': 'libfwup1:amd64', 'version': '12-3bionic2'},
#  {'name': 'libfwupd2:amd64', 'version': '1.0.9-0ubuntu2'},
#  {'name': 'libgail-3-0:amd64', 'version': '3.22.30-1ubuntu4'},
#  {'name': 'libgail-common:amd64', 'version': '2.24.32-1ubuntu1'},
#  {'name': 'libgail18:amd64', 'version': '2.24.32-1ubuntu1'},
#  {'name': 'libgbm1:amd64', 'version': '19.0.2-1ubuntu1.1~18.04.2'},
#  {'name': 'libgc1c2:amd64', 'version': '1:7.4.2-8ubuntu1'},
#  {'name': 'libgcab-1.0-0:amd64', 'version': '1.1-2'},
#  {'name': 'libgcc1:amd64', 'version': '1:8.3.0-6ubuntu1~18.04.1'},
#  {'name': 'libgck-1-0:amd64', 'version': '3.28.0-1'},
#  {'name': 'libgcr-base-3-1:amd64', 'version': '3.28.0-1'},
#  {'name': 'libgcr-ui-3-1:amd64', 'version': '3.28.0-1'},
#  {'name': 'libgcrypt20:amd64', 'version': '1.8.1-4ubuntu1.1'},
#  {'name': 'libgd3:amd64', 'version': '2.2.5-4ubuntu0.3'},
#  {'name': 'libgdata-common', 'version': '0.17.9-2'},
#  {'name': 'libgdata22:amd64', 'version': '0.17.9-2'},
#  {'name': 'libgdbm-compat4:amd64', 'version': '1.14.1-6'},
#  {'name': 'libgdbm5:amd64', 'version': '1.14.1-6'},
#  {'name': 'libgdk-pixbuf2.0-0:amd64', 'version': '2.36.11-2'},
#  {'name': 'libgdk-pixbuf2.0-bin', 'version': '2.36.11-2'},
#  {'name': 'libgdk-pixbuf2.0-common', 'version': '2.36.11-2'},
#  {'name': 'libgdm1', 'version': '3.28.3-0ubuntu18.04.4'},
#  {'name': 'libgee-0.8-2:amd64', 'version': '0.20.1-1'},
#  {'name': 'libgeoclue-2-0:amd64', 'version': '2.4.7-1ubuntu1'},
#  {'name': 'libgeocode-glib0:amd64', 'version': '3.25.4.1-4ubuntu0.18.04.1'},
#  {'name': 'libgeoip1:amd64', 'version': '1.6.12-1'},
#  {'name': 'libgexiv2-2:amd64', 'version': '0.10.8-1'},
#  {'name': 'libgirepository-1.0-1:amd64', 'version': '1.56.1-1'},
#  {'name': 'libgjs0g', 'version': '1.52.5-0ubuntu18.04.1'},
#  {'name': 'libgl1:amd64', 'version': '1.0.0-2ubuntu2.3'},
#  {'name': 'libgl1-mesa-dri:amd64', 'version': '19.0.2-1ubuntu1.1~18.04.2'},
#  {'name': 'libgl1-mesa-glx:amd64', 'version': '19.0.2-1ubuntu1.1~18.04.2'},
#  {'name': 'libglapi-mesa:amd64', 'version': '19.0.2-1ubuntu1.1~18.04.2'},
#  {'name': 'libgles2:amd64', 'version': '1.0.0-2ubuntu2.3'},
#  {'name': 'libglib-object-introspection-perl', 'version': '0.044-2'},
#  {'name': 'libglib-perl', 'version': '3:1.326-1build1'},
#  {'name': 'libglib2.0-0:amd64', 'version': '2.56.4-0ubuntu0.18.04.4'},
#  {'name': 'libglib2.0-bin', 'version': '2.56.4-0ubuntu0.18.04.4'},
#  {'name': 'libglib2.0-data', 'version': '2.56.4-0ubuntu0.18.04.4'},
#  {'name': 'libglu1-mesa:amd64', 'version': '9.0.0-2.1build1'},
#  {'name': 'libglvnd0:amd64', 'version': '1.0.0-2ubuntu2.3'},
#  {'name': 'libglx-mesa0:amd64', 'version': '19.0.2-1ubuntu1.1~18.04.2'},
#  {'name': 'libglx0:amd64', 'version': '1.0.0-2ubuntu2.3'},
#  {'name': 'libgmime-3.0-0:amd64', 'version': '3.2.0-1'},
#  {'name': 'libgmp10:amd64', 'version': '2:6.1.2+dfsg-2'},
#  {'name': 'libgnome-autoar-0-0:amd64', 'version': '0.2.3-1'},
#  {'name': 'libgnome-bluetooth13:amd64', 'version': '3.28.0-2ubuntu0.2'},
#  {'name': 'libgnome-desktop-3-17:amd64', 'version': '3.28.2-0ubuntu1.5'},
#  {'name': 'libgnome-games-support-1-3:amd64', 'version': '1.4.1-1'},
#  {'name': 'libgnome-games-support-common', 'version': '1.4.1-1'},
#  {'name': 'libgnome-menu-3-0:amd64', 'version': '3.13.3-11ubuntu1.1'},
#  {'name': 'libgnome-todo', 'version': '3.28.1-1'},
#  {'name': 'libgnomekbd-common', 'version': '3.26.0-3ubuntu0.18.04.1'},
#  {'name': 'libgnomekbd8:amd64', 'version': '3.26.0-3ubuntu0.18.04.1'},
#  {'name': 'libgnutls30:amd64', 'version': '3.5.18-1ubuntu1.1'},
#  {'name': 'libgoa-1.0-0b:amd64', 'version': '3.28.0-0ubuntu2.1'},
#  {'name': 'libgoa-1.0-common', 'version': '3.28.0-0ubuntu2.1'},
#  {'name': 'libgoa-backend-1.0-1:amd64', 'version': '3.28.0-0ubuntu2.1'},
#  {'name': 'libgom-1.0-0:amd64', 'version': '0.3.3-4'},
#  {'name': 'libgomp1:amd64', 'version': '8.3.0-6ubuntu1~18.04.1'},
#  {'name': 'libgpg-error0:amd64', 'version': '1.27-6'},
#  {'name': 'libgpgme11:amd64', 'version': '1.10.0-1ubuntu2'},
#  {'name': 'libgpgmepp6:amd64', 'version': '1.10.0-1ubuntu2'},
#  {'name': 'libgphoto2-6:amd64', 'version': '2.5.16-2'},
#  {'name': 'libgphoto2-l10n', 'version': '2.5.16-2'},
#  {'name': 'libgphoto2-port12:amd64', 'version': '2.5.16-2'},
#  {'name': 'libgpm2:amd64', 'version': '1.20.7-5'},
#  {'name': 'libgpod-common', 'version': '0.8.3-11'},
#  {'name': 'libgpod4:amd64', 'version': '0.8.3-11'},
#  {'name': 'libgraphene-1.0-0:amd64', 'version': '1.8.0-1'},
#  {'name': 'libgraphite2-3:amd64', 'version': '1.3.11-2'},
#  {'name': 'libgrilo-0.3-0:amd64', 'version': '0.3.4-1'},
#  {'name': 'libgs9:amd64', 'version': '9.26~dfsg+0-0ubuntu0.18.04.11'},
#  {'name': 'libgs9-common', 'version': '9.26~dfsg+0-0ubuntu0.18.04.11'},
#  {'name': 'libgspell-1-1:amd64', 'version': '1.6.1-1'},
#  {'name': 'libgspell-1-common', 'version': '1.6.1-1'},
#  {'name': 'libgssapi-krb5-2:amd64', 'version': '1.16-2ubuntu0.1'},
#  {'name': 'libgssapi3-heimdal:amd64', 'version': '7.5.0+dfsg-1'},
#  {'name': 'libgstreamer-gl1.0-0:amd64', 'version': '1.14.5-0ubuntu1~18.04.1'},
#  {'name': 'libgstreamer-plugins-base1.0-0:amd64',
#   'version': '1.14.5-0ubuntu1~18.04.1'},
#  {'name': 'libgstreamer-plugins-good1.0-0:amd64',
#   'version': '1.14.5-0ubuntu1~18.04.1'},
#  {'name': 'libgstreamer1.0-0:amd64', 'version': '1.14.5-0ubuntu1~18.04.1'},
#  {'name': 'libgtk-3-0:amd64', 'version': '3.22.30-1ubuntu4'},
#  {'name': 'libgtk-3-bin', 'version': '3.22.30-1ubuntu4'},
#  {'name': 'libgtk-3-common', 'version': '3.22.30-1ubuntu4'},
#  {'name': 'libgtk2.0-0:amd64', 'version': '2.24.32-1ubuntu1'},
#  {'name': 'libgtk2.0-bin', 'version': '2.24.32-1ubuntu1'},
#  {'name': 'libgtk2.0-common', 'version': '2.24.32-1ubuntu1'},
#  {'name': 'libgtk3-perl', 'version': '0.032-1'},
#  {'name': 'libgtksourceview-3.0-1:amd64', 'version': '3.24.7-1'},
#  {'name': 'libgtksourceview-3.0-common', 'version': '3.24.7-1'},
#  {'name': 'libgtop-2.0-11:amd64', 'version': '2.38.0-2ubuntu0.18.04.1'},
#  {'name': 'libgtop2-common', 'version': '2.38.0-2ubuntu0.18.04.1'},
#  {'name': 'libgudev-1.0-0:amd64', 'version': '1:232-2'},
#  {'name': 'libgusb2:amd64', 'version': '0.2.11-1'},
#  {'name': 'libgutenprint2', 'version': '5.2.13-2'},
#  {'name': 'libgweather-3-15:amd64', 'version': '3.28.2-1~ubuntu18.04.1'},
#  {'name': 'libgweather-common', 'version': '3.28.2-1~ubuntu18.04.1'},
#  {'name': 'libgxps2:amd64', 'version': '0.3.0-2'},
#  {'name': 'libharfbuzz-icu0:amd64', 'version': '1.7.2-1ubuntu1'},
#  {'name': 'libharfbuzz0b:amd64', 'version': '1.7.2-1ubuntu1'},
#  {'name': 'libhcrypto4-heimdal:amd64', 'version': '7.5.0+dfsg-1'},
#  {'name': 'libheimbase1-heimdal:amd64', 'version': '7.5.0+dfsg-1'},
#  {'name': 'libheimntlm0-heimdal:amd64', 'version': '7.5.0+dfsg-1'},
#  {'name': 'libhogweed4:amd64', 'version': '3.4-1'},
#  {'name': 'libhpmud0:amd64', 'version': '3.17.10+repack0-5'},
#  {'name': 'libhtml-form-perl', 'version': '6.03-1'},
#  {'name': 'libhtml-format-perl', 'version': '2.12-1'},
#  {'name': 'libhtml-parser-perl', 'version': '3.72-3build1'},
#  {'name': 'libhtml-tagset-perl', 'version': '3.20-3'},
#  {'name': 'libhtml-tree-perl', 'version': '5.07-1'},
#  {'name': 'libhttp-cookies-perl', 'version': '6.04-1'},
#  {'name': 'libhttp-daemon-perl', 'version': '6.01-1'},
#  {'name': 'libhttp-date-perl', 'version': '6.02-1'},
#  {'name': 'libhttp-message-perl', 'version': '6.14-1'},
#  {'name': 'libhttp-negotiate-perl', 'version': '6.00-2'},
#  {'name': 'libhunspell-1.6-0:amd64', 'version': '1.6.2-1'},
#  {'name': 'libhx509-5-heimdal:amd64', 'version': '7.5.0+dfsg-1'},
#  {'name': 'libhyphen0:amd64', 'version': '2.8.8-5'},
#  {'name': 'libibus-1.0-5:amd64', 'version': '1.5.17-3ubuntu4'},
#  {'name': 'libical3:amd64', 'version': '3.0.1-5'},
#  {'name': 'libice6:amd64', 'version': '2:1.0.9-2'},
#  {'name': 'libicu60:amd64', 'version': '60.2-3ubuntu3'},
#  {'name': 'libidn11:amd64', 'version': '1.33-2.1ubuntu1.2'},
#  {'name': 'libidn2-0:amd64', 'version': '2.0.4-1.1build2'},
#  {'name': 'libiec61883-0:amd64', 'version': '1.2.0-2'},
#  {'name': 'libieee1284-3:amd64', 'version': '0.2.11-13'},
#  {'name': 'libijs-0.35:amd64', 'version': '0.35-13'},
#  {'name': 'libilmbase12:amd64', 'version': '2.2.0-11ubuntu2'},
#  {'name': 'libimobiledevice6:amd64',
#   'version': '1.2.1~git20171128.5a854327+dfsg-0.1'},
#  {'name': 'libindicator3-7', 'version': '16.10.0+18.04.20180321.1-0ubuntu1'},
#  {'name': 'libinput-bin', 'version': '1.10.4-1ubuntu0.18.04.1'},
#  {'name': 'libinput10:amd64', 'version': '1.10.4-1ubuntu0.18.04.1'},
#  {'name': 'libio-html-perl', 'version': '1.001-1'},
#  {'name': 'libio-pty-perl', 'version': '1:1.08-1.1build4'},
#  {'name': 'libio-socket-inet6-perl', 'version': '2.72-2'},
#  {'name': 'libio-socket-ssl-perl', 'version': '2.060-3~ubuntu18.04.1'},
#  {'name': 'libio-string-perl', 'version': '1.08-3'},
#  {'name': 'libip4tc0:amd64', 'version': '1.6.1-2ubuntu2'},
#  {'name': 'libip6tc0:amd64', 'version': '1.6.1-2ubuntu2'},
#  {'name': 'libipc-run-perl', 'version': '0.96-1'},
#  {'name': 'libipc-system-simple-perl', 'version': '1.25-4'},
#  {'name': 'libiptc0:amd64', 'version': '1.6.1-2ubuntu2'},
#  {'name': 'libirs160:amd64', 'version': '1:9.11.3+dfsg-1ubuntu1.8'},
#  {'name': 'libisc-export169:amd64', 'version': '1:9.11.3+dfsg-1ubuntu1.8'},
#  {'name': 'libisc169:amd64', 'version': '1:9.11.3+dfsg-1ubuntu1.8'},
#  {'name': 'libisccc160:amd64', 'version': '1:9.11.3+dfsg-1ubuntu1.8'},
#  {'name': 'libisccfg160:amd64', 'version': '1:9.11.3+dfsg-1ubuntu1.8'},
#  {'name': 'libisl19:amd64', 'version': '0.19-1'},
#  {'name': 'libiw30:amd64', 'version': '30~pre9-12ubuntu1'},
#  {'name': 'libjack-jackd2-0:amd64', 'version': '1.9.12~dfsg-2'},
#  {'name': 'libjansson4:amd64', 'version': '2.11-1'},
#  {'name': 'libjavascriptcoregtk-4.0-18:amd64',
#   'version': '2.24.2-0ubuntu0.18.04.1'},
#  {'name': 'libjbig0:amd64', 'version': '2.1-3.1build1'},
#  {'name': 'libjbig2dec0:amd64', 'version': '0.13-6'},
#  {'name': 'libjpeg-turbo8:amd64', 'version': '1.5.2-0ubuntu5.18.04.1'},
#  {'name': 'libjpeg8:amd64', 'version': '8c-2ubuntu8'},
#  {'name': 'libjson-c3:amd64', 'version': '0.12.1-1.3'},
#  {'name': 'libjson-glib-1.0-0:amd64', 'version': '1.4.2-3'},
#  {'name': 'libjson-glib-1.0-common', 'version': '1.4.2-3'},
#  {'name': 'libk5crypto3:amd64', 'version': '1.16-2ubuntu0.1'},
#  {'name': 'libkeyutils1:amd64', 'version': '1.5.9-9.2ubuntu2'},
#  {'name': 'libklibc', 'version': '2.0.4-9ubuntu2'},
#  {'name': 'libkmod2:amd64', 'version': '24-1ubuntu3.2'},
#  {'name': 'libkpathsea6:amd64', 'version': '2017.20170613.44572-8ubuntu0.1'},
#  {'name': 'libkrb5-26-heimdal:amd64', 'version': '7.5.0+dfsg-1'},
#  {'name': 'libkrb5-3:amd64', 'version': '1.16-2ubuntu0.1'},
#  {'name': 'libkrb5support0:amd64', 'version': '1.16-2ubuntu0.1'},
#  {'name': 'libksba8:amd64', 'version': '1.3.5-2'},
#  {'name': 'liblangtag-common', 'version': '0.6.2-1'},
#  {'name': 'liblangtag1:amd64', 'version': '0.6.2-1'},
#  {'name': 'liblcms2-2:amd64', 'version': '2.9-1ubuntu0.1'},
#  {'name': 'liblcms2-utils', 'version': '2.9-1ubuntu0.1'},
#  {'name': 'libldap-2.4-2:amd64', 'version': '2.4.45+dfsg-1ubuntu1.3'},
#  {'name': 'libldap-common', 'version': '2.4.45+dfsg-1ubuntu1.3'},
#  {'name': 'libldb1:amd64', 'version': '2:1.2.3-1ubuntu0.1'},
#  {'name': 'liblirc-client0:amd64', 'version': '0.10.0-2'},
#  {'name': 'liblist-moreutils-perl', 'version': '0.416-1build3'},
#  {'name': 'libllvm6.0:amd64', 'version': '1:6.0-1ubuntu2'},
#  {'name': 'libllvm8:amd64', 'version': '1:8-3~ubuntu18.04.1'},
#  {'name': 'liblocale-gettext-perl', 'version': '1.07-3build2'},
#  {'name': 'liblouis-data', 'version': '3.5.0-1ubuntu0.3'},
#  {'name': 'liblouis14:amd64', 'version': '3.5.0-1ubuntu0.3'},
#  {'name': 'liblouisutdml-bin', 'version': '2.7.0-1'},
#  {'name': 'liblouisutdml-data', 'version': '2.7.0-1'},
#  {'name': 'liblouisutdml8:amd64', 'version': '2.7.0-1'},
#  {'name': 'liblqr-1-0:amd64', 'version': '0.4.2-2.1'},
#  {'name': 'libltdl7:amd64', 'version': '2.4.6-2'},
#  {'name': 'liblua5.3-0:amd64', 'version': '5.3.3-1ubuntu0.18.04.1'},
#  {'name': 'liblwp-mediatypes-perl', 'version': '6.02-1'},
#  {'name': 'liblwp-protocol-https-perl', 'version': '6.07-2'},
#  {'name': 'liblwres160:amd64', 'version': '1:9.11.3+dfsg-1ubuntu1.8'},
#  {'name': 'liblz4-1:amd64', 'version': '0.0~r131-2ubuntu3'},
#  {'name': 'liblzma5:amd64', 'version': '5.2.2-1.3'},
#  {'name': 'liblzo2-2:amd64', 'version': '2.08-1.2'},
#  {'name': 'libmagic-mgc', 'version': '1:5.32-2ubuntu0.2'},
#  {'name': 'libmagic1:amd64', 'version': '1:5.32-2ubuntu0.2'},
#  {'name': 'libmagickcore-6.q16-3:amd64',
#   'version': '8:6.9.7.4+dfsg-16ubuntu6.7'},
#  {'name': 'libmagickcore-6.q16-3-extra:amd64',
#   'version': '8:6.9.7.4+dfsg-16ubuntu6.7'},
#  {'name': 'libmagickwand-6.q16-3:amd64',
#   'version': '8:6.9.7.4+dfsg-16ubuntu6.7'},
#  {'name': 'libmailtools-perl', 'version': '2.18-1'},
#  {'name': 'libmbim-glib4:amd64', 'version': '1.18.0-1~ubuntu18.04.1'},
#  {'name': 'libmbim-proxy', 'version': '1.18.0-1~ubuntu18.04.1'},
#  {'name': 'libmediaart-2.0-0:amd64', 'version': '1.9.4-1'},
#  {'name': 'libmessaging-menu0:amd64',
#   'version': '13.10.1+17.04.20170120-0ubuntu2'},
#  {'name': 'libmhash2:amd64', 'version': '0.9.9.9-7'},
#  {'name': 'libminiupnpc10:amd64', 'version': '1.9.20140610-4ubuntu2'},
#  {'name': 'libmm-glib0:amd64', 'version': '1.10.0-1~ubuntu18.04.2'},
#  {'name': 'libmnl0:amd64', 'version': '1.0.4-2'},
#  {'name': 'libmount1:amd64', 'version': '2.31.1-0.4ubuntu3.3'},
#  {'name': 'libmozjs-52-0:amd64', 'version': '52.9.1-0ubuntu0.18.04.1'},
#  {'name': 'libmp3lame0:amd64', 'version': '3.100-2'},
#  {'name': 'libmpc3:amd64', 'version': '1.1.0-1'},
#  {'name': 'libmpdec2:amd64', 'version': '2.4.2-1ubuntu1'},
#  {'name': 'libmpfr6:amd64', 'version': '4.0.1-1'},
#  {'name': 'libmpg123-0:amd64', 'version': '1.25.10-1'},
#  {'name': 'libmspub-0.1-1:amd64', 'version': '0.1.4-1'},
#  {'name': 'libmtdev1:amd64', 'version': '1.1.5-1ubuntu3'},
#  {'name': 'libmtp-common', 'version': '1.1.13-1'},
#  {'name': 'libmtp-runtime', 'version': '1.1.13-1'},
#  {'name': 'libmtp9:amd64', 'version': '1.1.13-1'},
#  {'name': 'libmutter-2-0:amd64', 'version': '3.28.4-0ubuntu18.04.1'},
#  {'name': 'libmwaw-0.3-3:amd64', 'version': '0.3.13-1'},
#  {'name': 'libmythes-1.2-0:amd64', 'version': '2:1.2.4-3'},
#  {'name': 'libnatpmp1', 'version': '20150609-2'},
#  {'name': 'libnautilus-extension1a:amd64',
#   'version': '1:3.26.4-0~ubuntu18.04.4'},
#  {'name': 'libncurses5:amd64', 'version': '6.1-1ubuntu1.18.04'},
#  {'name': 'libncursesw5:amd64', 'version': '6.1-1ubuntu1.18.04'},
#  {'name': 'libndp0:amd64', 'version': '1.6-1'},
#  {'name': 'libneon27-gnutls:amd64', 'version': '0.30.2-3~ubuntu18.04.1'},
#  {'name': 'libnet-dbus-perl', 'version': '1.1.0-4build2'},
#  {'name': 'libnet-dns-perl', 'version': '1.10-2'},
#  {'name': 'libnet-domain-tld-perl', 'version': '1.75-1'},
#  {'name': 'libnet-http-perl', 'version': '6.17-1'},
#  {'name': 'libnet-ip-perl', 'version': '1.26-1'},
#  {'name': 'libnet-libidn-perl', 'version': '0.12.ds-2build4'},
#  {'name': 'libnet-smtp-ssl-perl', 'version': '1.04-1'},
#  {'name': 'libnet-ssleay-perl', 'version': '1.84-1ubuntu0.2'},
#  {'name': 'libnetfilter-conntrack3:amd64', 'version': '1.0.6-2'},
#  {'name': 'libnetpbm10', 'version': '2:10.0-15.3build1'},
#  {'name': 'libnettle6:amd64', 'version': '3.4-1'},
#  {'name': 'libnewt0.52:amd64', 'version': '0.52.20-1ubuntu1'},
#  {'name': 'libnfnetlink0:amd64', 'version': '1.0.1-3'},
#  {'name': 'libnghttp2-14:amd64', 'version': '1.30.0-1ubuntu1'},
#  {'name': 'libnih1:amd64', 'version': '1.0.3-6ubuntu2'},
#  {'name': 'libnl-3-200:amd64', 'version': '3.2.29-0ubuntu3'},
#  {'name': 'libnl-genl-3-200:amd64', 'version': '3.2.29-0ubuntu3'},
#  {'name': 'libnm0:amd64', 'version': '1.10.6-2ubuntu1.1'},
#  {'name': 'libnma0:amd64', 'version': '1.8.10-2ubuntu2'},
#  {'name': 'libnotify-bin', 'version': '0.7.7-3'},
#  {'name': 'libnotify4:amd64', 'version': '0.7.7-3'},
#  {'name': 'libnpth0:amd64', 'version': '1.5-3'},
#  {'name': 'libnspr4:amd64', 'version': '2:4.18-1ubuntu1'},
#  {'name': 'libnss-mdns:amd64', 'version': '0.10-8ubuntu1'},
#  {'name': 'libnss-myhostname:amd64', 'version': '237-3ubuntu10.28'},
#  {'name': 'libnss-systemd:amd64', 'version': '237-3ubuntu10.28'},
#  {'name': 'libnss3:amd64', 'version': '2:3.35-2ubuntu2.3'},
#  {'name': 'libntfs-3g88', 'version': '1:2017.3.23-2ubuntu0.18.04.2'},
#  {'name': 'libnuma1:amd64', 'version': '2.0.11-2.1ubuntu0.1'},
#  {'name': 'liboauth0:amd64', 'version': '1.0.3-1'},
#  {'name': 'libodfgen-0.1-1:amd64', 'version': '0.1.6-2'},
#  {'name': 'libogg0:amd64', 'version': '1.3.2-1'},
#  {'name': 'libopenexr22:amd64', 'version': '2.2.0-11.1ubuntu1'},
#  {'name': 'libopus0:amd64', 'version': '1.1.2-1ubuntu1'},
#  {'name': 'liborc-0.4-0:amd64', 'version': '1:0.4.28-1'},
#  {'name': 'liborcus-0.13-0:amd64', 'version': '0.13.4-2'},
#  {'name': 'libp11-kit0:amd64', 'version': '0.23.9-2'},
#  {'name': 'libpackagekit-glib2-18:amd64', 'version': '1.1.9-1ubuntu2.18.04.5'},
#  {'name': 'libpagemaker-0.0-0:amd64', 'version': '0.0.4-1'},
#  {'name': 'libpam-cap:amd64', 'version': '1:2.25-1.2'},
#  {'name': 'libpam-gnome-keyring:amd64',
#   'version': '3.28.0.2-1ubuntu1.18.04.1'},
#  {'name': 'libpam-modules:amd64', 'version': '1.1.8-3.6ubuntu2.18.04.1'},
#  {'name': 'libpam-modules-bin', 'version': '1.1.8-3.6ubuntu2.18.04.1'},
#  {'name': 'libpam-runtime', 'version': '1.1.8-3.6ubuntu2.18.04.1'},
#  {'name': 'libpam-systemd:amd64', 'version': '237-3ubuntu10.28'},
#  {'name': 'libpam0g:amd64', 'version': '1.1.8-3.6ubuntu2.18.04.1'},
#  {'name': 'libpango-1.0-0:amd64', 'version': '1.40.14-1ubuntu0.1'},
#  {'name': 'libpangocairo-1.0-0:amd64', 'version': '1.40.14-1ubuntu0.1'},
#  {'name': 'libpangoft2-1.0-0:amd64', 'version': '1.40.14-1ubuntu0.1'},
#  {'name': 'libpangoxft-1.0-0:amd64', 'version': '1.40.14-1ubuntu0.1'},
#  {'name': 'libpaper-utils', 'version': '1.1.24+nmu5ubuntu1'},
#  {'name': 'libpaper1:amd64', 'version': '1.1.24+nmu5ubuntu1'},
#  {'name': 'libparse-debianchangelog-perl', 'version': '1.2.0-12'},
#  {'name': 'libparted-fs-resize0:amd64', 'version': '3.2-20ubuntu0.2'},
#  {'name': 'libparted2:amd64', 'version': '3.2-20ubuntu0.2'},
#  {'name': 'libpcap0.8:amd64', 'version': '1.8.1-6ubuntu1'},
#  {'name': 'libpcaudio0', 'version': '1.0-1'},
#  {'name': 'libpci3:amd64', 'version': '1:3.5.2-1ubuntu1.1'},
#  {'name': 'libpciaccess0:amd64', 'version': '0.14-1'},
#  {'name': 'libpcre3:amd64', 'version': '2:8.39-9'},
#  {'name': 'libpcsclite1:amd64', 'version': '1.8.23-1'},
#  {'name': 'libpeas-1.0-0:amd64', 'version': '1.22.0-2'},
#  {'name': 'libpeas-common', 'version': '1.22.0-2'},
#  {'name': 'libperl5.26:amd64', 'version': '5.26.1-6ubuntu0.3'},
#  {'name': 'libperlio-gzip-perl', 'version': '0.19-1build3'},
#  {'name': 'libphonenumber7:amd64', 'version': '7.1.0-5ubuntu5'},
#  {'name': 'libpipeline1:amd64', 'version': '1.5.0-1'},
#  {'name': 'libpixman-1-0:amd64', 'version': '0.34.0-2'},
#  {'name': 'libplist3:amd64', 'version': '2.0.0-2ubuntu1'},
#  {'name': 'libplymouth4:amd64', 'version': '0.9.3-1ubuntu7.18.04.2'},
#  {'name': 'libpng16-16:amd64', 'version': '1.6.34-1ubuntu0.18.04.2'},
#  {'name': 'libpolkit-agent-1-0:amd64', 'version': '0.105-20ubuntu0.18.04.5'},
#  {'name': 'libpolkit-backend-1-0:amd64', 'version': '0.105-20ubuntu0.18.04.5'},
#  {'name': 'libpolkit-gobject-1-0:amd64', 'version': '0.105-20ubuntu0.18.04.5'},
#  {'name': 'libpoppler-glib8:amd64', 'version': '0.62.0-2ubuntu2.10'},
#  {'name': 'libpoppler73:amd64', 'version': '0.62.0-2ubuntu2.10'},
#  {'name': 'libpopt0:amd64', 'version': '1.16-11'},
#  {'name': 'libprocps6:amd64', 'version': '2:3.3.12-3ubuntu1.1'},
#  {'name': 'libprotobuf10:amd64', 'version': '3.0.0-9.1ubuntu1'},
#  {'name': 'libproxy1-plugin-gsettings:amd64', 'version': '0.4.15-1'},
#  {'name': 'libproxy1-plugin-networkmanager:amd64', 'version': '0.4.15-1'},
#  {'name': 'libproxy1v5:amd64', 'version': '0.4.15-1'},
#  {'name': 'libpsl5:amd64', 'version': '0.19.1-5build1'},
#  {'name': 'libpulse-mainloop-glib0:amd64', 'version': '1:11.1-1ubuntu7.2'},
#  {'name': 'libpulse0:amd64', 'version': '1:11.1-1ubuntu7.2'},
#  {'name': 'libpulsedsp:amd64', 'version': '1:11.1-1ubuntu7.2'},
#  {'name': 'libpwquality-common', 'version': '1.4.0-2'},
#  {'name': 'libpwquality1:amd64', 'version': '1.4.0-2'},
#  {'name': 'libpython2.7:amd64', 'version': '2.7.15-4ubuntu4~18.04'},
#  {'name': 'libpython2.7-minimal:amd64', 'version': '2.7.15-4ubuntu4~18.04'},
#  {'name': 'libpython2.7-stdlib:amd64', 'version': '2.7.15-4ubuntu4~18.04'},
#  {'name': 'libpython3-stdlib:amd64', 'version': '3.6.7-1~18.04'},
#  {'name': 'libpython3.6:amd64', 'version': '3.6.8-1~18.04.1'},
#  {'name': 'libpython3.6-minimal:amd64', 'version': '3.6.8-1~18.04.1'},
#  {'name': 'libpython3.6-stdlib:amd64', 'version': '3.6.8-1~18.04.1'},
#  {'name': 'libqmi-glib5:amd64', 'version': '1.22.0-1.2~ubuntu18.04.1'},
#  {'name': 'libqmi-proxy', 'version': '1.22.0-1.2~ubuntu18.04.1'},
#  {'name': 'libqpdf21:amd64', 'version': '8.0.2-3'},
#  {'name': 'libqqwing2v5:amd64', 'version': '1.3.4-1.1'},
#  {'name': 'libraptor2-0:amd64', 'version': '2.0.14-1build1'},
#  {'name': 'librasqal3:amd64', 'version': '0.9.32-1build1'},
#  {'name': 'libraw1394-11:amd64', 'version': '2.1.2-1'},
#  {'name': 'libraw16:amd64', 'version': '0.18.8-1ubuntu0.3'},
#  {'name': 'librdf0:amd64', 'version': '1.0.17-1.1'},
#  {'name': 'libreadline7:amd64', 'version': '7.0-3'},
#  {'name': 'libreoffice-avmedia-backend-gstreamer',
#   'version': '1:6.0.7-0ubuntu0.18.04.9'},
#  {'name': 'libreoffice-base-core', 'version': '1:6.0.7-0ubuntu0.18.04.9'},
#  {'name': 'libreoffice-calc', 'version': '1:6.0.7-0ubuntu0.18.04.9'},
#  {'name': 'libreoffice-common', 'version': '1:6.0.7-0ubuntu0.18.04.9'},
#  {'name': 'libreoffice-core', 'version': '1:6.0.7-0ubuntu0.18.04.9'},
#  {'name': 'libreoffice-draw', 'version': '1:6.0.7-0ubuntu0.18.04.9'},
#  {'name': 'libreoffice-gnome', 'version': '1:6.0.7-0ubuntu0.18.04.9'},
#  {'name': 'libreoffice-gtk3', 'version': '1:6.0.7-0ubuntu0.18.04.9'},
#  {'name': 'libreoffice-help-en-us', 'version': '1:6.0.7-0ubuntu0.18.04.9'},
#  {'name': 'libreoffice-impress', 'version': '1:6.0.7-0ubuntu0.18.04.9'},
#  {'name': 'libreoffice-math', 'version': '1:6.0.7-0ubuntu0.18.04.9'},
#  {'name': 'libreoffice-ogltrans', 'version': '1:6.0.7-0ubuntu0.18.04.9'},
#  {'name': 'libreoffice-pdfimport', 'version': '1:6.0.7-0ubuntu0.18.04.9'},
#  ...]

# %%
def split_first_item(line):
    items = line.split(' ', 1)
    return {'name': items[0].strip()}

def parse_systemctl_list_units_stdout(stdout):
    return [split_first_item(line) for line in stdout]

# %%
stdin, stdout, stderr = client.exec_command('systemctl list-units --type service | grep ".service" | sed "s/\.service//g"')

parse_systemctl_list_units_stdout(stdout)
# Out:
# [{'name': 'accounts-daemon'},
#  {'name': 'acpid'},
#  {'name': 'apparmor'},
#  {'name': 'apport'},
#  {'name': 'avahi-daemon'},
#  {'name': 'bolt'},
#  {'name': 'colord'},
#  {'name': 'console-setup'},
#  {'name': 'cron'},
#  {'name': 'cups-browsed'},
#  {'name': 'cups'},
#  {'name': 'dbus'},
#  {'name': 'fwupd'},
#  {'name': 'gdm'},
#  {'name': 'grub-common'},
#  {'name': 'kerneloops'},
#  {'name': 'keyboard-setup'},
#  {'name': 'kmod-static-nodes'},
#  {'name': 'ModemManager'},
#  {'name': 'networkd-dispatcher'},
#  {'name': 'networking'},
#  {'name': 'NetworkManager-wait-online'},
#  {'name': 'NetworkManager'},
#  {'name': 'packagekit'},
#  {'name': 'polkit'},
#  {'name': 'rsyslog'},
#  {'name': 'rtkit-daemon'},
#  {'name': 'setvtrgb'},
#  {'name': 'snapd.seeded'},
#  {'name': 'snapd'},
#  {'name': 'speech-dispatcher'},
#  {'name': 'ssh'},
#  {'name': 'systemd-journal-flush'},
#  {'name': 'systemd-journald'},
#  {'name': 'systemd-logind'},
#  {'name': 'systemd-modules-load'},
#  {'name': 'systemd-random-seed'},
#  {'name': 'systemd-remount-fs'},
#  {'name': 'systemd-resolved'},
#  {'name': 'systemd-sysctl'},
#  {'name': 'systemd-tmpfiles-setup-dev'},
#  {'name': 'systemd-tmpfiles-setup'},
#  {'name': 'systemd-udev-trigger'},
#  {'name': 'systemd-udevd'},
#  {'name': 'systemd-update-utmp'},
#  {'name': 'systemd-user-sessions'},
#  {'name': 'udisks2'},
#  {'name': 'ufw'},
#  {'name': 'unattended-upgrades'},
#  {'name': 'upower'},
#  {'name': 'user@1000'},
#  {'name': 'user@121'},
#  {'name': 'vboxadd-service'},
#  {'name': 'vboxadd'},
#  {'name': 'whoopsie'},
#  {'name': 'wpa_supplicant'}]

# %%
class DebianInfoCrawler(LinuxSystemInfoCrawler):
    __software_cmd_handlers = (
        CMDHandler("dpkg-query -f '${binary:Package};${Version}\n' -W", 
                   parse_dpkg_query_stdout),
    )
    
    __deamon_services_cmd_handlers = (
        CMDHandler('systemctl list-units --type service | grep ".service" | sed "s/\.service//g"', 
                   parse_systemctl_list_units_stdout),
    )
    
    def get_software(self):
        return self.__gather_software_info()
    
    def get_deamon_services(self):
        return self.__gather_deamon_services_info()
    
    def __gather_software_info(self):
        software_info = []
        for cmd_handler in self.__software_cmd_handlers:
            software_info +=  self._read_remote_system_info(cmd_handler)
        return software_info

    def __gather_deamon_services_info(self):
        deamon_services_info = []
        for cmd_handler in self.__deamon_services_cmd_handlers:
            deamon_services_info +=  self._read_remote_system_info(cmd_handler)
        return deamon_services_info

# %%
crawler = DebianInfoCrawler(client)

# %%
crawler.get_operating_system()
# Out:
# {'name': 'Ubuntu',
#  'version': '18.04.3 LTS (Bionic Beaver)',
#  'id': 'ubuntu',
#  'id_like': 'debian',
#  'pretty_name': 'Ubuntu 18.04.3 LTS',
#  'version_id': '18.04',
#  'home_url': 'https://www.ubuntu.com/',
#  'support_url': 'https://help.ubuntu.com/',
#  'bug_report_url': 'https://bugs.launchpad.net/ubuntu/',
#  'privacy_policy_url': 'https://www.ubuntu.com/legal/terms-and-policies/privacy-policy',
#  'version_codename': 'bionic',
#  'ubuntu_codename': 'bionic',
#  'static_hostname': 'u1',
#  'icon_name': 'computer-vm',
#  'chassis': 'vm',
#  'machine_id': 'ca6dfc4eb469493fa214dcef38a759f5',
#  'boot_id': '1f0e0f02265545a7b98d01fcb71f4e60',
#  'virtualization': 'oracle',
#  'operating_system': 'Ubuntu 18.04.3 LTS',
#  'kernel': 'Linux 5.0.0-23-generic',
#  'architecture': 'x86-64'}

# %%
crawler.get_cpu()
# Out:
# [{'architecture': 'x86_64',
#   'cpu_op-mode(s)': '32-bit, 64-bit',
#   'byte_order': 'Little Endian',
#   'cpu(s)': '1',
#   'on-line_cpu(s)_list': '0',
#   'thread(s)_per_core': '1',
#   'core(s)_per_socket': '1',
#   'socket(s)': '1',
#   'numa_node(s)': '1',
#   'vendor_id': 'GenuineIntel',
#   'cpu_family': '6',
#   'model': '158',
#   'model_name': 'Intel(R) Core(TM) i7-8700K CPU @ 3.70GHz',
#   'stepping': '10',
#   'cpu_mhz': '3695.976',
#   'bogomips': '7391.95',
#   'hypervisor_vendor': 'KVM',
#   'virtualization_type': 'full',
#   'l1d_cache': '32K',
#   'l1i_cache': '32K',
#   'l2_cache': '256K',
#   'l3_cache': '12288K',
#   'numa_node0_cpu(s)': '0',
#   'flags': 'fpu vme de pse tsc msr pae mce cx8 apic sep mtrr pge mca cmov pat pse36 clflush mmx fxsr sse sse2 syscall nx rdtscp lm constant_tsc rep_good nopl xtopology nonstop_tsc cpuid tsc_known_freq pni pclmulqdq monitor ssse3 cx16 pcid sse4_1 sse4_2 x2apic movbe popcnt aes xsave avx rdrand hypervisor lahf_lm abm 3dnowprefetch invpcid_single pti fsgsbase avx2 invpcid rdseed clflushopt md_clear flush_l1d'}]

# %%
crawler.get_gpu()
# Out:
# [{'id': 'display',
#   'class': 'display',
#   'claimed': True,
#   'handle': 'PCI:0000:00:02.0',
#   'description': 'VGA compatible controller',
#   'product': 'VirtualBox Graphics Adapter',
#   'vendor': 'InnoTek Systemberatung GmbH',
#   'physid': '2',
#   'businfo': 'pci@0000:00:02.0',
#   'version': '00',
#   'width': 32,
#   'clock': 33000000,
#   'configuration': {'driver': 'vboxvideo', 'latency': '0'},
#   'capabilities': {'vga_controller': True, 'rom': 'extension ROM'}}]

# %%
crawler.get_software()
# Out:
# [{'name': 'accountsservice', 'version': '0.6.45-1ubuntu1'},
#  {'name': 'acl', 'version': '2.2.52-3build1'},
#  {'name': 'acpi-support', 'version': '0.142'},
#  {'name': 'acpid', 'version': '1:2.0.28-1ubuntu1'},
#  {'name': 'adduser', 'version': '3.116ubuntu1'},
#  {'name': 'adium-theme-ubuntu', 'version': '0.3.4-0ubuntu4'},
#  {'name': 'adwaita-icon-theme', 'version': '3.28.0-1ubuntu1'},
#  {'name': 'aisleriot', 'version': '1:3.22.5-1'},
#  {'name': 'alsa-base', 'version': '1.0.25+dfsg-0ubuntu5'},
#  {'name': 'alsa-utils', 'version': '1.1.3-1ubuntu1'},
#  {'name': 'amd64-microcode', 'version': '3.20180524.1~ubuntu0.18.04.2'},
#  {'name': 'anacron', 'version': '2.3-24'},
#  {'name': 'apg', 'version': '2.2.3.dfsg.1-5'},
#  {'name': 'app-install-data-partner', 'version': '16.04'},
#  {'name': 'apparmor', 'version': '2.12-4ubuntu5.1'},
#  {'name': 'apport', 'version': '2.20.9-0ubuntu7.7'},
#  {'name': 'apport-gtk', 'version': '2.20.9-0ubuntu7.7'},
#  {'name': 'apport-symptoms', 'version': '0.20'},
#  {'name': 'appstream', 'version': '0.12.0-3ubuntu1'},
#  {'name': 'apt', 'version': '1.6.11'},
#  {'name': 'apt-config-icons', 'version': '0.12.0-3ubuntu1'},
#  {'name': 'apt-utils', 'version': '1.6.11'},
#  {'name': 'aptdaemon', 'version': '1.1.1+bzr982-0ubuntu19.1'},
#  {'name': 'aptdaemon-data', 'version': '1.1.1+bzr982-0ubuntu19.1'},
#  {'name': 'apturl', 'version': '0.5.2ubuntu14.2'},
#  {'name': 'apturl-common', 'version': '0.5.2ubuntu14.2'},
#  {'name': 'aspell', 'version': '0.60.7~20110707-4'},
#  {'name': 'aspell-en', 'version': '2017.08.24-0-0.1'},
#  {'name': 'at-spi2-core', 'version': '2.28.0-1'},
#  {'name': 'avahi-autoipd', 'version': '0.7-3.1ubuntu1.2'},
#  {'name': 'avahi-daemon', 'version': '0.7-3.1ubuntu1.2'},
#  {'name': 'avahi-utils', 'version': '0.7-3.1ubuntu1.2'},
#  {'name': 'baobab', 'version': '3.28.0-1'},
#  {'name': 'base-files', 'version': '10.1ubuntu2.6'},
#  {'name': 'base-passwd', 'version': '3.5.44'},
#  {'name': 'bash', 'version': '4.4.18-2ubuntu1.2'},
#  {'name': 'bash-completion', 'version': '1:2.8-1ubuntu1'},
#  {'name': 'bc', 'version': '1.07.1-2'},
#  {'name': 'bind9-host', 'version': '1:9.11.3+dfsg-1ubuntu1.8'},
#  {'name': 'binutils', 'version': '2.30-21ubuntu1~18.04.2'},
#  {'name': 'binutils-common:amd64', 'version': '2.30-21ubuntu1~18.04.2'},
#  {'name': 'binutils-x86-64-linux-gnu', 'version': '2.30-21ubuntu1~18.04.2'},
#  {'name': 'bluez', 'version': '5.48-0ubuntu3.1'},
#  {'name': 'bluez-cups', 'version': '5.48-0ubuntu3.1'},
#  {'name': 'bluez-obexd', 'version': '5.48-0ubuntu3.1'},
#  {'name': 'bolt', 'version': '0.5-0ubuntu0.18.04.1'},
#  {'name': 'branding-ubuntu', 'version': '0.10'},
#  {'name': 'brltty', 'version': '5.5-4ubuntu2.0.1'},
#  {'name': 'bsdmainutils', 'version': '11.1.2ubuntu1'},
#  {'name': 'bsdutils', 'version': '1:2.31.1-0.4ubuntu3.3'},
#  {'name': 'bubblewrap', 'version': '0.2.1-1ubuntu0.1'},
#  {'name': 'busybox-initramfs', 'version': '1:1.27.2-2ubuntu3.2'},
#  {'name': 'busybox-static', 'version': '1:1.27.2-2ubuntu3.2'},
#  {'name': 'bzip2', 'version': '1.0.6-8.1ubuntu0.2'},
#  {'name': 'ca-certificates', 'version': '20180409'},
#  {'name': 'cheese', 'version': '3.28.0-1ubuntu1'},
#  {'name': 'cheese-common', 'version': '3.28.0-1ubuntu1'},
#  {'name': 'colord', 'version': '1.3.3-2build1'},
#  {'name': 'colord-data', 'version': '1.3.3-2build1'},
#  {'name': 'command-not-found', 'version': '18.04.5'},
#  {'name': 'command-not-found-data', 'version': '18.04.5'},
#  {'name': 'console-setup', 'version': '1.178ubuntu2.9'},
#  {'name': 'console-setup-linux', 'version': '1.178ubuntu2.9'},
#  {'name': 'coreutils', 'version': '8.28-1ubuntu1'},
#  {'name': 'cpio', 'version': '2.12+dfsg-6'},
#  {'name': 'cpp', 'version': '4:7.4.0-1ubuntu2.3'},
#  {'name': 'cpp-7', 'version': '7.4.0-1ubuntu1~18.04.1'},
#  {'name': 'cracklib-runtime', 'version': '2.9.2-5build1'},
#  {'name': 'crda', 'version': '3.18-1build1'},
#  {'name': 'cron', 'version': '3.0pl1-128.1ubuntu1'},
#  {'name': 'cups', 'version': '2.2.7-1ubuntu2.7'},
#  {'name': 'cups-browsed', 'version': '1.20.2-0ubuntu3.1'},
#  {'name': 'cups-bsd', 'version': '2.2.7-1ubuntu2.7'},
#  {'name': 'cups-client', 'version': '2.2.7-1ubuntu2.7'},
#  {'name': 'cups-common', 'version': '2.2.7-1ubuntu2.7'},
#  {'name': 'cups-core-drivers', 'version': '2.2.7-1ubuntu2.7'},
#  {'name': 'cups-daemon', 'version': '2.2.7-1ubuntu2.7'},
#  {'name': 'cups-filters', 'version': '1.20.2-0ubuntu3.1'},
#  {'name': 'cups-filters-core-drivers', 'version': '1.20.2-0ubuntu3.1'},
#  {'name': 'cups-ipp-utils', 'version': '2.2.7-1ubuntu2.7'},
#  {'name': 'cups-pk-helper', 'version': '0.2.6-1ubuntu1.2'},
#  {'name': 'cups-ppdc', 'version': '2.2.7-1ubuntu2.7'},
#  {'name': 'cups-server-common', 'version': '2.2.7-1ubuntu2.7'},
#  {'name': 'dash', 'version': '0.5.8-2.10'},
#  {'name': 'dbus', 'version': '1.12.2-1ubuntu1.1'},
#  {'name': 'dbus-user-session', 'version': '1.12.2-1ubuntu1.1'},
#  {'name': 'dbus-x11', 'version': '1.12.2-1ubuntu1.1'},
#  {'name': 'dc', 'version': '1.07.1-2'},
#  {'name': 'dconf-cli', 'version': '0.26.0-2ubuntu3'},
#  {'name': 'dconf-gsettings-backend:amd64', 'version': '0.26.0-2ubuntu3'},
#  {'name': 'dconf-service', 'version': '0.26.0-2ubuntu3'},
#  {'name': 'debconf', 'version': '1.5.66ubuntu1'},
#  {'name': 'debconf-i18n', 'version': '1.5.66ubuntu1'},
#  {'name': 'debianutils', 'version': '4.8.4'},
#  {'name': 'deja-dup', 'version': '37.1-2fakesync1ubuntu0.1'},
#  {'name': 'desktop-file-utils', 'version': '0.23-1ubuntu3.18.04.2'},
#  {'name': 'dictionaries-common', 'version': '1.27.2'},
#  {'name': 'diffstat', 'version': '1.61-1build1'},
#  {'name': 'diffutils', 'version': '1:3.6-1'},
#  {'name': 'dirmngr', 'version': '2.2.4-1ubuntu1.2'},
#  {'name': 'distro-info-data', 'version': '0.37ubuntu0.5'},
#  {'name': 'dmidecode', 'version': '3.1-1'},
#  {'name': 'dmsetup', 'version': '2:1.02.145-4.1ubuntu3.18.04.1'},
#  {'name': 'dmz-cursor-theme', 'version': '0.4.5ubuntu1'},
#  {'name': 'dns-root-data', 'version': '2018013001'},
#  {'name': 'dnsmasq-base', 'version': '2.79-1'},
#  {'name': 'dnsutils', 'version': '1:9.11.3+dfsg-1ubuntu1.8'},
#  {'name': 'dosfstools', 'version': '4.1-1'},
#  {'name': 'dpkg', 'version': '1.19.0.5ubuntu2.1'},
#  {'name': 'e2fsprogs', 'version': '1.44.1-1ubuntu1.1'},
#  {'name': 'ed', 'version': '1.10-2.1'},
#  {'name': 'efibootmgr', 'version': '15-1'},
#  {'name': 'eject', 'version': '2.1.5+deb1+cvs20081104-13.2'},
#  {'name': 'emacsen-common', 'version': '2.0.8'},
#  {'name': 'enchant', 'version': '1.6.0-11.1'},
#  {'name': 'eog', 'version': '3.28.1-1'},
#  {'name': 'espeak-ng-data:amd64', 'version': '1.49.2+dfsg-1'},
#  {'name': 'evince', 'version': '3.28.4-0ubuntu1.2'},
#  {'name': 'evince-common', 'version': '3.28.4-0ubuntu1.2'},
#  {'name': 'evolution-data-server', 'version': '3.28.5-0ubuntu0.18.04.2'},
#  {'name': 'evolution-data-server-common',
#   'version': '3.28.5-0ubuntu0.18.04.2'},
#  {'name': 'example-content', 'version': '50'},
#  {'name': 'fdisk', 'version': '2.31.1-0.4ubuntu3.3'},
#  {'name': 'file', 'version': '1:5.32-2ubuntu0.2'},
#  {'name': 'file-roller', 'version': '3.28.0-1ubuntu1'},
#  {'name': 'findutils', 'version': '4.6.0+git+20170828-2'},
#  {'name': 'firefox', 'version': '69.0+build2-0ubuntu0.18.04.1'},
#  {'name': 'firefox-locale-en', 'version': '69.0+build2-0ubuntu0.18.04.1'},
#  {'name': 'fontconfig', 'version': '2.12.6-0ubuntu2'},
#  {'name': 'fontconfig-config', 'version': '2.12.6-0ubuntu2'},
#  {'name': 'fonts-beng', 'version': '2:1.2'},
#  {'name': 'fonts-beng-extra', 'version': '1.0-6ubuntu0.1'},
#  {'name': 'fonts-dejavu-core', 'version': '2.37-1'},
#  {'name': 'fonts-deva', 'version': '2:1.2'},
#  {'name': 'fonts-deva-extra', 'version': '3.0-4ubuntu0.1'},
#  {'name': 'fonts-droid-fallback', 'version': '1:6.0.1r16-1.1'},
#  {'name': 'fonts-freefont-ttf', 'version': '20120503-7'},
#  {'name': 'fonts-gargi', 'version': '2.0-4'},
#  {'name': 'fonts-gubbi', 'version': '1.3-3'},
#  {'name': 'fonts-gujr', 'version': '2:1.2'},
#  {'name': 'fonts-gujr-extra', 'version': '1.0-6ubuntu0.1'},
#  {'name': 'fonts-guru', 'version': '2:1.2'},
#  {'name': 'fonts-guru-extra', 'version': '2.0-4ubuntu0.1'},
#  {'name': 'fonts-indic', 'version': '2:1.2'},
#  {'name': 'fonts-kacst', 'version': '2.01+mry-14'},
#  {'name': 'fonts-kacst-one', 'version': '5.0+svn11846-9'},
#  {'name': 'fonts-kalapi', 'version': '1.0-2'},
#  {'name': 'fonts-khmeros-core', 'version': '5.0-7ubuntu1'},
#  {'name': 'fonts-knda', 'version': '2:1.2'},
#  {'name': 'fonts-lao', 'version': '0.0.20060226-9ubuntu1'},
#  {'name': 'fonts-liberation', 'version': '1:1.07.4-7~18.04.1'},
#  {'name': 'fonts-liberation2', 'version': '2.00.1-7~18.04.2'},
#  {'name': 'fonts-lklug-sinhala', 'version': '0.6-3'},
#  {'name': 'fonts-lohit-beng-assamese', 'version': '2.91.5-1'},
#  {'name': 'fonts-lohit-beng-bengali', 'version': '2.91.5-1'},
#  {'name': 'fonts-lohit-deva', 'version': '2.95.4-2'},
#  {'name': 'fonts-lohit-gujr', 'version': '2.92.4-2'},
#  {'name': 'fonts-lohit-guru', 'version': '2.91.2-1'},
#  {'name': 'fonts-lohit-knda', 'version': '2.5.4-1'},
#  {'name': 'fonts-lohit-mlym', 'version': '2.92.2-1'},
#  {'name': 'fonts-lohit-orya', 'version': '2.91.2-1'},
#  {'name': 'fonts-lohit-taml', 'version': '2.91.3-1'},
#  {'name': 'fonts-lohit-taml-classical', 'version': '2.5.4-1'},
#  {'name': 'fonts-lohit-telu', 'version': '2.5.5-1'},
#  {'name': 'fonts-mlym', 'version': '2:1.2'},
#  {'name': 'fonts-nakula', 'version': '1.0-3'},
#  {'name': 'fonts-navilu', 'version': '1.2-2'},
#  {'name': 'fonts-noto-cjk', 'version': '1:20190409+repack1-0ubuntu0.18.04'},
#  {'name': 'fonts-noto-color-emoji', 'version': '0~20180810-0ubuntu1'},
#  {'name': 'fonts-noto-mono', 'version': '20171026-2'},
#  {'name': 'fonts-opensymbol',
#   'version': '2:102.10+LibO6.0.7-0ubuntu0.18.04.9'},
#  {'name': 'fonts-orya', 'version': '2:1.2'},
#  {'name': 'fonts-orya-extra', 'version': '2.0-5ubuntu0.1'},
#  {'name': 'fonts-pagul', 'version': '1.0-7'},
#  {'name': 'fonts-sahadeva', 'version': '1.0-4'},
#  {'name': 'fonts-samyak-deva', 'version': '1.2.2-4'},
#  {'name': 'fonts-samyak-gujr', 'version': '1.2.2-4'},
#  {'name': 'fonts-samyak-mlym', 'version': '1.2.2-4'},
#  {'name': 'fonts-samyak-taml', 'version': '1.2.2-4'},
#  {'name': 'fonts-sarai', 'version': '1.0-2'},
#  {'name': 'fonts-sil-abyssinica', 'version': '1.500-1'},
#  {'name': 'fonts-sil-padauk', 'version': '3.003-1'},
#  {'name': 'fonts-smc', 'version': '1:7.0'},
#  {'name': 'fonts-smc-anjalioldlipi', 'version': '7.0-2'},
#  {'name': 'fonts-smc-chilanka', 'version': '1.2.0-2'},
#  {'name': 'fonts-smc-dyuthi', 'version': '2.0-1'},
#  {'name': 'fonts-smc-karumbi', 'version': '1.0-1'},
#  {'name': 'fonts-smc-keraleeyam', 'version': '2.0-1'},
#  {'name': 'fonts-smc-manjari', 'version': '1.5.1-1'},
#  {'name': 'fonts-smc-meera', 'version': '7.0-2'},
#  {'name': 'fonts-smc-rachana', 'version': '7.0-2'},
#  {'name': 'fonts-smc-raghumalayalamsans', 'version': '2.1.1-2'},
#  {'name': 'fonts-smc-suruma', 'version': '3.2.1-1'},
#  {'name': 'fonts-smc-uroob', 'version': '2.0-1'},
#  {'name': 'fonts-taml', 'version': '2:1.3'},
#  {'name': 'fonts-telu', 'version': '2:1.2'},
#  {'name': 'fonts-telu-extra', 'version': '2.0-4'},
#  {'name': 'fonts-thai-tlwg', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tibetan-machine', 'version': '1.901b-5'},
#  {'name': 'fonts-tlwg-garuda', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-garuda-ttf', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-kinnari', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-kinnari-ttf', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-laksaman', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-laksaman-ttf', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-loma', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-loma-ttf', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-mono', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-mono-ttf', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-norasi', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-norasi-ttf', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-purisa', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-purisa-ttf', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-sawasdee', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-sawasdee-ttf', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-typewriter', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-typewriter-ttf', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-typist', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-typist-ttf', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-typo', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-typo-ttf', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-umpush', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-umpush-ttf', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-waree', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-tlwg-waree-ttf', 'version': '1:0.6.4-2'},
#  {'name': 'fonts-ubuntu', 'version': '0.83-2'},
#  {'name': 'foomatic-db-compressed-ppds', 'version': '20180306-1'},
#  {'name': 'friendly-recovery', 'version': '0.2.38ubuntu1.1'},
#  {'name': 'ftp', 'version': '0.17-34'},
#  {'name': 'fuse', 'version': '2.9.7-1ubuntu1'},
#  {'name': 'fwupd', 'version': '1.0.9-0ubuntu2'},
#  {'name': 'fwupdate', 'version': '12-3bionic2'},
#  {'name': 'fwupdate-signed', 'version': '1.19bionic2+12-3bionic2'},
#  {'name': 'gcc-7-base:amd64', 'version': '7.4.0-1ubuntu1~18.04.1'},
#  {'name': 'gcc-8-base:amd64', 'version': '8.3.0-6ubuntu1~18.04.1'},
#  {'name': 'gcr', 'version': '3.28.0-1'},
#  {'name': 'gdb', 'version': '8.1-0ubuntu3'},
#  {'name': 'gdbserver', 'version': '8.1-0ubuntu3'},
#  {'name': 'gdisk', 'version': '1.0.3-1'},
#  {'name': 'gdm3', 'version': '3.28.3-0ubuntu18.04.4'},
#  {'name': 'gedit', 'version': '3.28.1-1ubuntu1.2'},
#  {'name': 'gedit-common', 'version': '3.28.1-1ubuntu1.2'},
#  {'name': 'genisoimage', 'version': '9:1.1.11-3ubuntu2'},
#  {'name': 'geoclue-2.0', 'version': '2.4.7-1ubuntu1'},
#  {'name': 'geoip-database', 'version': '20180315-1'},
#  {'name': 'gettext', 'version': '0.19.8.1-6ubuntu0.3'},
#  {'name': 'gettext-base', 'version': '0.19.8.1-6ubuntu0.3'},
#  {'name': 'ghostscript', 'version': '9.26~dfsg+0-0ubuntu0.18.04.11'},
#  {'name': 'ghostscript-x', 'version': '9.26~dfsg+0-0ubuntu0.18.04.11'},
#  {'name': 'gir1.2-accountsservice-1.0', 'version': '0.6.45-1ubuntu1'},
#  {'name': 'gir1.2-atk-1.0:amd64', 'version': '2.28.1-1'},
#  {'name': 'gir1.2-atspi-2.0:amd64', 'version': '2.28.0-1'},
#  {'name': 'gir1.2-dbusmenu-glib-0.4:amd64',
#   'version': '16.04.1+18.04.20171206-0ubuntu2'},
#  {'name': 'gir1.2-dee-1.0', 'version': '1.2.7+17.10.20170616-0ubuntu4'},
#  {'name': 'gir1.2-freedesktop:amd64', 'version': '1.56.1-1'},
#  {'name': 'gir1.2-gck-1:amd64', 'version': '3.28.0-1'},
#  {'name': 'gir1.2-gcr-3:amd64', 'version': '3.28.0-1'},
#  {'name': 'gir1.2-gdesktopenums-3.0:amd64', 'version': '3.28.0-1ubuntu1'},
#  {'name': 'gir1.2-gdkpixbuf-2.0:amd64', 'version': '2.36.11-2'},
#  {'name': 'gir1.2-gdm-1.0', 'version': '3.28.3-0ubuntu18.04.4'},
#  {'name': 'gir1.2-geoclue-2.0:amd64', 'version': '2.4.7-1ubuntu1'},
#  {'name': 'gir1.2-geocodeglib-1.0:amd64',
#   'version': '3.25.4.1-4ubuntu0.18.04.1'},
#  {'name': 'gir1.2-glib-2.0:amd64', 'version': '1.56.1-1'},
#  {'name': 'gir1.2-gmenu-3.0:amd64', 'version': '3.13.3-11ubuntu1.1'},
#  {'name': 'gir1.2-gnomebluetooth-1.0:amd64', 'version': '3.28.0-2ubuntu0.2'},
#  {'name': 'gir1.2-gnomedesktop-3.0:amd64', 'version': '3.28.2-0ubuntu1.5'},
#  {'name': 'gir1.2-goa-1.0:amd64', 'version': '3.28.0-0ubuntu2.1'},
#  {'name': 'gir1.2-gst-plugins-base-1.0:amd64',
#   'version': '1.14.5-0ubuntu1~18.04.1'},
#  {'name': 'gir1.2-gstreamer-1.0:amd64', 'version': '1.14.5-0ubuntu1~18.04.1'},
#  {'name': 'gir1.2-gtk-3.0:amd64', 'version': '3.22.30-1ubuntu4'},
#  {'name': 'gir1.2-gtksource-3.0:amd64', 'version': '3.24.7-1'},
#  {'name': 'gir1.2-gudev-1.0:amd64', 'version': '1:232-2'},
#  {'name': 'gir1.2-gweather-3.0:amd64', 'version': '3.28.2-1~ubuntu18.04.1'},
#  {'name': 'gir1.2-ibus-1.0:amd64', 'version': '1.5.17-3ubuntu4'},
#  {'name': 'gir1.2-javascriptcoregtk-4.0:amd64',
#   'version': '2.24.2-0ubuntu0.18.04.1'},
#  {'name': 'gir1.2-json-1.0:amd64', 'version': '1.4.2-3'},
#  {'name': 'gir1.2-mutter-2:amd64', 'version': '3.28.4-0ubuntu18.04.1'},
#  {'name': 'gir1.2-nm-1.0:amd64', 'version': '1.10.6-2ubuntu1.1'},
#  {'name': 'gir1.2-nma-1.0:amd64', 'version': '1.8.10-2ubuntu2'},
#  {'name': 'gir1.2-notify-0.7:amd64', 'version': '0.7.7-3'},
#  {'name': 'gir1.2-packagekitglib-1.0', 'version': '1.1.9-1ubuntu2.18.04.5'},
#  {'name': 'gir1.2-pango-1.0:amd64', 'version': '1.40.14-1ubuntu0.1'},
#  {'name': 'gir1.2-peas-1.0:amd64', 'version': '1.22.0-2'},
#  {'name': 'gir1.2-polkit-1.0', 'version': '0.105-20ubuntu0.18.04.5'},
#  {'name': 'gir1.2-rb-3.0:amd64', 'version': '3.4.2-4ubuntu1'},
#  {'name': 'gir1.2-rsvg-2.0:amd64', 'version': '2.40.20-2'},
#  {'name': 'gir1.2-secret-1:amd64', 'version': '0.18.6-1'},
#  {'name': 'gir1.2-snapd-1:amd64', 'version': '1.47-0ubuntu0.18.04.0'},
#  {'name': 'gir1.2-soup-2.4:amd64', 'version': '2.62.1-1ubuntu0.1'},
#  {'name': 'gir1.2-totem-1.0:amd64', 'version': '3.26.0-0ubuntu6.2'},
#  {'name': 'gir1.2-totemplparser-1.0:amd64', 'version': '3.26.0-1ubuntu2'},
#  {'name': 'gir1.2-udisks-2.0:amd64', 'version': '2.7.6-3ubuntu0.2'},
#  {'name': 'gir1.2-unity-5.0:amd64',
#   'version': '7.1.4+18.04.20180209.1-0ubuntu2'},
#  {'name': 'gir1.2-upowerglib-1.0:amd64', 'version': '0.99.7-2ubuntu0.18.04.1'},
#  {'name': 'gir1.2-vte-2.91:amd64', 'version': '0.52.2-1ubuntu1~18.04.2'},
#  {'name': 'gir1.2-webkit2-4.0:amd64', 'version': '2.24.2-0ubuntu0.18.04.1'},
#  {'name': 'gir1.2-wnck-3.0:amd64', 'version': '3.24.1-2'},
#  {'name': 'gjs', 'version': '1.52.5-0ubuntu18.04.1'},
#  {'name': 'gkbd-capplet', 'version': '3.26.0-3ubuntu0.18.04.1'},
#  {'name': 'glib-networking:amd64', 'version': '2.56.0-1'},
#  {'name': 'glib-networking-common', 'version': '2.56.0-1'},
#  {'name': 'glib-networking-services', 'version': '2.56.0-1'},
#  {'name': 'gnome-accessibility-themes', 'version': '3.28-1ubuntu1'},
#  {'name': 'gnome-bluetooth', 'version': '3.28.0-2ubuntu0.2'},
#  {'name': 'gnome-calendar', 'version': '3.28.2-0ubuntu0.18.04.1'},
#  {'name': 'gnome-control-center', 'version': '1:3.28.2-0ubuntu0.18.04.4'},
#  {'name': 'gnome-control-center-data', 'version': '1:3.28.2-0ubuntu0.18.04.4'},
#  {'name': 'gnome-control-center-faces',
#   'version': '1:3.28.2-0ubuntu0.18.04.4'},
#  {'name': 'gnome-desktop3-data', 'version': '3.28.2-0ubuntu1.5'},
#  {'name': 'gnome-disk-utility', 'version': '3.28.3-0ubuntu1~18.04.1'},
#  {'name': 'gnome-font-viewer', 'version': '3.28.0-1'},
#  {'name': 'gnome-getting-started-docs', 'version': '3.28.2-0ubuntu0.1'},
#  {'name': 'gnome-initial-setup', 'version': '3.28.0-2ubuntu6.16.04.4'},
#  {'name': 'gnome-keyring', 'version': '3.28.0.2-1ubuntu1.18.04.1'},
#  {'name': 'gnome-keyring-pkcs11:amd64',
#   'version': '3.28.0.2-1ubuntu1.18.04.1'},
#  {'name': 'gnome-mahjongg', 'version': '1:3.22.0-3'},
#  {'name': 'gnome-menus', 'version': '3.13.3-11ubuntu1.1'},
#  {'name': 'gnome-mines', 'version': '1:3.28.0-1ubuntu1'},
#  {'name': 'gnome-online-accounts', 'version': '3.28.0-0ubuntu2.1'},
#  {'name': 'gnome-power-manager', 'version': '3.26.0-1'},
#  {'name': 'gnome-screenshot', 'version': '3.25.0-0ubuntu2'},
#  {'name': 'gnome-session-bin', 'version': '3.28.1-0ubuntu3'},
#  {'name': 'gnome-session-canberra', 'version': '0.30-5ubuntu1'},
#  {'name': 'gnome-session-common', 'version': '3.28.1-0ubuntu3'},
#  {'name': 'gnome-settings-daemon', 'version': '3.28.1-0ubuntu1.3'},
#  {'name': 'gnome-settings-daemon-schemas', 'version': '3.28.1-0ubuntu1.3'},
#  {'name': 'gnome-shell', 'version': '3.28.4-0ubuntu18.04.1'},
#  {'name': 'gnome-shell-common', 'version': '3.28.4-0ubuntu18.04.1'},
#  {'name': 'gnome-shell-extension-appindicator', 'version': '18.04.1'},
#  {'name': 'gnome-shell-extension-ubuntu-dock',
#   'version': '0.9.1ubuntu18.04.3'},
#  {'name': 'gnome-software', 'version': '3.28.1-0ubuntu4.18.04.10'},
#  {'name': 'gnome-software-common', 'version': '3.28.1-0ubuntu4.18.04.10'},
#  {'name': 'gnome-software-plugin-snap', 'version': '3.28.1-0ubuntu4.18.04.10'},
#  {'name': 'gnome-startup-applications', 'version': '3.28.1-0ubuntu3'},
#  {'name': 'gnome-sudoku', 'version': '1:3.28.0-1'},
#  {'name': 'gnome-terminal', 'version': '3.28.2-1ubuntu1~18.04.1'},
#  {'name': 'gnome-terminal-data', 'version': '3.28.2-1ubuntu1~18.04.1'},
#  {'name': 'gnome-themes-extra:amd64', 'version': '3.28-1ubuntu1'},
#  {'name': 'gnome-themes-extra-data', 'version': '3.28-1ubuntu1'},
#  {'name': 'gnome-todo', 'version': '3.28.1-1'},
#  {'name': 'gnome-todo-common', 'version': '3.28.1-1'},
#  {'name': 'gnome-user-docs', 'version': '3.28.2+git20180715-0ubuntu0.1'},
#  {'name': 'gnome-user-guide', 'version': '3.28.2+git20180715-0ubuntu0.1'},
#  {'name': 'gnome-video-effects', 'version': '0.4.3-1ubuntu1'},
#  {'name': 'gnupg', 'version': '2.2.4-1ubuntu1.2'},
#  {'name': 'gnupg-l10n', 'version': '2.2.4-1ubuntu1.2'},
#  {'name': 'gnupg-utils', 'version': '2.2.4-1ubuntu1.2'},
#  {'name': 'gpg', 'version': '2.2.4-1ubuntu1.2'},
#  {'name': 'gpg-agent', 'version': '2.2.4-1ubuntu1.2'},
#  {'name': 'gpg-wks-client', 'version': '2.2.4-1ubuntu1.2'},
#  {'name': 'gpg-wks-server', 'version': '2.2.4-1ubuntu1.2'},
#  {'name': 'gpgconf', 'version': '2.2.4-1ubuntu1.2'},
#  {'name': 'gpgsm', 'version': '2.2.4-1ubuntu1.2'},
#  {'name': 'gpgv', 'version': '2.2.4-1ubuntu1.2'},
#  {'name': 'grep', 'version': '3.1-2'},
#  {'name': 'grilo-plugins-0.3-base:amd64', 'version': '0.3.5-1ubuntu1'},
#  {'name': 'groff-base', 'version': '1.22.3-10'},
#  {'name': 'grub-common', 'version': '2.02-2ubuntu8.13'},
#  {'name': 'grub-gfxpayload-lists', 'version': '0.7'},
#  {'name': 'grub-pc', 'version': '2.02-2ubuntu8.13'},
#  {'name': 'grub-pc-bin', 'version': '2.02-2ubuntu8.13'},
#  {'name': 'grub2-common', 'version': '2.02-2ubuntu8.13'},
#  {'name': 'gsettings-desktop-schemas', 'version': '3.28.0-1ubuntu1'},
#  {'name': 'gsettings-ubuntu-schemas',
#   'version': '0.0.7+17.10.20170922-0ubuntu1'},
#  {'name': 'gsfonts', 'version': '1:8.11+urwcyr1.0.7~pre44-4.4'},
#  {'name': 'gstreamer1.0-alsa:amd64', 'version': '1.14.5-0ubuntu1~18.04.1'},
#  {'name': 'gstreamer1.0-clutter-3.0:amd64', 'version': '3.0.26-1'},
#  {'name': 'gstreamer1.0-gl:amd64', 'version': '1.14.5-0ubuntu1~18.04.1'},
#  {'name': 'gstreamer1.0-gtk3:amd64', 'version': '1.14.5-0ubuntu1~18.04.1'},
#  {'name': 'gstreamer1.0-packagekit', 'version': '1.1.9-1ubuntu2.18.04.5'},
#  {'name': 'gstreamer1.0-plugins-base:amd64',
#   'version': '1.14.5-0ubuntu1~18.04.1'},
#  {'name': 'gstreamer1.0-plugins-base-apps',
#   'version': '1.14.5-0ubuntu1~18.04.1'},
#  {'name': 'gstreamer1.0-plugins-good:amd64',
#   'version': '1.14.5-0ubuntu1~18.04.1'},
#  {'name': 'gstreamer1.0-pulseaudio:amd64',
#   'version': '1.14.5-0ubuntu1~18.04.1'},
#  {'name': 'gstreamer1.0-tools', 'version': '1.14.5-0ubuntu1~18.04.1'},
#  {'name': 'gstreamer1.0-x:amd64', 'version': '1.14.5-0ubuntu1~18.04.1'},
#  {'name': 'gtk-update-icon-cache', 'version': '3.22.30-1ubuntu4'},
#  {'name': 'gtk2-engines-murrine:amd64', 'version': '0.98.2-2ubuntu1'},
#  {'name': 'gtk2-engines-pixbuf:amd64', 'version': '2.24.32-1ubuntu1'},
#  {'name': 'guile-2.0-libs:amd64', 'version': '2.0.13+1-5ubuntu0.1'},
#  {'name': 'gvfs:amd64', 'version': '1.36.1-0ubuntu1.3.3'},
#  {'name': 'gvfs-backends', 'version': '1.36.1-0ubuntu1.3.3'},
#  {'name': 'gvfs-bin', 'version': '1.36.1-0ubuntu1.3.3'},
#  {'name': 'gvfs-common', 'version': '1.36.1-0ubuntu1.3.3'},
#  {'name': 'gvfs-daemons', 'version': '1.36.1-0ubuntu1.3.3'},
#  {'name': 'gvfs-fuse', 'version': '1.36.1-0ubuntu1.3.3'},
#  {'name': 'gvfs-libs:amd64', 'version': '1.36.1-0ubuntu1.3.3'},
#  {'name': 'gzip', 'version': '1.6-5ubuntu1'},
#  {'name': 'hdparm', 'version': '9.54+ds-1'},
#  {'name': 'hicolor-icon-theme', 'version': '0.17-2'},
#  {'name': 'hostname', 'version': '3.20'},
#  {'name': 'hplip', 'version': '3.17.10+repack0-5'},
#  {'name': 'hplip-data', 'version': '3.17.10+repack0-5'},
#  {'name': 'humanity-icon-theme', 'version': '0.6.15'},
#  {'name': 'hunspell-en-us', 'version': '1:2017.08.24'},
#  {'name': 'hyphen-en-us', 'version': '2.8.8-5'},
#  {'name': 'ibus', 'version': '1.5.17-3ubuntu4'},
#  {'name': 'ibus-gtk:amd64', 'version': '1.5.17-3ubuntu4'},
#  {'name': 'ibus-gtk3:amd64', 'version': '1.5.17-3ubuntu4'},
#  {'name': 'ibus-table', 'version': '1.9.14-3'},
#  {'name': 'ifupdown', 'version': '0.8.17ubuntu1.1'},
#  {'name': 'iio-sensor-proxy', 'version': '2.4-2'},
#  {'name': 'im-config', 'version': '0.34-1ubuntu1.3'},
#  {'name': 'imagemagick', 'version': '8:6.9.7.4+dfsg-16ubuntu6.7'},
#  {'name': 'imagemagick-6-common', 'version': '8:6.9.7.4+dfsg-16ubuntu6.7'},
#  {'name': 'imagemagick-6.q16', 'version': '8:6.9.7.4+dfsg-16ubuntu6.7'},
#  {'name': 'info', 'version': '6.5.0.dfsg.1-2'},
#  {'name': 'init', 'version': '1.51'},
#  {'name': 'init-system-helpers', 'version': '1.51'},
#  {'name': 'initramfs-tools', 'version': '0.130ubuntu3.8'},
#  {'name': 'initramfs-tools-bin', 'version': '0.130ubuntu3.8'},
#  {'name': 'initramfs-tools-core', 'version': '0.130ubuntu3.8'},
#  {'name': 'inputattach', 'version': '1:1.6.0-2'},
#  {'name': 'install-info', 'version': '6.5.0.dfsg.1-2'},
#  {'name': 'intel-microcode', 'version': '3.20190618.0ubuntu0.18.04.1'},
#  {'name': 'intltool-debian', 'version': '0.35.0+20060710.4'},
#  {'name': 'ippusbxd', 'version': '1.32-2'},
#  {'name': 'iproute2', 'version': '4.15.0-2ubuntu1'},
#  {'name': 'iptables', 'version': '1.6.1-2ubuntu2'},
#  {'name': 'iputils-arping', 'version': '3:20161105-1ubuntu3'},
#  {'name': 'iputils-ping', 'version': '3:20161105-1ubuntu3'},
#  {'name': 'iputils-tracepath', 'version': '3:20161105-1ubuntu3'},
#  {'name': 'irqbalance', 'version': '1.3.0-0.1ubuntu0.18.04.1'},
#  {'name': 'isc-dhcp-client', 'version': '4.3.5-3ubuntu7.1'},
#  {'name': 'isc-dhcp-common', 'version': '4.3.5-3ubuntu7.1'},
#  {'name': 'iso-codes', 'version': '3.79-1'},
#  {'name': 'iucode-tool', 'version': '2.3.1-1'},
#  {'name': 'iw', 'version': '4.14-0.1'},
#  {'name': 'kbd', 'version': '2.0.4-2ubuntu1'},
#  {'name': 'kerneloops', 'version': '0.12+git20140509-6ubuntu2'},
#  {'name': 'keyboard-configuration', 'version': '1.178ubuntu2.9'},
#  {'name': 'klibc-utils', 'version': '2.0.4-9ubuntu2'},
#  {'name': 'kmod', 'version': '24-1ubuntu3.2'},
#  {'name': 'krb5-locales', 'version': '1.16-2ubuntu0.1'},
#  {'name': 'language-pack-en', 'version': '1:18.04+20190718'},
#  {'name': 'language-pack-en-base', 'version': '1:18.04+20180712'},
#  {'name': 'language-pack-gnome-en', 'version': '1:18.04+20190718'},
#  {'name': 'language-pack-gnome-en-base', 'version': '1:18.04+20180712'},
#  {'name': 'language-selector-common', 'version': '0.188.3'},
#  {'name': 'language-selector-gnome', 'version': '0.188.3'},
#  {'name': 'laptop-detect', 'version': '0.16'},
#  {'name': 'less', 'version': '487-0.1'},
#  {'name': 'libaa1:amd64', 'version': '1.4p5-44build2'},
#  {'name': 'libabw-0.1-1:amd64', 'version': '0.1.2-1ubuntu1'},
#  {'name': 'libaccountsservice0:amd64', 'version': '0.6.45-1ubuntu1'},
#  {'name': 'libacl1:amd64', 'version': '2.2.52-3build1'},
#  {'name': 'libao-common', 'version': '1.2.2+20180113-1ubuntu1'},
#  {'name': 'libao4:amd64', 'version': '1.2.2+20180113-1ubuntu1'},
#  {'name': 'libapparmor1:amd64', 'version': '2.12-4ubuntu5.1'},
#  {'name': 'libappindicator3-1',
#   'version': '12.10.1+18.04.20180322.1-0ubuntu1'},
#  {'name': 'libappstream-glib8:amd64', 'version': '0.7.7-2'},
#  {'name': 'libappstream4:amd64', 'version': '0.12.0-3ubuntu1'},
#  {'name': 'libapt-inst2.0:amd64', 'version': '1.6.11'},
#  {'name': 'libapt-pkg-perl', 'version': '0.1.33build1'},
#  {'name': 'libapt-pkg5.0:amd64', 'version': '1.6.11'},
#  {'name': 'libarchive-zip-perl', 'version': '1.60-1ubuntu0.1'},
#  {'name': 'libarchive13:amd64', 'version': '3.2.2-3.1ubuntu0.3'},
#  {'name': 'libargon2-0:amd64', 'version': '0~20161029-1.1'},
#  {'name': 'libart-2.0-2:amd64', 'version': '2.3.21-3'},
#  {'name': 'libasn1-8-heimdal:amd64', 'version': '7.5.0+dfsg-1'},
#  {'name': 'libasound2:amd64', 'version': '1.1.3-5ubuntu0.2'},
#  {'name': 'libasound2-data', 'version': '1.1.3-5ubuntu0.2'},
#  {'name': 'libasound2-plugins:amd64', 'version': '1.1.1-1ubuntu1'},
#  {'name': 'libaspell15:amd64', 'version': '0.60.7~20110707-4'},
#  {'name': 'libassuan0:amd64', 'version': '2.5.1-2'},
#  {'name': 'libasyncns0:amd64', 'version': '0.8-6'},
#  {'name': 'libatasmart4:amd64', 'version': '0.19-4'},
#  {'name': 'libatk-adaptor:amd64', 'version': '2.26.2-1'},
#  {'name': 'libatk-bridge2.0-0:amd64', 'version': '2.26.2-1'},
#  {'name': 'libatk1.0-0:amd64', 'version': '2.28.1-1'},
#  {'name': 'libatk1.0-data', 'version': '2.28.1-1'},
#  {'name': 'libatm1:amd64', 'version': '1:2.5.1-2build1'},
#  {'name': 'libatspi2.0-0:amd64', 'version': '2.28.0-1'},
#  {'name': 'libattr1:amd64', 'version': '1:2.4.47-2build1'},
#  {'name': 'libaudio2:amd64', 'version': '1.9.4-6'},
#  {'name': 'libaudit-common', 'version': '1:2.8.2-1ubuntu1'},
#  {'name': 'libaudit1:amd64', 'version': '1:2.8.2-1ubuntu1'},
#  {'name': 'libauthen-sasl-perl', 'version': '2.1600-1'},
#  {'name': 'libavahi-client3:amd64', 'version': '0.7-3.1ubuntu1.2'},
#  {'name': 'libavahi-common-data:amd64', 'version': '0.7-3.1ubuntu1.2'},
#  {'name': 'libavahi-common3:amd64', 'version': '0.7-3.1ubuntu1.2'},
#  {'name': 'libavahi-core7:amd64', 'version': '0.7-3.1ubuntu1.2'},
#  {'name': 'libavahi-glib1:amd64', 'version': '0.7-3.1ubuntu1.2'},
#  {'name': 'libavahi-ui-gtk3-0:amd64', 'version': '0.7-3.1ubuntu1.2'},
#  {'name': 'libavc1394-0:amd64', 'version': '0.5.4-4build1'},
#  {'name': 'libbabeltrace1:amd64', 'version': '1.5.5-1'},
#  {'name': 'libbind9-160:amd64', 'version': '1:9.11.3+dfsg-1ubuntu1.8'},
#  {'name': 'libbinutils:amd64', 'version': '2.30-21ubuntu1~18.04.2'},
#  {'name': 'libblkid1:amd64', 'version': '2.31.1-0.4ubuntu3.3'},
#  {'name': 'libblockdev-crypto2:amd64', 'version': '2.16-2'},
#  {'name': 'libblockdev-fs2:amd64', 'version': '2.16-2'},
#  {'name': 'libblockdev-loop2:amd64', 'version': '2.16-2'},
#  {'name': 'libblockdev-part-err2:amd64', 'version': '2.16-2'},
#  {'name': 'libblockdev-part2:amd64', 'version': '2.16-2'},
#  {'name': 'libblockdev-swap2:amd64', 'version': '2.16-2'},
#  {'name': 'libblockdev-utils2:amd64', 'version': '2.16-2'},
#  {'name': 'libblockdev2:amd64', 'version': '2.16-2'},
#  {'name': 'libbluetooth3:amd64', 'version': '5.48-0ubuntu3.1'},
#  {'name': 'libboost-date-time1.65.1:amd64', 'version': '1.65.1+dfsg-0ubuntu5'},
#  {'name': 'libboost-filesystem1.65.1:amd64',
#   'version': '1.65.1+dfsg-0ubuntu5'},
#  {'name': 'libboost-iostreams1.65.1:amd64', 'version': '1.65.1+dfsg-0ubuntu5'},
#  {'name': 'libboost-locale1.65.1:amd64', 'version': '1.65.1+dfsg-0ubuntu5'},
#  {'name': 'libboost-system1.65.1:amd64', 'version': '1.65.1+dfsg-0ubuntu5'},
#  {'name': 'libboost-thread1.65.1:amd64', 'version': '1.65.1+dfsg-0ubuntu5'},
#  {'name': 'libbrlapi0.6:amd64', 'version': '5.5-4ubuntu2.0.1'},
#  {'name': 'libbrotli1:amd64', 'version': '1.0.3-1ubuntu1.2'},
#  {'name': 'libbsd0:amd64', 'version': '0.8.7-1'},
#  {'name': 'libbz2-1.0:amd64', 'version': '1.0.6-8.1ubuntu0.2'},
#  {'name': 'libc-bin', 'version': '2.27-3ubuntu1'},
#  {'name': 'libc6:amd64', 'version': '2.27-3ubuntu1'},
#  {'name': 'libc6-dbg:amd64', 'version': '2.27-3ubuntu1'},
#  {'name': 'libcaca0:amd64', 'version': '0.99.beta19-2ubuntu0.18.04.1'},
#  {'name': 'libcairo-gobject-perl', 'version': '1.004-2build3'},
#  {'name': 'libcairo-gobject2:amd64', 'version': '1.15.10-2ubuntu0.1'},
#  {'name': 'libcairo-perl', 'version': '1.106-2build2'},
#  {'name': 'libcairo2:amd64', 'version': '1.15.10-2ubuntu0.1'},
#  {'name': 'libcamel-1.2-61:amd64', 'version': '3.28.5-0ubuntu0.18.04.2'},
#  {'name': 'libcanberra-gtk3-0:amd64', 'version': '0.30-5ubuntu1'},
#  {'name': 'libcanberra-gtk3-module:amd64', 'version': '0.30-5ubuntu1'},
#  {'name': 'libcanberra-pulse:amd64', 'version': '0.30-5ubuntu1'},
#  {'name': 'libcanberra0:amd64', 'version': '0.30-5ubuntu1'},
#  {'name': 'libcap-ng0:amd64', 'version': '0.7.7-3.1'},
#  {'name': 'libcap2:amd64', 'version': '1:2.25-1.2'},
#  {'name': 'libcap2-bin', 'version': '1:2.25-1.2'},
#  {'name': 'libcc1-0:amd64', 'version': '8.3.0-6ubuntu1~18.04.1'},
#  {'name': 'libcdio-cdda2:amd64', 'version': '10.2+0.94+2-2build1'},
#  {'name': 'libcdio-paranoia2:amd64', 'version': '10.2+0.94+2-2build1'},
#  {'name': 'libcdio17:amd64', 'version': '1.0.0-2ubuntu2'},
#  {'name': 'libcdparanoia0:amd64', 'version': '3.10.2+debian-13'},
#  {'name': 'libcdr-0.1-1:amd64', 'version': '0.1.4-1build1'},
#  {'name': 'libcgi-fast-perl', 'version': '1:2.13-1'},
#  {'name': 'libcgi-pm-perl', 'version': '4.38-1'},
#  {'name': 'libcheese-gtk25:amd64', 'version': '3.28.0-1ubuntu1'},
#  {'name': 'libcheese8:amd64', 'version': '3.28.0-1ubuntu1'},
#  {'name': 'libclass-accessor-perl', 'version': '0.51-1'},
#  {'name': 'libclone-perl', 'version': '0.39-1'},
#  {'name': 'libclucene-contribs1v5:amd64', 'version': '2.3.3.4+dfsg-1'},
#  {'name': 'libclucene-core1v5:amd64', 'version': '2.3.3.4+dfsg-1'},
#  {'name': 'libclutter-1.0-0:amd64', 'version': '1.26.2+dfsg-4'},
#  {'name': 'libclutter-1.0-common', 'version': '1.26.2+dfsg-4'},
#  {'name': 'libclutter-gst-3.0-0:amd64', 'version': '3.0.26-1'},
#  {'name': 'libclutter-gtk-1.0-0:amd64', 'version': '1.8.4-3'},
#  {'name': 'libcmis-0.5-5v5', 'version': '0.5.1+git20160603-3build2'},
#  {'name': 'libcogl-common', 'version': '1.22.2-3ubuntu1'},
#  {'name': 'libcogl-pango20:amd64', 'version': '1.22.2-3ubuntu1'},
#  {'name': 'libcogl-path20:amd64', 'version': '1.22.2-3ubuntu1'},
#  {'name': 'libcogl20:amd64', 'version': '1.22.2-3ubuntu1'},
#  {'name': 'libcolamd2:amd64', 'version': '1:5.1.2-2'},
#  {'name': 'libcolord-gtk1:amd64', 'version': '0.1.26-2'},
#  {'name': 'libcolord2:amd64', 'version': '1.3.3-2build1'},
#  {'name': 'libcolorhug2:amd64', 'version': '1.3.3-2build1'},
#  {'name': 'libcom-err2:amd64', 'version': '1.44.1-1ubuntu1.1'},
#  {'name': 'libcrack2:amd64', 'version': '2.9.2-5build1'},
#  {'name': 'libcroco3:amd64', 'version': '0.6.12-2'},
#  {'name': 'libcryptsetup12:amd64', 'version': '2:2.0.2-1ubuntu1.1'},
#  {'name': 'libcups2:amd64', 'version': '2.2.7-1ubuntu2.7'},
#  {'name': 'libcupscgi1:amd64', 'version': '2.2.7-1ubuntu2.7'},
#  {'name': 'libcupsfilters1:amd64', 'version': '1.20.2-0ubuntu3.1'},
#  {'name': 'libcupsimage2:amd64', 'version': '2.2.7-1ubuntu2.7'},
#  {'name': 'libcupsmime1:amd64', 'version': '2.2.7-1ubuntu2.7'},
#  {'name': 'libcupsppdc1:amd64', 'version': '2.2.7-1ubuntu2.7'},
#  {'name': 'libcurl3-gnutls:amd64', 'version': '7.58.0-2ubuntu3.7'},
#  {'name': 'libdaemon0:amd64', 'version': '0.14-6'},
#  {'name': 'libdata-dump-perl', 'version': '1.23-1'},
#  {'name': 'libdatrie1:amd64', 'version': '0.2.10-7'},
#  {'name': 'libdazzle-1.0-0:amd64', 'version': '3.28.1-1'},
#  {'name': 'libdb5.3:amd64', 'version': '5.3.28-13.1ubuntu1.1'},
#  {'name': 'libdbus-1-3:amd64', 'version': '1.12.2-1ubuntu1.1'},
#  {'name': 'libdbus-glib-1-2:amd64', 'version': '0.110-2'},
#  {'name': 'libdbusmenu-glib4:amd64',
#   'version': '16.04.1+18.04.20171206-0ubuntu2'},
#  {'name': 'libdbusmenu-gtk3-4:amd64',
#   'version': '16.04.1+18.04.20171206-0ubuntu2'},
#  {'name': 'libdbusmenu-gtk4:amd64',
#   'version': '16.04.1+18.04.20171206-0ubuntu2'},
#  {'name': 'libdconf1:amd64', 'version': '0.26.0-2ubuntu3'},
#  {'name': 'libdebconfclient0:amd64', 'version': '0.213ubuntu1'},
#  {'name': 'libdee-1.0-4:amd64', 'version': '1.2.7+17.10.20170616-0ubuntu4'},
#  {'name': 'libdevmapper1.02.1:amd64',
#   'version': '2:1.02.145-4.1ubuntu3.18.04.1'},
#  {'name': 'libdigest-hmac-perl', 'version': '1.03+dfsg-1'},
#  {'name': 'libdjvulibre-text', 'version': '3.5.27.1-8'},
#  {'name': 'libdjvulibre21:amd64', 'version': '3.5.27.1-8'},
#  {'name': 'libdmapsharing-3.0-2:amd64', 'version': '2.9.39-2'},
#  {'name': 'libdns-export1100', 'version': '1:9.11.3+dfsg-1ubuntu1.8'},
#  {'name': 'libdns1100:amd64', 'version': '1:9.11.3+dfsg-1ubuntu1.8'},
#  {'name': 'libdotconf0:amd64', 'version': '1.3-0.3fakesync1'},
#  {'name': 'libdpkg-perl', 'version': '1.19.0.5ubuntu2.1'},
#  {'name': 'libdrm-amdgpu1:amd64', 'version': '2.4.97-1ubuntu1~18.04.1'},
#  {'name': 'libdrm-common', 'version': '2.4.97-1ubuntu1~18.04.1'},
#  {'name': 'libdrm-intel1:amd64', 'version': '2.4.97-1ubuntu1~18.04.1'},
#  {'name': 'libdrm-nouveau2:amd64', 'version': '2.4.97-1ubuntu1~18.04.1'},
#  {'name': 'libdrm-radeon1:amd64', 'version': '2.4.97-1ubuntu1~18.04.1'},
#  {'name': 'libdrm2:amd64', 'version': '2.4.97-1ubuntu1~18.04.1'},
#  {'name': 'libdv4:amd64', 'version': '1.0.0-11'},
#  {'name': 'libdw1:amd64', 'version': '0.170-0.4ubuntu0.1'},
#  {'name': 'libe-book-0.1-1:amd64', 'version': '0.1.3-1'},
#  {'name': 'libebackend-1.2-10:amd64', 'version': '3.28.5-0ubuntu0.18.04.2'},
#  {'name': 'libebook-1.2-19:amd64', 'version': '3.28.5-0ubuntu0.18.04.2'},
#  {'name': 'libebook-contacts-1.2-2:amd64',
#   'version': '3.28.5-0ubuntu0.18.04.2'},
#  {'name': 'libecal-1.2-19:amd64', 'version': '3.28.5-0ubuntu0.18.04.2'},
#  {'name': 'libedata-book-1.2-25:amd64', 'version': '3.28.5-0ubuntu0.18.04.2'},
#  {'name': 'libedata-cal-1.2-28:amd64', 'version': '3.28.5-0ubuntu0.18.04.2'},
#  {'name': 'libedataserver-1.2-23:amd64', 'version': '3.28.5-0ubuntu0.18.04.2'},
#  {'name': 'libedataserverui-1.2-2:amd64',
#   'version': '3.28.5-0ubuntu0.18.04.2'},
#  {'name': 'libedit2:amd64', 'version': '3.1-20170329-1'},
#  {'name': 'libefiboot1:amd64', 'version': '34-1'},
#  {'name': 'libefivar1:amd64', 'version': '34-1'},
#  {'name': 'libegl-mesa0:amd64', 'version': '19.0.2-1ubuntu1.1~18.04.2'},
#  {'name': 'libegl1:amd64', 'version': '1.0.0-2ubuntu2.3'},
#  {'name': 'libegl1-mesa:amd64', 'version': '19.0.2-1ubuntu1.1~18.04.2'},
#  {'name': 'libelf1:amd64', 'version': '0.170-0.4ubuntu0.1'},
#  {'name': 'libemail-valid-perl', 'version': '1.202-1'},
#  {'name': 'libenchant1c2a:amd64', 'version': '1.6.0-11.1'},
#  {'name': 'libencode-locale-perl', 'version': '1.05-1'},
#  {'name': 'libeot0:amd64', 'version': '0.01-5'},
#  {'name': 'libepoxy0:amd64', 'version': '1.4.3-1'},
#  {'name': 'libepubgen-0.1-1:amd64', 'version': '0.1.0-2ubuntu1'},
#  {'name': 'libespeak-ng1:amd64', 'version': '1.49.2+dfsg-1'},
#  {'name': 'libestr0:amd64', 'version': '0.1.10-2.1'},
#  {'name': 'libetonyek-0.1-1:amd64', 'version': '0.1.7-3'},
#  {'name': 'libevdev2:amd64', 'version': '1.5.8+dfsg-1'},
#  {'name': 'libevdocument3-4:amd64', 'version': '3.28.4-0ubuntu1.2'},
#  {'name': 'libevent-2.1-6:amd64', 'version': '2.1.8-stable-4build1'},
#  {'name': 'libevview3-3:amd64', 'version': '3.28.4-0ubuntu1.2'},
#  {'name': 'libexempi3:amd64', 'version': '2.4.5-2'},
#  {'name': 'libexif12:amd64', 'version': '0.6.21-4'},
#  {'name': 'libexiv2-14:amd64', 'version': '0.25-3.1ubuntu0.18.04.3'},
#  {'name': 'libexpat1:amd64', 'version': '2.2.5-3ubuntu0.1'},
#  {'name': 'libexporter-tiny-perl', 'version': '1.000000-2'},
#  {'name': 'libext2fs2:amd64', 'version': '1.44.1-1ubuntu1.1'},
#  {'name': 'libexttextcat-2.0-0:amd64', 'version': '3.4.5-1'},
#  {'name': 'libexttextcat-data', 'version': '3.4.5-1'},
#  {'name': 'libfastjson4:amd64', 'version': '0.99.8-2'},
#  {'name': 'libfcgi-perl', 'version': '0.78-2build1'},
#  {'name': 'libfdisk1:amd64', 'version': '2.31.1-0.4ubuntu3.3'},
#  {'name': 'libffi6:amd64', 'version': '3.2.1-8'},
#  {'name': 'libfftw3-double3:amd64', 'version': '3.3.7-1'},
#  {'name': 'libfftw3-single3:amd64', 'version': '3.3.7-1'},
#  {'name': 'libfile-basedir-perl', 'version': '0.07-1'},
#  {'name': 'libfile-copy-recursive-perl', 'version': '0.40-1'},
#  {'name': 'libfile-desktopentry-perl', 'version': '0.22-1'},
#  {'name': 'libfile-fcntllock-perl', 'version': '0.22-3build2'},
#  {'name': 'libfile-listing-perl', 'version': '6.04-1'},
#  {'name': 'libfile-mimeinfo-perl', 'version': '0.28-1'},
#  {'name': 'libflac8:amd64', 'version': '1.3.2-1'},
#  {'name': 'libfont-afm-perl', 'version': '1.20-2'},
#  {'name': 'libfontconfig1:amd64', 'version': '2.12.6-0ubuntu2'},
#  {'name': 'libfontembed1:amd64', 'version': '1.20.2-0ubuntu3.1'},
#  {'name': 'libfontenc1:amd64', 'version': '1:1.1.3-1'},
#  {'name': 'libfreehand-0.1-1', 'version': '0.1.2-2'},
#  {'name': 'libfreerdp-client2-2:amd64',
#   'version': '2.0.0~git20170725.1.1648deb+dfsg1-7ubuntu0.1'},
#  {'name': 'libfreerdp2-2:amd64',
#   'version': '2.0.0~git20170725.1.1648deb+dfsg1-7ubuntu0.1'},
#  {'name': 'libfreetype6:amd64', 'version': '2.8.1-2ubuntu2'},
#  {'name': 'libfribidi0:amd64', 'version': '0.19.7-2'},
#  {'name': 'libfuse2:amd64', 'version': '2.9.7-1ubuntu1'},
#  {'name': 'libfwup1:amd64', 'version': '12-3bionic2'},
#  {'name': 'libfwupd2:amd64', 'version': '1.0.9-0ubuntu2'},
#  {'name': 'libgail-3-0:amd64', 'version': '3.22.30-1ubuntu4'},
#  {'name': 'libgail-common:amd64', 'version': '2.24.32-1ubuntu1'},
#  {'name': 'libgail18:amd64', 'version': '2.24.32-1ubuntu1'},
#  {'name': 'libgbm1:amd64', 'version': '19.0.2-1ubuntu1.1~18.04.2'},
#  {'name': 'libgc1c2:amd64', 'version': '1:7.4.2-8ubuntu1'},
#  {'name': 'libgcab-1.0-0:amd64', 'version': '1.1-2'},
#  {'name': 'libgcc1:amd64', 'version': '1:8.3.0-6ubuntu1~18.04.1'},
#  {'name': 'libgck-1-0:amd64', 'version': '3.28.0-1'},
#  {'name': 'libgcr-base-3-1:amd64', 'version': '3.28.0-1'},
#  {'name': 'libgcr-ui-3-1:amd64', 'version': '3.28.0-1'},
#  {'name': 'libgcrypt20:amd64', 'version': '1.8.1-4ubuntu1.1'},
#  {'name': 'libgd3:amd64', 'version': '2.2.5-4ubuntu0.3'},
#  {'name': 'libgdata-common', 'version': '0.17.9-2'},
#  {'name': 'libgdata22:amd64', 'version': '0.17.9-2'},
#  {'name': 'libgdbm-compat4:amd64', 'version': '1.14.1-6'},
#  {'name': 'libgdbm5:amd64', 'version': '1.14.1-6'},
#  {'name': 'libgdk-pixbuf2.0-0:amd64', 'version': '2.36.11-2'},
#  {'name': 'libgdk-pixbuf2.0-bin', 'version': '2.36.11-2'},
#  {'name': 'libgdk-pixbuf2.0-common', 'version': '2.36.11-2'},
#  {'name': 'libgdm1', 'version': '3.28.3-0ubuntu18.04.4'},
#  {'name': 'libgee-0.8-2:amd64', 'version': '0.20.1-1'},
#  {'name': 'libgeoclue-2-0:amd64', 'version': '2.4.7-1ubuntu1'},
#  {'name': 'libgeocode-glib0:amd64', 'version': '3.25.4.1-4ubuntu0.18.04.1'},
#  {'name': 'libgeoip1:amd64', 'version': '1.6.12-1'},
#  {'name': 'libgexiv2-2:amd64', 'version': '0.10.8-1'},
#  {'name': 'libgirepository-1.0-1:amd64', 'version': '1.56.1-1'},
#  {'name': 'libgjs0g', 'version': '1.52.5-0ubuntu18.04.1'},
#  {'name': 'libgl1:amd64', 'version': '1.0.0-2ubuntu2.3'},
#  {'name': 'libgl1-mesa-dri:amd64', 'version': '19.0.2-1ubuntu1.1~18.04.2'},
#  {'name': 'libgl1-mesa-glx:amd64', 'version': '19.0.2-1ubuntu1.1~18.04.2'},
#  {'name': 'libglapi-mesa:amd64', 'version': '19.0.2-1ubuntu1.1~18.04.2'},
#  {'name': 'libgles2:amd64', 'version': '1.0.0-2ubuntu2.3'},
#  {'name': 'libglib-object-introspection-perl', 'version': '0.044-2'},
#  {'name': 'libglib-perl', 'version': '3:1.326-1build1'},
#  {'name': 'libglib2.0-0:amd64', 'version': '2.56.4-0ubuntu0.18.04.4'},
#  {'name': 'libglib2.0-bin', 'version': '2.56.4-0ubuntu0.18.04.4'},
#  {'name': 'libglib2.0-data', 'version': '2.56.4-0ubuntu0.18.04.4'},
#  {'name': 'libglu1-mesa:amd64', 'version': '9.0.0-2.1build1'},
#  {'name': 'libglvnd0:amd64', 'version': '1.0.0-2ubuntu2.3'},
#  {'name': 'libglx-mesa0:amd64', 'version': '19.0.2-1ubuntu1.1~18.04.2'},
#  {'name': 'libglx0:amd64', 'version': '1.0.0-2ubuntu2.3'},
#  {'name': 'libgmime-3.0-0:amd64', 'version': '3.2.0-1'},
#  {'name': 'libgmp10:amd64', 'version': '2:6.1.2+dfsg-2'},
#  {'name': 'libgnome-autoar-0-0:amd64', 'version': '0.2.3-1'},
#  {'name': 'libgnome-bluetooth13:amd64', 'version': '3.28.0-2ubuntu0.2'},
#  {'name': 'libgnome-desktop-3-17:amd64', 'version': '3.28.2-0ubuntu1.5'},
#  {'name': 'libgnome-games-support-1-3:amd64', 'version': '1.4.1-1'},
#  {'name': 'libgnome-games-support-common', 'version': '1.4.1-1'},
#  {'name': 'libgnome-menu-3-0:amd64', 'version': '3.13.3-11ubuntu1.1'},
#  {'name': 'libgnome-todo', 'version': '3.28.1-1'},
#  {'name': 'libgnomekbd-common', 'version': '3.26.0-3ubuntu0.18.04.1'},
#  {'name': 'libgnomekbd8:amd64', 'version': '3.26.0-3ubuntu0.18.04.1'},
#  {'name': 'libgnutls30:amd64', 'version': '3.5.18-1ubuntu1.1'},
#  {'name': 'libgoa-1.0-0b:amd64', 'version': '3.28.0-0ubuntu2.1'},
#  {'name': 'libgoa-1.0-common', 'version': '3.28.0-0ubuntu2.1'},
#  {'name': 'libgoa-backend-1.0-1:amd64', 'version': '3.28.0-0ubuntu2.1'},
#  {'name': 'libgom-1.0-0:amd64', 'version': '0.3.3-4'},
#  {'name': 'libgomp1:amd64', 'version': '8.3.0-6ubuntu1~18.04.1'},
#  {'name': 'libgpg-error0:amd64', 'version': '1.27-6'},
#  {'name': 'libgpgme11:amd64', 'version': '1.10.0-1ubuntu2'},
#  {'name': 'libgpgmepp6:amd64', 'version': '1.10.0-1ubuntu2'},
#  {'name': 'libgphoto2-6:amd64', 'version': '2.5.16-2'},
#  {'name': 'libgphoto2-l10n', 'version': '2.5.16-2'},
#  {'name': 'libgphoto2-port12:amd64', 'version': '2.5.16-2'},
#  {'name': 'libgpm2:amd64', 'version': '1.20.7-5'},
#  {'name': 'libgpod-common', 'version': '0.8.3-11'},
#  {'name': 'libgpod4:amd64', 'version': '0.8.3-11'},
#  {'name': 'libgraphene-1.0-0:amd64', 'version': '1.8.0-1'},
#  {'name': 'libgraphite2-3:amd64', 'version': '1.3.11-2'},
#  {'name': 'libgrilo-0.3-0:amd64', 'version': '0.3.4-1'},
#  {'name': 'libgs9:amd64', 'version': '9.26~dfsg+0-0ubuntu0.18.04.11'},
#  {'name': 'libgs9-common', 'version': '9.26~dfsg+0-0ubuntu0.18.04.11'},
#  {'name': 'libgspell-1-1:amd64', 'version': '1.6.1-1'},
#  {'name': 'libgspell-1-common', 'version': '1.6.1-1'},
#  {'name': 'libgssapi-krb5-2:amd64', 'version': '1.16-2ubuntu0.1'},
#  {'name': 'libgssapi3-heimdal:amd64', 'version': '7.5.0+dfsg-1'},
#  {'name': 'libgstreamer-gl1.0-0:amd64', 'version': '1.14.5-0ubuntu1~18.04.1'},
#  {'name': 'libgstreamer-plugins-base1.0-0:amd64',
#   'version': '1.14.5-0ubuntu1~18.04.1'},
#  {'name': 'libgstreamer-plugins-good1.0-0:amd64',
#   'version': '1.14.5-0ubuntu1~18.04.1'},
#  {'name': 'libgstreamer1.0-0:amd64', 'version': '1.14.5-0ubuntu1~18.04.1'},
#  {'name': 'libgtk-3-0:amd64', 'version': '3.22.30-1ubuntu4'},
#  {'name': 'libgtk-3-bin', 'version': '3.22.30-1ubuntu4'},
#  {'name': 'libgtk-3-common', 'version': '3.22.30-1ubuntu4'},
#  {'name': 'libgtk2.0-0:amd64', 'version': '2.24.32-1ubuntu1'},
#  {'name': 'libgtk2.0-bin', 'version': '2.24.32-1ubuntu1'},
#  {'name': 'libgtk2.0-common', 'version': '2.24.32-1ubuntu1'},
#  {'name': 'libgtk3-perl', 'version': '0.032-1'},
#  {'name': 'libgtksourceview-3.0-1:amd64', 'version': '3.24.7-1'},
#  {'name': 'libgtksourceview-3.0-common', 'version': '3.24.7-1'},
#  {'name': 'libgtop-2.0-11:amd64', 'version': '2.38.0-2ubuntu0.18.04.1'},
#  {'name': 'libgtop2-common', 'version': '2.38.0-2ubuntu0.18.04.1'},
#  {'name': 'libgudev-1.0-0:amd64', 'version': '1:232-2'},
#  {'name': 'libgusb2:amd64', 'version': '0.2.11-1'},
#  {'name': 'libgutenprint2', 'version': '5.2.13-2'},
#  {'name': 'libgweather-3-15:amd64', 'version': '3.28.2-1~ubuntu18.04.1'},
#  {'name': 'libgweather-common', 'version': '3.28.2-1~ubuntu18.04.1'},
#  {'name': 'libgxps2:amd64', 'version': '0.3.0-2'},
#  {'name': 'libharfbuzz-icu0:amd64', 'version': '1.7.2-1ubuntu1'},
#  {'name': 'libharfbuzz0b:amd64', 'version': '1.7.2-1ubuntu1'},
#  {'name': 'libhcrypto4-heimdal:amd64', 'version': '7.5.0+dfsg-1'},
#  {'name': 'libheimbase1-heimdal:amd64', 'version': '7.5.0+dfsg-1'},
#  {'name': 'libheimntlm0-heimdal:amd64', 'version': '7.5.0+dfsg-1'},
#  {'name': 'libhogweed4:amd64', 'version': '3.4-1'},
#  {'name': 'libhpmud0:amd64', 'version': '3.17.10+repack0-5'},
#  {'name': 'libhtml-form-perl', 'version': '6.03-1'},
#  {'name': 'libhtml-format-perl', 'version': '2.12-1'},
#  {'name': 'libhtml-parser-perl', 'version': '3.72-3build1'},
#  {'name': 'libhtml-tagset-perl', 'version': '3.20-3'},
#  {'name': 'libhtml-tree-perl', 'version': '5.07-1'},
#  {'name': 'libhttp-cookies-perl', 'version': '6.04-1'},
#  {'name': 'libhttp-daemon-perl', 'version': '6.01-1'},
#  {'name': 'libhttp-date-perl', 'version': '6.02-1'},
#  {'name': 'libhttp-message-perl', 'version': '6.14-1'},
#  {'name': 'libhttp-negotiate-perl', 'version': '6.00-2'},
#  {'name': 'libhunspell-1.6-0:amd64', 'version': '1.6.2-1'},
#  {'name': 'libhx509-5-heimdal:amd64', 'version': '7.5.0+dfsg-1'},
#  {'name': 'libhyphen0:amd64', 'version': '2.8.8-5'},
#  {'name': 'libibus-1.0-5:amd64', 'version': '1.5.17-3ubuntu4'},
#  {'name': 'libical3:amd64', 'version': '3.0.1-5'},
#  {'name': 'libice6:amd64', 'version': '2:1.0.9-2'},
#  {'name': 'libicu60:amd64', 'version': '60.2-3ubuntu3'},
#  {'name': 'libidn11:amd64', 'version': '1.33-2.1ubuntu1.2'},
#  {'name': 'libidn2-0:amd64', 'version': '2.0.4-1.1build2'},
#  {'name': 'libiec61883-0:amd64', 'version': '1.2.0-2'},
#  {'name': 'libieee1284-3:amd64', 'version': '0.2.11-13'},
#  {'name': 'libijs-0.35:amd64', 'version': '0.35-13'},
#  {'name': 'libilmbase12:amd64', 'version': '2.2.0-11ubuntu2'},
#  {'name': 'libimobiledevice6:amd64',
#   'version': '1.2.1~git20171128.5a854327+dfsg-0.1'},
#  {'name': 'libindicator3-7', 'version': '16.10.0+18.04.20180321.1-0ubuntu1'},
#  {'name': 'libinput-bin', 'version': '1.10.4-1ubuntu0.18.04.1'},
#  {'name': 'libinput10:amd64', 'version': '1.10.4-1ubuntu0.18.04.1'},
#  {'name': 'libio-html-perl', 'version': '1.001-1'},
#  {'name': 'libio-pty-perl', 'version': '1:1.08-1.1build4'},
#  {'name': 'libio-socket-inet6-perl', 'version': '2.72-2'},
#  {'name': 'libio-socket-ssl-perl', 'version': '2.060-3~ubuntu18.04.1'},
#  {'name': 'libio-string-perl', 'version': '1.08-3'},
#  {'name': 'libip4tc0:amd64', 'version': '1.6.1-2ubuntu2'},
#  {'name': 'libip6tc0:amd64', 'version': '1.6.1-2ubuntu2'},
#  {'name': 'libipc-run-perl', 'version': '0.96-1'},
#  {'name': 'libipc-system-simple-perl', 'version': '1.25-4'},
#  {'name': 'libiptc0:amd64', 'version': '1.6.1-2ubuntu2'},
#  {'name': 'libirs160:amd64', 'version': '1:9.11.3+dfsg-1ubuntu1.8'},
#  {'name': 'libisc-export169:amd64', 'version': '1:9.11.3+dfsg-1ubuntu1.8'},
#  {'name': 'libisc169:amd64', 'version': '1:9.11.3+dfsg-1ubuntu1.8'},
#  {'name': 'libisccc160:amd64', 'version': '1:9.11.3+dfsg-1ubuntu1.8'},
#  {'name': 'libisccfg160:amd64', 'version': '1:9.11.3+dfsg-1ubuntu1.8'},
#  {'name': 'libisl19:amd64', 'version': '0.19-1'},
#  {'name': 'libiw30:amd64', 'version': '30~pre9-12ubuntu1'},
#  {'name': 'libjack-jackd2-0:amd64', 'version': '1.9.12~dfsg-2'},
#  {'name': 'libjansson4:amd64', 'version': '2.11-1'},
#  {'name': 'libjavascriptcoregtk-4.0-18:amd64',
#   'version': '2.24.2-0ubuntu0.18.04.1'},
#  {'name': 'libjbig0:amd64', 'version': '2.1-3.1build1'},
#  {'name': 'libjbig2dec0:amd64', 'version': '0.13-6'},
#  {'name': 'libjpeg-turbo8:amd64', 'version': '1.5.2-0ubuntu5.18.04.1'},
#  {'name': 'libjpeg8:amd64', 'version': '8c-2ubuntu8'},
#  {'name': 'libjson-c3:amd64', 'version': '0.12.1-1.3'},
#  {'name': 'libjson-glib-1.0-0:amd64', 'version': '1.4.2-3'},
#  {'name': 'libjson-glib-1.0-common', 'version': '1.4.2-3'},
#  {'name': 'libk5crypto3:amd64', 'version': '1.16-2ubuntu0.1'},
#  {'name': 'libkeyutils1:amd64', 'version': '1.5.9-9.2ubuntu2'},
#  {'name': 'libklibc', 'version': '2.0.4-9ubuntu2'},
#  {'name': 'libkmod2:amd64', 'version': '24-1ubuntu3.2'},
#  {'name': 'libkpathsea6:amd64', 'version': '2017.20170613.44572-8ubuntu0.1'},
#  {'name': 'libkrb5-26-heimdal:amd64', 'version': '7.5.0+dfsg-1'},
#  {'name': 'libkrb5-3:amd64', 'version': '1.16-2ubuntu0.1'},
#  {'name': 'libkrb5support0:amd64', 'version': '1.16-2ubuntu0.1'},
#  {'name': 'libksba8:amd64', 'version': '1.3.5-2'},
#  {'name': 'liblangtag-common', 'version': '0.6.2-1'},
#  {'name': 'liblangtag1:amd64', 'version': '0.6.2-1'},
#  {'name': 'liblcms2-2:amd64', 'version': '2.9-1ubuntu0.1'},
#  {'name': 'liblcms2-utils', 'version': '2.9-1ubuntu0.1'},
#  {'name': 'libldap-2.4-2:amd64', 'version': '2.4.45+dfsg-1ubuntu1.3'},
#  {'name': 'libldap-common', 'version': '2.4.45+dfsg-1ubuntu1.3'},
#  {'name': 'libldb1:amd64', 'version': '2:1.2.3-1ubuntu0.1'},
#  {'name': 'liblirc-client0:amd64', 'version': '0.10.0-2'},
#  {'name': 'liblist-moreutils-perl', 'version': '0.416-1build3'},
#  {'name': 'libllvm6.0:amd64', 'version': '1:6.0-1ubuntu2'},
#  {'name': 'libllvm8:amd64', 'version': '1:8-3~ubuntu18.04.1'},
#  {'name': 'liblocale-gettext-perl', 'version': '1.07-3build2'},
#  {'name': 'liblouis-data', 'version': '3.5.0-1ubuntu0.3'},
#  {'name': 'liblouis14:amd64', 'version': '3.5.0-1ubuntu0.3'},
#  {'name': 'liblouisutdml-bin', 'version': '2.7.0-1'},
#  {'name': 'liblouisutdml-data', 'version': '2.7.0-1'},
#  {'name': 'liblouisutdml8:amd64', 'version': '2.7.0-1'},
#  {'name': 'liblqr-1-0:amd64', 'version': '0.4.2-2.1'},
#  {'name': 'libltdl7:amd64', 'version': '2.4.6-2'},
#  {'name': 'liblua5.3-0:amd64', 'version': '5.3.3-1ubuntu0.18.04.1'},
#  {'name': 'liblwp-mediatypes-perl', 'version': '6.02-1'},
#  {'name': 'liblwp-protocol-https-perl', 'version': '6.07-2'},
#  {'name': 'liblwres160:amd64', 'version': '1:9.11.3+dfsg-1ubuntu1.8'},
#  {'name': 'liblz4-1:amd64', 'version': '0.0~r131-2ubuntu3'},
#  {'name': 'liblzma5:amd64', 'version': '5.2.2-1.3'},
#  {'name': 'liblzo2-2:amd64', 'version': '2.08-1.2'},
#  {'name': 'libmagic-mgc', 'version': '1:5.32-2ubuntu0.2'},
#  {'name': 'libmagic1:amd64', 'version': '1:5.32-2ubuntu0.2'},
#  {'name': 'libmagickcore-6.q16-3:amd64',
#   'version': '8:6.9.7.4+dfsg-16ubuntu6.7'},
#  {'name': 'libmagickcore-6.q16-3-extra:amd64',
#   'version': '8:6.9.7.4+dfsg-16ubuntu6.7'},
#  {'name': 'libmagickwand-6.q16-3:amd64',
#   'version': '8:6.9.7.4+dfsg-16ubuntu6.7'},
#  {'name': 'libmailtools-perl', 'version': '2.18-1'},
#  {'name': 'libmbim-glib4:amd64', 'version': '1.18.0-1~ubuntu18.04.1'},
#  {'name': 'libmbim-proxy', 'version': '1.18.0-1~ubuntu18.04.1'},
#  {'name': 'libmediaart-2.0-0:amd64', 'version': '1.9.4-1'},
#  {'name': 'libmessaging-menu0:amd64',
#   'version': '13.10.1+17.04.20170120-0ubuntu2'},
#  {'name': 'libmhash2:amd64', 'version': '0.9.9.9-7'},
#  {'name': 'libminiupnpc10:amd64', 'version': '1.9.20140610-4ubuntu2'},
#  {'name': 'libmm-glib0:amd64', 'version': '1.10.0-1~ubuntu18.04.2'},
#  {'name': 'libmnl0:amd64', 'version': '1.0.4-2'},
#  {'name': 'libmount1:amd64', 'version': '2.31.1-0.4ubuntu3.3'},
#  {'name': 'libmozjs-52-0:amd64', 'version': '52.9.1-0ubuntu0.18.04.1'},
#  {'name': 'libmp3lame0:amd64', 'version': '3.100-2'},
#  {'name': 'libmpc3:amd64', 'version': '1.1.0-1'},
#  {'name': 'libmpdec2:amd64', 'version': '2.4.2-1ubuntu1'},
#  {'name': 'libmpfr6:amd64', 'version': '4.0.1-1'},
#  {'name': 'libmpg123-0:amd64', 'version': '1.25.10-1'},
#  {'name': 'libmspub-0.1-1:amd64', 'version': '0.1.4-1'},
#  {'name': 'libmtdev1:amd64', 'version': '1.1.5-1ubuntu3'},
#  {'name': 'libmtp-common', 'version': '1.1.13-1'},
#  {'name': 'libmtp-runtime', 'version': '1.1.13-1'},
#  {'name': 'libmtp9:amd64', 'version': '1.1.13-1'},
#  {'name': 'libmutter-2-0:amd64', 'version': '3.28.4-0ubuntu18.04.1'},
#  {'name': 'libmwaw-0.3-3:amd64', 'version': '0.3.13-1'},
#  {'name': 'libmythes-1.2-0:amd64', 'version': '2:1.2.4-3'},
#  {'name': 'libnatpmp1', 'version': '20150609-2'},
#  {'name': 'libnautilus-extension1a:amd64',
#   'version': '1:3.26.4-0~ubuntu18.04.4'},
#  {'name': 'libncurses5:amd64', 'version': '6.1-1ubuntu1.18.04'},
#  {'name': 'libncursesw5:amd64', 'version': '6.1-1ubuntu1.18.04'},
#  {'name': 'libndp0:amd64', 'version': '1.6-1'},
#  {'name': 'libneon27-gnutls:amd64', 'version': '0.30.2-3~ubuntu18.04.1'},
#  {'name': 'libnet-dbus-perl', 'version': '1.1.0-4build2'},
#  {'name': 'libnet-dns-perl', 'version': '1.10-2'},
#  {'name': 'libnet-domain-tld-perl', 'version': '1.75-1'},
#  {'name': 'libnet-http-perl', 'version': '6.17-1'},
#  {'name': 'libnet-ip-perl', 'version': '1.26-1'},
#  {'name': 'libnet-libidn-perl', 'version': '0.12.ds-2build4'},
#  {'name': 'libnet-smtp-ssl-perl', 'version': '1.04-1'},
#  {'name': 'libnet-ssleay-perl', 'version': '1.84-1ubuntu0.2'},
#  {'name': 'libnetfilter-conntrack3:amd64', 'version': '1.0.6-2'},
#  {'name': 'libnetpbm10', 'version': '2:10.0-15.3build1'},
#  {'name': 'libnettle6:amd64', 'version': '3.4-1'},
#  {'name': 'libnewt0.52:amd64', 'version': '0.52.20-1ubuntu1'},
#  {'name': 'libnfnetlink0:amd64', 'version': '1.0.1-3'},
#  {'name': 'libnghttp2-14:amd64', 'version': '1.30.0-1ubuntu1'},
#  {'name': 'libnih1:amd64', 'version': '1.0.3-6ubuntu2'},
#  {'name': 'libnl-3-200:amd64', 'version': '3.2.29-0ubuntu3'},
#  {'name': 'libnl-genl-3-200:amd64', 'version': '3.2.29-0ubuntu3'},
#  {'name': 'libnm0:amd64', 'version': '1.10.6-2ubuntu1.1'},
#  {'name': 'libnma0:amd64', 'version': '1.8.10-2ubuntu2'},
#  {'name': 'libnotify-bin', 'version': '0.7.7-3'},
#  {'name': 'libnotify4:amd64', 'version': '0.7.7-3'},
#  {'name': 'libnpth0:amd64', 'version': '1.5-3'},
#  {'name': 'libnspr4:amd64', 'version': '2:4.18-1ubuntu1'},
#  {'name': 'libnss-mdns:amd64', 'version': '0.10-8ubuntu1'},
#  {'name': 'libnss-myhostname:amd64', 'version': '237-3ubuntu10.28'},
#  {'name': 'libnss-systemd:amd64', 'version': '237-3ubuntu10.28'},
#  {'name': 'libnss3:amd64', 'version': '2:3.35-2ubuntu2.3'},
#  {'name': 'libntfs-3g88', 'version': '1:2017.3.23-2ubuntu0.18.04.2'},
#  {'name': 'libnuma1:amd64', 'version': '2.0.11-2.1ubuntu0.1'},
#  {'name': 'liboauth0:amd64', 'version': '1.0.3-1'},
#  {'name': 'libodfgen-0.1-1:amd64', 'version': '0.1.6-2'},
#  {'name': 'libogg0:amd64', 'version': '1.3.2-1'},
#  {'name': 'libopenexr22:amd64', 'version': '2.2.0-11.1ubuntu1'},
#  {'name': 'libopus0:amd64', 'version': '1.1.2-1ubuntu1'},
#  {'name': 'liborc-0.4-0:amd64', 'version': '1:0.4.28-1'},
#  {'name': 'liborcus-0.13-0:amd64', 'version': '0.13.4-2'},
#  {'name': 'libp11-kit0:amd64', 'version': '0.23.9-2'},
#  {'name': 'libpackagekit-glib2-18:amd64', 'version': '1.1.9-1ubuntu2.18.04.5'},
#  {'name': 'libpagemaker-0.0-0:amd64', 'version': '0.0.4-1'},
#  {'name': 'libpam-cap:amd64', 'version': '1:2.25-1.2'},
#  {'name': 'libpam-gnome-keyring:amd64',
#   'version': '3.28.0.2-1ubuntu1.18.04.1'},
#  {'name': 'libpam-modules:amd64', 'version': '1.1.8-3.6ubuntu2.18.04.1'},
#  {'name': 'libpam-modules-bin', 'version': '1.1.8-3.6ubuntu2.18.04.1'},
#  {'name': 'libpam-runtime', 'version': '1.1.8-3.6ubuntu2.18.04.1'},
#  {'name': 'libpam-systemd:amd64', 'version': '237-3ubuntu10.28'},
#  {'name': 'libpam0g:amd64', 'version': '1.1.8-3.6ubuntu2.18.04.1'},
#  {'name': 'libpango-1.0-0:amd64', 'version': '1.40.14-1ubuntu0.1'},
#  {'name': 'libpangocairo-1.0-0:amd64', 'version': '1.40.14-1ubuntu0.1'},
#  {'name': 'libpangoft2-1.0-0:amd64', 'version': '1.40.14-1ubuntu0.1'},
#  {'name': 'libpangoxft-1.0-0:amd64', 'version': '1.40.14-1ubuntu0.1'},
#  {'name': 'libpaper-utils', 'version': '1.1.24+nmu5ubuntu1'},
#  {'name': 'libpaper1:amd64', 'version': '1.1.24+nmu5ubuntu1'},
#  {'name': 'libparse-debianchangelog-perl', 'version': '1.2.0-12'},
#  {'name': 'libparted-fs-resize0:amd64', 'version': '3.2-20ubuntu0.2'},
#  {'name': 'libparted2:amd64', 'version': '3.2-20ubuntu0.2'},
#  {'name': 'libpcap0.8:amd64', 'version': '1.8.1-6ubuntu1'},
#  {'name': 'libpcaudio0', 'version': '1.0-1'},
#  {'name': 'libpci3:amd64', 'version': '1:3.5.2-1ubuntu1.1'},
#  {'name': 'libpciaccess0:amd64', 'version': '0.14-1'},
#  {'name': 'libpcre3:amd64', 'version': '2:8.39-9'},
#  {'name': 'libpcsclite1:amd64', 'version': '1.8.23-1'},
#  {'name': 'libpeas-1.0-0:amd64', 'version': '1.22.0-2'},
#  {'name': 'libpeas-common', 'version': '1.22.0-2'},
#  {'name': 'libperl5.26:amd64', 'version': '5.26.1-6ubuntu0.3'},
#  {'name': 'libperlio-gzip-perl', 'version': '0.19-1build3'},
#  {'name': 'libphonenumber7:amd64', 'version': '7.1.0-5ubuntu5'},
#  {'name': 'libpipeline1:amd64', 'version': '1.5.0-1'},
#  {'name': 'libpixman-1-0:amd64', 'version': '0.34.0-2'},
#  {'name': 'libplist3:amd64', 'version': '2.0.0-2ubuntu1'},
#  {'name': 'libplymouth4:amd64', 'version': '0.9.3-1ubuntu7.18.04.2'},
#  {'name': 'libpng16-16:amd64', 'version': '1.6.34-1ubuntu0.18.04.2'},
#  {'name': 'libpolkit-agent-1-0:amd64', 'version': '0.105-20ubuntu0.18.04.5'},
#  {'name': 'libpolkit-backend-1-0:amd64', 'version': '0.105-20ubuntu0.18.04.5'},
#  {'name': 'libpolkit-gobject-1-0:amd64', 'version': '0.105-20ubuntu0.18.04.5'},
#  {'name': 'libpoppler-glib8:amd64', 'version': '0.62.0-2ubuntu2.10'},
#  {'name': 'libpoppler73:amd64', 'version': '0.62.0-2ubuntu2.10'},
#  {'name': 'libpopt0:amd64', 'version': '1.16-11'},
#  {'name': 'libprocps6:amd64', 'version': '2:3.3.12-3ubuntu1.1'},
#  {'name': 'libprotobuf10:amd64', 'version': '3.0.0-9.1ubuntu1'},
#  {'name': 'libproxy1-plugin-gsettings:amd64', 'version': '0.4.15-1'},
#  {'name': 'libproxy1-plugin-networkmanager:amd64', 'version': '0.4.15-1'},
#  {'name': 'libproxy1v5:amd64', 'version': '0.4.15-1'},
#  {'name': 'libpsl5:amd64', 'version': '0.19.1-5build1'},
#  {'name': 'libpulse-mainloop-glib0:amd64', 'version': '1:11.1-1ubuntu7.2'},
#  {'name': 'libpulse0:amd64', 'version': '1:11.1-1ubuntu7.2'},
#  {'name': 'libpulsedsp:amd64', 'version': '1:11.1-1ubuntu7.2'},
#  {'name': 'libpwquality-common', 'version': '1.4.0-2'},
#  {'name': 'libpwquality1:amd64', 'version': '1.4.0-2'},
#  {'name': 'libpython2.7:amd64', 'version': '2.7.15-4ubuntu4~18.04'},
#  {'name': 'libpython2.7-minimal:amd64', 'version': '2.7.15-4ubuntu4~18.04'},
#  {'name': 'libpython2.7-stdlib:amd64', 'version': '2.7.15-4ubuntu4~18.04'},
#  {'name': 'libpython3-stdlib:amd64', 'version': '3.6.7-1~18.04'},
#  {'name': 'libpython3.6:amd64', 'version': '3.6.8-1~18.04.1'},
#  {'name': 'libpython3.6-minimal:amd64', 'version': '3.6.8-1~18.04.1'},
#  {'name': 'libpython3.6-stdlib:amd64', 'version': '3.6.8-1~18.04.1'},
#  {'name': 'libqmi-glib5:amd64', 'version': '1.22.0-1.2~ubuntu18.04.1'},
#  {'name': 'libqmi-proxy', 'version': '1.22.0-1.2~ubuntu18.04.1'},
#  {'name': 'libqpdf21:amd64', 'version': '8.0.2-3'},
#  {'name': 'libqqwing2v5:amd64', 'version': '1.3.4-1.1'},
#  {'name': 'libraptor2-0:amd64', 'version': '2.0.14-1build1'},
#  {'name': 'librasqal3:amd64', 'version': '0.9.32-1build1'},
#  {'name': 'libraw1394-11:amd64', 'version': '2.1.2-1'},
#  {'name': 'libraw16:amd64', 'version': '0.18.8-1ubuntu0.3'},
#  {'name': 'librdf0:amd64', 'version': '1.0.17-1.1'},
#  {'name': 'libreadline7:amd64', 'version': '7.0-3'},
#  {'name': 'libreoffice-avmedia-backend-gstreamer',
#   'version': '1:6.0.7-0ubuntu0.18.04.9'},
#  {'name': 'libreoffice-base-core', 'version': '1:6.0.7-0ubuntu0.18.04.9'},
#  {'name': 'libreoffice-calc', 'version': '1:6.0.7-0ubuntu0.18.04.9'},
#  {'name': 'libreoffice-common', 'version': '1:6.0.7-0ubuntu0.18.04.9'},
#  {'name': 'libreoffice-core', 'version': '1:6.0.7-0ubuntu0.18.04.9'},
#  {'name': 'libreoffice-draw', 'version': '1:6.0.7-0ubuntu0.18.04.9'},
#  {'name': 'libreoffice-gnome', 'version': '1:6.0.7-0ubuntu0.18.04.9'},
#  {'name': 'libreoffice-gtk3', 'version': '1:6.0.7-0ubuntu0.18.04.9'},
#  {'name': 'libreoffice-help-en-us', 'version': '1:6.0.7-0ubuntu0.18.04.9'},
#  {'name': 'libreoffice-impress', 'version': '1:6.0.7-0ubuntu0.18.04.9'},
#  {'name': 'libreoffice-math', 'version': '1:6.0.7-0ubuntu0.18.04.9'},
#  {'name': 'libreoffice-ogltrans', 'version': '1:6.0.7-0ubuntu0.18.04.9'},
#  {'name': 'libreoffice-pdfimport', 'version': '1:6.0.7-0ubuntu0.18.04.9'},
#  ...]

# %%
crawler.get_deamon_services()
# Out:
# [{'name': 'accounts-daemon'},
#  {'name': 'acpid'},
#  {'name': 'apparmor'},
#  {'name': 'apport'},
#  {'name': 'avahi-daemon'},
#  {'name': 'bolt'},
#  {'name': 'colord'},
#  {'name': 'console-setup'},
#  {'name': 'cron'},
#  {'name': 'cups-browsed'},
#  {'name': 'cups'},
#  {'name': 'dbus'},
#  {'name': 'fwupd'},
#  {'name': 'gdm'},
#  {'name': 'grub-common'},
#  {'name': 'kerneloops'},
#  {'name': 'keyboard-setup'},
#  {'name': 'kmod-static-nodes'},
#  {'name': 'ModemManager'},
#  {'name': 'networkd-dispatcher'},
#  {'name': 'networking'},
#  {'name': 'NetworkManager-wait-online'},
#  {'name': 'NetworkManager'},
#  {'name': 'packagekit'},
#  {'name': 'polkit'},
#  {'name': 'rsyslog'},
#  {'name': 'rtkit-daemon'},
#  {'name': 'setvtrgb'},
#  {'name': 'snapd.seeded'},
#  {'name': 'snapd'},
#  {'name': 'speech-dispatcher'},
#  {'name': 'ssh'},
#  {'name': 'systemd-journal-flush'},
#  {'name': 'systemd-journald'},
#  {'name': 'systemd-logind'},
#  {'name': 'systemd-modules-load'},
#  {'name': 'systemd-random-seed'},
#  {'name': 'systemd-remount-fs'},
#  {'name': 'systemd-resolved'},
#  {'name': 'systemd-sysctl'},
#  {'name': 'systemd-tmpfiles-setup-dev'},
#  {'name': 'systemd-tmpfiles-setup'},
#  {'name': 'systemd-udev-trigger'},
#  {'name': 'systemd-udevd'},
#  {'name': 'systemd-update-utmp'},
#  {'name': 'systemd-user-sessions'},
#  {'name': 'udisks2'},
#  {'name': 'ufw'},
#  {'name': 'unattended-upgrades'},
#  {'name': 'upower'},
#  {'name': 'user@1000'},
#  {'name': 'user@121'},
#  {'name': 'vboxadd-service'},
#  {'name': 'vboxadd'},
#  {'name': 'whoopsie'},
#  {'name': 'wpa_supplicant'}]

# %%
class CentOSInfoCrawler(LinuxSystemInfoCrawler):
    def get_updates(self):
        return
    
    def get_software(self):
        return

    
class FedoraInfoCrawler(LinuxSystemInfoCrawler):
    def get_updates(self):
        return
    
    def get_software(self):
        return

    
class RedHatInfoCrawler(LinuxSystemInfoCrawler):
    def get_updates(self):software
        return
    
    def get_software(self):
        return

    
class FreeBSDInfoCrawler(LinuxSystemInfoCrawler):
    def get_updates(self):
        return
    
    def get_software(self):
        return

class OpenBSDInfoCrawler(LinuxSystemInfoCrawler):
    def get_updates(self):
        return
    
    def get_software(self):
        return
